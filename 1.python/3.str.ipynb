# %% [markdown]
# - What is string

# %% [markdown]
# to record the text information, such as names , words, phrases, sentences, paragraphs, or an entire encylopedia

# %% [markdown]
# to create the string we can either **single quotes** or **doubles quotes** or **triple quotes**

# %%
x= 'john'

print(x)
# Out:
# john

# %%
type(x)
# Out:
# str

# %%
x="john"

print(x)
# Out:
# john

# %%
y='deeplearning sits at the heart of generativeai'

print(y)
# Out:
# deeplearning sits at the heart of generativeai

# %%
z='I'm jaya , i want to become a data scientist'
print(z)
# Out:
#   Cell In[22], line 1
#     z='I'm jaya , i want to become a data scientist'
#                                                    ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
z="I'm jaya , i want to become a data scientist"
print(z)
# Out:
# I'm jaya , i want to become a data scientist

# %%
p=' The main benefit of agentic AI is its ability to dramatically lower "transaction costs"—the time and human effort spent searching for data
communicating, and completing administrative tasks. By doing these steps at a fraction of the cost, businesses can scale their productivity to new heights
Deploying agentic AI is not just about adopting a new tool; 
it requires a complete workflow transformation. Organizations must align data, put safety guardrails in place, and rethink how people and machines work together'
# Out:
#   Cell In[25], line 1
#     p=' The main benefit of agentic AI is its ability to dramatically lower "transaction costs"—the time and human effort spent searching for data
#       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
p=" The main benefit of agentic AI is its ability to dramatically lower "transaction costs"—the time and human effort spent searching for data
communicating, and completing administrative tasks. By doing these steps at a fraction of the cost, businesses can scale their productivity to new heights
Deploying agentic AI is not just about adopting a new tool; 
it requires a complete workflow transformation. Organizations must align data, put safety guardrails in place, and rethink how people and machines work together"
# Out:
#   Cell In[26], line 1
#     p=" The main benefit of agentic AI is its ability to dramatically lower "transaction costs"—the time and human effort spent searching for data
#                                                                                               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
p='''The main benefit of agentic AI is its ability to dramatically lower "transaction costs"—the time and human effort spent searching for data
communicating, and completing administrative tasks. By doing these steps at a fraction of the cost, businesses can scale their productivity to new heights
Deploying agentic AI is not just about adopting a new tool; 
it requires a complete workflow transformation. Organizations must align data, put safety guardrails in place, and rethink how people and machines work together'''


print(p)
# Out:
# The main benefit of agentic AI is its ability to dramatically lower "transaction costs"—the time and human effort spent searching for data
# communicating, and completing administrative tasks. By doing these steps at a fraction of the cost, businesses can scale their productivity to new heights
# Deploying agentic AI is not just about adopting a new tool;
# it requires a complete workflow transformation. Organizations must align data, put safety guardrails in place, and rethink how people and machines work together

# %% [markdown]
# - string  immutable

# %%
p.upper()
# Out:
# 'THE MAIN BENEFIT OF AGENTIC AI IS ITS ABILITY TO DRAMATICALLY LOWER "TRANSACTION COSTS"—THE TIME AND HUMAN EFFORT SPENT SEARCHING FOR DATA\nCOMMUNICATING, AND COMPLETING ADMINISTRATIVE TASKS. BY DOING THESE STEPS AT A FRACTION OF THE COST, BUSINESSES CAN SCALE THEIR PRODUCTIVITY TO NEW HEIGHTS\nDEPLOYING AGENTIC AI IS NOT JUST ABOUT ADOPTING A NEW TOOL; \nIT REQUIRES A COMPLETE WORKFLOW TRANSFORMATION. ORGANIZATIONS MUST ALIGN DATA, PUT SAFETY GUARDRAILS IN PLACE, AND RETHINK HOW PEOPLE AND MACHINES WORK TOGETHER'

# %%
p
# Out:
# 'The main benefit of agentic AI is its ability to dramatically lower "transaction costs"—the time and human effort spent searching for data\ncommunicating, and completing administrative tasks. By doing these steps at a fraction of the cost, businesses can scale their productivity to new heights\nDeploying agentic AI is not just about adopting a new tool; \nit requires a complete workflow transformation. Organizations must align data, put safety guardrails in place, and rethink how people and machines work together'

# %% [markdown]
# - List mutable

# %%
a=[1,3,6,9]


print(a)
# Out:
# [1, 3, 6, 9]

# %%
a.append(10)
print(a)
# Out:
# [1, 3, 6, 9, 10]

# %%
a
# Out:
# [1, 3, 6, 9, 10]

# %% [markdown]
# - When to use print()

# %%
"ravi"

"ai&ml"

"hyderabad"
# Out:
# 'hyderabad'

# %%
print("ravi")
print("ai&ml")
print("hyderabad")
# Out:
# ravi
# ai&ml
# hyderabad

# %%
print("Hello","AI&ML","Hyderabad",1,3,5,.9,5+8j,True,False)
# Out:
# Hello AI&ML Hyderabad 1 3 5 0.9 (5+8j) True False

# %%
print("Hello","AI&ML","Hyderabad",1,3,5,.9,5+8j,True,False,sep=' ')
# Out:
# Hello AI&ML Hyderabad 1 3 5 0.9 (5+8j) True False

# %%
print("Hello","AI&ML","Hyderabad",1,3,5,.9,5+8j,True,False,sep="   ")
# Out:
# Hello   AI&ML   Hyderabad   1   3   5   0.9   (5+8j)   True   False

# %%
print("Hello","AI&ML","Hyderabad",1,3,5,.9,5+8j,True,False,sep="*")
# Out:
# Hello*AI&ML*Hyderabad*1*3*5*0.9*(5+8j)*True*False

# %%
print("8")
print()
print(9)
# Out:
# 8
#
# 9

# %%
print("ai&ml")
print("hyderabad")
# Out:
# ai&ml
# hyderabad

# %%
print("ai&ml",end=' ')
print("hyderabad")
# Out:
# ai&ml hyderabad

# %%
print("ai&ml",end='+')
print("hyderabad")
# Out:
# ai&ml+hyderabad

# %% [markdown]
# - issue here

# %%
x=5
y="john"

print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       1 x=5
#       2 y="john"
#       3
# ----> 4 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# - concatenate

# %%
x=9

print(x)
print(type(x))
# Out:
# 9
# <class 'int'>

# %%
print(type(str(x)))
# Out:
# 5
# <class 'str'>

# %%
x=5
y="john"

print(  str(x) +y)
# Out:
# 5john

# %%
x=5
y="john"

print(  str(x)+ "   " +y)
# Out:
# 5   john

# %% [markdown]
# - Indexing
#
# +ve or forward indexing (start from left (0)  to right)
#
# -ve or backward indexing  (start from (-1) Right 2  left )

# %%
a="datascience"

# %% [markdown]
# - print t

# %%
a[2]
# Out:
# 't'

# %%
a[-9]
# Out:
# 't'

# %%
print(a[4])

print(a[-7])
# Out:
# s
# s

# %% [markdown]
# - slicing

# %%
a='DataScience' 

print(a)
# Out:
# DataScience

# %%
print(a[0:4])
# Out:
# Data

# %%
print(a[2:5])
# Out:
# taS

# %% [markdown]
# - step (n-1)

# %%
a="datascience"

a
# Out:
# 'datascience'

# %%
print(a[::])
# Out:
# datascience

# %%
print(a[0:4:])
# Out:
# data

# %%
print(a[0:4:1])
# Out:
# data

# %%
print(a[0:4:-1])

# %%
print(a[0:4:2])
# Out:
# dt

# %% [markdown]
# - ve slicing

# %%
a= "DataScience"

a[-11:-7]
# Out:
# 'Data'

# %%
a[-8:-11]
# Out:
# ''

# %%
a[-11:-7:]
# Out:
# 'Data'

# %%
a[-11:-7:1]
# Out:
# 'Data'

# %%
a[-11:-7:-1]
# Out:
# ''

# %%
a[-11:-3:]
# Out:
# 'DataScie'

# %%
a[-11:-3:3]
# Out:
# 'Dai'

# %%
a[-11:-3:-3]
# Out:
# ''

# %%
a[-8:-11:-1]
# Out:
# 'ata'

# %% [markdown]
# - methods & functions

# %% [markdown]
# - index

# %%
a= "datascience"

# %%
a.index("s")
# Out:
# 4

# %%
a.index("a")
# Out:
# 1

# %% [markdown]
# - immutable

# %%
s="Hello"

# %%
s[0]="C"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 s[0]="C"
#
# TypeError: 'str' object does not support item assignment

# %%
s.replace("H",'C')
# Out:
# 'Cello'

# %%
s
# Out:
# 'Hello'

# %% [markdown]
# - len()   - Function

# %%
len(s)
# Out:
# 5

# %% [markdown]
# - methods

# %% [markdown]
# - upper()

# %%
s.upper()
# Out:
# 'HELLO'

# %%
s.lower()
# Out:
# 'hello'

# %%
p="mathematics is heart of machine learning & deeplearning"

p
# Out:
# 'mathematics is heart of machine learning & deeplearning'

# %%
p.capitalize()
# Out:
# 'Mathematics is heart of machine learning & deeplearning'

# %%
p.title()
# Out:
# 'Mathematics Is Heart Of Machine Learning & Deeplearning'

# %%
"HydeRAbAd".swapcase()
# Out:
# 'hYDEraBaD'

# %%
name ="          raju"


name
# Out:
# '          raju'

# %%
name.lstrip()
# Out:
# 'raju'

# %%
name1 ="raju             "

name1
# Out:
# 'raju             '

# %%
name1.rstrip()
# Out:
# 'raju'

# %%
name2="       raju         "

name2
# Out:
# '       raju         '

# %%
name2.strip()
# Out:
# 'raju'

# %% [markdown]
# - count

# %%
z="Deep Neural Networks"

z
# Out:
# 'Deep Neural Networks'

# %%
z.count("Ne")
# Out:
# 2

# %%
z.count("e")
# Out:
# 4

# %%
z.count(" ")
# Out:
# 2

# %%
z
# Out:
# 'Deep Neural Networks'

# %%
z.find("D")
# Out:
# 0

# %%
z.find("N")
# Out:
# 5

# %%
z.find("i")
# Out:
# -1

# %% [markdown]
# - startswith / endswith

# %%
a= "it is raining"



a.startswith("if")
# Out:
# False

# %%
a.endswith("raining")
# Out:
# True

# %%
b="flat"

b.isalpha()
# Out:
# True

# %%
b="flat50"

b.isalpha()
# Out:
# False

# %% [markdown]
# - isalnum    ---> either alphabets or numebrs or both

# %%
b="flat50"

b.isalnum()
# Out:
# True

# %%
c="50"

c.isalnum()
# Out:
# True

# %%
c="flat"

c.isalnum()
# Out:
# True

# %%
c="flat50@"

c.isalnum()
# Out:
# False

# %%
e="209"

e.isdigit()
# Out:
# True

# %%
b="flat50"

b.isdigit()
# Out:
# False

# %% [markdown]
# - split / join

# %%
a="who is pm of india"


a.split()
# Out:
# ['who', 'is', 'pm', 'of', 'india']

# %%
a="who is pm of india"


a.split("x")
# Out:
# ['who is pm of india']

# %%
de=['who', 'is', 'pm', 'of', 'india']


" ".join(de)
# Out:
# 'who is pm of india'

# %%
de=['who', 'is', 'pm', 'of', 'india']


"#".join(de)
# Out:
# 'who#is#pm#of#india'

# %%
de=('who', 'is', 'pm', 'of', 'india')

" ".join(de)
# Out:
# 'who is pm of india'

# %% [markdown]
# - format

# %%
a="ravi"

a
# Out:
# 'ravi'

# %%
print("this is name :", a)
# Out:
# this is name : ravi

# %%
name="ravi"

age=60

print(f"Hello my name is {name} and I am {age}")
# Out:
#    Hello my name is ravi and I am 60

# %%
print("Hello ,my name is {} and I am {} ".format("ravi",60))
# Out:
# Hello ,my name is ravi and I am 60

# %%
print("Hello ,my name is {0} and I am {1} ".format("ravi",60))
# Out:
# Hello ,my name is ravi and I am 60

# %%
print("Hello ,my name is {1} and I am {0} ".format("ravi",60))
# Out:
# Hello ,my name is 60 and I am ravi

# %%
a= "datascience"


a[::1]
# Out:
# 'datascience'

# %%
a[::-1]
# Out:
# 'ecneicsatad'

# %%
a[::-2]
# Out:
# 'enistd'

# %%
a[::-3]
# Out:
# 'eesa'
