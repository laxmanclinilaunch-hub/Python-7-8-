# %% [markdown]
# # If- elif - else

# %% [markdown]
# if statements in python allows us to tell the computer to perform alternative actions based on certain set conditional results
#
# we are telling to the computer "Hey if this case happens , perform someaction, otherwise  if another case happens perform someother action , otherwise if  all other actions are failed perform this action only"

# %% [markdown]
# if case1:
#
#     perform action1
#
# elif case2:
#
#     perofmr action2
#
# else:
#
#     perform action3

# %%
5<10

# %%
a= 5

if a<10:       # it is true                 #
    print("yes , it is true")
# Out:
# yes , it is true

# %%
a= 5

if a>10:       # it is False                 #
    print("yes , it is true")

# %%
a= 5

if a<10:       # it is true               
    print("yes , it is true")
    
else:
    print("No, it is False")
# Out:
# yes , it is true

# %%
a= 5

if a>10:       # it is false               
    print("yes , it is true")
    
else:
    print("No, it is False")
# Out:
# No, it is False

# %%
a=10

if a==11:
    print('my conditions was false')

else:
    print("it is printed means ,above if conditoins fails")
# Out:
# it is printed means ,above if conditoins fails

# %%
a= 10
if a==12:
    print("here we are trying to compare a with 12")

elif a==10:
    print("we are trying to compare a with 10 ")

else:
    print("if all the above blocks are failed the print this only")
# Out:
# we are trying to compare a with 10

# %%
city="hyderabad"

if city=="mumbai":
    print("welcome to the mumbai")
elif city=="chennai":
    print("welcome to chennai")
elif city=="delhi":
    print("welcome to the delhi")
else:
    print("where are you?")
# Out:
# where are you?

# %%
city="hyderabad"

if city=="mumbai":
    print("welcome to the mumbai")
elif city=="chennai":
    print("welcome to chennai")
elif city=="hyderabad":
    print("welcome to the hyderabad")
else:
    print("where are you?")
# Out:
# welcome to the hyderabad

# %% [markdown]
# - nested if-elif-else

# %%
number1=-2

number2=9

if number1 >0:
    if number2<10:
        print(number1+number2)
    else:
        print("the number should be greterthan 10")
elif number1 <0:
    print("this is a negative number")

else:
    print("the number is zero")
# Out:
# this is a negative number

# %%
number1=int(input())

number2=int(input())

if number1 >0:
    if number2<10:
        print(number1+number2)
    else:
        print("the number should be greterthan 10")
elif number1 <0:
    print("this is a negative number")

else:
    print("the number is zero")
# Out:
# 9

# %%
a=10
print(a)

print(type(a))
# Out:
# 10
# <class 'int'>

# %%
b=input()

print(b)

print(type(b))
# Out:
# this is laxman
# <class 'str'>

# %%
c=int(input())

print(c)

print(type(c))
# Out:
# 99
# <class 'int'>

# %%
d=float(input())

print(d)

print(type(d))
# Out:
# 7.0
# <class 'float'>

# %%
val = float(input("enter the float number"))


if val >=0:
    if val == 0:
        print('entered value is Zero')
    else:
        print('enter value is positive number')

else:
    print("enter value is negative number")
# Out:
# enter value is negative number

# %%
val = float(input("enter the float number"))

if val>0:
    print("the value was +ve number")
elif val==0:
    print("the value is Zero")
else:
    print('given number negative')
# Out:
# given number negative

# %%
marks= int(input())

if marks < 600:
    print("Not quilified GRE")
    if marks <500:
        print("Not qulified Tofel")
        if marks <400:
            print('again write the exam tofel')
    else:
        print("selected for Tofel")

else:
    print("selected for GRE")
# Out:
# Not quilified GRE
# Not qulified Tofel

# %%
a=[1,2,3,"suhas",35.75,6.9]


for i in a:
    print(i)
# Out:
# 1
# 2
# 3
# suhas
# 35.75
# 6.9

# %%
for i in a:
    if type(i)==int:
        print(i)
# Out:
# 1
# 2
# 3

# %%
for i in a:
    if type(i)==str:
        print(i)
# Out:
# suhas

# %%
for i in a:
    if type(i)==float:
        print(i)
# Out:
# 35.75
# 6.9

# %%
for i in a:
    if type(i)==float or type(i) ==int:
        print(i)
# Out:
# 1
# 2
# 3
# 35.75
# 6.9

# %%
a
# Out:
# [1, 2, 3, 'suhas', 35.75, 6.9]

# %%
for i in a:
    if type(i)==float:
        print(i+5)
# Out:
# 40.75
# 11.9

# %% [markdown]
# - Truthy & falsy statements

# %% [markdown]
# this statements are called falsy satements
#
# - None
#
# - False
#
# - 0
#
# - 0.0
#
# - " "   empty str
#
# - [ ]  empty list
#
# - ( )  empty tuples
#
# - set()
#
# - { }  empty dict

# %%
if False:
    print("this is very bad")

else:
    print("this is not bad")
# Out:
# this is not bad

# %%
if [ ]:
    print("this is my emptylist")
else:
    print("this is empty list falsy statement")
# Out:
# this is empty list falsy statement
