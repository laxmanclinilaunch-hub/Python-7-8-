# %% [markdown]
# - Sets

# %% [markdown]
# - 1. sets are unordered collection of unique elements

# %%
a=[1,4,2,3,45,1]

print(a)

b=(1,4,2,3,45,1)


print(b)

c={1,4,2,3,45,1}

print(c)
# Out:
# [1, 4, 2, 3, 45, 1]
# (1, 4, 2, 3, 45, 1)
# {1, 2, 3, 4, 45}

# %% [markdown]
# - sets can't have duplicates

# %% [markdown]
# - sets are mutable

# %% [markdown]
# - while construction of the Non-empty sets use { }  curly braces and by separating each element by commas

# %% [markdown]
# # How to create empty str, empty list, empty tuples, empty sets, empty dict

# %%
a=" "

print(f"empty str :{a}")


b=[ ]

print(f" empty list :{b}")

c=()

print(f" empty tuples :{c}")

empty_set= set()

print(f" empty sets :{empty_set}")


d= { }

print(f" empty dict:  {d}")
# Out:
# empty str :
#  empty list :[]
#  empty tuples :()
#  empty sets :set()
#  empty dict:  {}

# %%
non_empty_set={1,6,90,"suhas","swathi"}


non_empty_set
# Out:
# {1, 6, 90, 'suhas', 'swathi'}

# %%
type(non_empty_set)
# Out:
# set

# %%
my_lit=[1,2,3,54, 12,6+8j,True,"Swathi",1,3,54]

print(my_lit)
# Out:
# [1, 2, 3, 54, 12, (6+8j), True, 'Swathi', 1, 3, 54]

# %%
# chaning list to tuples

tuple(my_lit)
# Out:
# (1, 2, 3, 54, 12, (6+8j), True, 'Swathi', 1, 3, 54)

# %%
# chnage the list to sets

set(my_lit)
# Out:
# {(6+8j), 1, 12, 2, 3, 54, 'Swathi'}

# %% [markdown]
# - add method

# %%
my_set=set()

print(my_set)
# Out:
# set()

# %%
my_set.add("shivakumar")

# %%
my_set
# Out:
# {'shivakumar'}

# %%
my_set.add("suman")

# %%
my_set
# Out:
# {'shivakumar', 'suman'}

# %% [markdown]
# - update

# %%
x={143, "sai","sujana"}


x
# Out:
# {143, 'sai', 'sujana'}

# %%
x.update(['shivakumar',"clr",True])

# %%
x
# Out:
# {143, True, 'clr', 'sai', 'shivakumar', 'sujana'}

# %% [markdown]
# - remove

# %%
x
# Out:
# {143, True, 'clr', 'sai', 'shivakumar', 'sujana'}

# %%
x.remove(143)

# %%
x
# Out:
# {True, 'clr', 'sai', 'shivakumar', 'sujana'}

# %%
x.remove(100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 x.remove(100)
#
# KeyError: 100

# %%
x.discard(100)

# %%
x
# Out:
# {True, 'clr', 'sai', 'shivakumar', 'sujana'}

# %% [markdown]
# - Union

# %%
A={4,5,6,7,8}

B={1,2,3,4,5}

# %%
A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
A | B
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# - intersection

# %%
A.intersection(B)
# Out:
# {4, 5}

# %%
A & B
# Out:
# {4, 5}

# %% [markdown]
# - Difference

# %%
A.difference(B)
# Out:
# {6, 7, 8}

# %%
A - B
# Out:
# {6, 7, 8}

# %%
B.difference(A)
# Out:
# {1, 2, 3}

# %%
B-A
# Out:
# {1, 2, 3}
