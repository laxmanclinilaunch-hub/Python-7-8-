# %% [markdown]
# # - Oops:
#    object orinented programming language
#
#    - it based on the concept of classes & object
#
#
#    - the entire program has been divide into small units (objects )  which contains both of data & methods (functions) that operates the data

# %% [markdown]
# - classes:
#  - it is a blueprint  for creating objects(it is blueprint of object)
#  - it has a set of attributes(variable_names) and methods (functions)
#
#
#   - attributes:
#       -  variables that hold data related to the class
#
#   - method:
#      - functions defined within a class that can operate its attributes
#
#
#
#
# - object:
#   - it is an instance of a class

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - without class attribute (variable)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - with class attributes

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class PYTHON:
    sub="oops"     # class attribute(variable)


    def __init__(self,name,age):     # contructor

       # instance attributes( variable)
        self.name=name
        self.age=age                             

    def find_name(self):      # methods
        return self.name

    def find_age(self):          # methods
        return self.age

# %% [markdown]
# - For accessing and modification of instance attributes (variables)  and instance methods (functions) we have to use  object

# %%
obj=PYTHON("SHIVAKUMAR",25)

# %% [markdown]
# - we have to check the values are shivakumar and 25 initalized or not

# %%
obj.age    # we can access instance attribute
# Out:
# 25

# %%
obj.name   # we can access instance attribute
# Out:
# 'SHIVAKUMAR'

# %%
obj.find_name()   # accessing instance method
# Out:
# 'SHIVAKUMAR'

# %%
obj.find_age()    # accessing instance method
# Out:
# 25

# %%
# modification or updating my instance attributes (variables)

obj.name="atual"

# %%
obj.name
# Out:
# 'atual'

# %%
# modification or updating my instance attributes (variables)

obj.age =30

# %%
obj.age
# Out:
# 30

# %%
# to get modified values in instance methods

obj.find_name()
# Out:
# 'atual'

# %%
## to get modified values in instance methods
obj.find_age()
# Out:
# 30

# %% [markdown]
# -   Type of constructors:
#
#     - Non-Parameterized constructor:
#         initalized attributes with **Default values**

# %%
class netflix:
    new_show=29

    def __init__(self):
        self.mail="laxman@gmail.com"
        self.password=000                     # Non - parameterized constructor
        self.service="Free"
        self.amount=0      


    def find_password(self):
        return self.password

# %%
user22=netflix()


user22.find_password()
# Out:
# 0

# %% [markdown]
# - 2.parameterized constructor:
#      - it takes one or more arguments in addition to self, it allows for the initilization of an object  with specific values provided at the time of object creation

# %%
class netflix:
    new_show=31     # Class attribute 

    def __init__(self,mail,password,service,amount):     # parameterized constructor
        self.mail=mail
        self.password=password
        self.service=service
        self.amount=amount

    def profile(self):
        return self.service, self.amount

# %% [markdown]
# - Any attribute (variable) defined before of - ** __ init __** - or above of the - ** __ init __**- thatattribute is called class attribute (variable) and if we were delacre any attribute below of the constructor **__init__**  defined with self is called instance attribute  ( variable)

# %%
class hotstar():
    new_movie="agadha"


    def __init__(self,mail, password,service, amount):
        self.mail=mail
        self.password=password
        self.service=service
        self.amount=amount


    def get_password(self):
        return self.password

# %%
my_account=hotstar("lakshman@gmail.com",1234,"paid",5000)

# %%
my_account.new_movie     # accessing of the class variable using  object
# Out:
# 'agadha'

# %%
my_account.mail     # accessing instance variables
# Out:
# 'lakshman@gmail.com'

# %%
my_account.password
# Out:
# 1234

# %%
my_account.service
# Out:
# 'paid'

# %%
my_account.amount
# Out:
# 5000

# %%
hotstar.new_movie   # accessing class variable using class name
# Out:
# 'agadha'

# %%
my_account.password =5603    # updating my instance variable

# %%
my_account.password
# Out:
# 5603

# %%
my_account.new_movie="makutam"    # updating my class atrribute using object

# %%
my_account.new_movie
# Out:
# 'makutam'

# %%
hotstar.new_movie="kalki-2"    # updating my class atrribute using class name

# %%
hotstar.new_movie
# Out:
# 'kalki-2'

# %% [markdown]
# - understand class & object
#
# -  type of attributes
#     - class attribute
#     - instance attribute
#
# - type of constructor
#    - Non- parameterized
#
#    - parameterized
#
#
# - type of methods
#   - instance method (if you are using instance variables with self)
#   - class method   (if you are using class attributes with cls key word)
#   - static method (Neither used instance variables nor used class attributes and we use staticmethod as keyword )

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - instance method

# %%
class hotstar():
    new_movie="agadha"


    def __init__(self,mail, password,service, amount):
        self.mail=mail
        self.password=password
        self.service=service
        self.amount=amount


    def get_password(self):
        return self.password

# %% [markdown]
# - class method :
#
#    - for writting class method , we have to use decorator **@classmethod** and also we use **cls** parameter which refer to class not instance

# %%
class hotstar1:
    new_show="salar"


    def __init__(self,mail, password):
        self.mail=mail
        self.password=password
        self.service="free"
        self.amount=0


    def get_password(self):
        return self.password


    @classmethod
    def get_show(cls):
        return cls.new_show

    @classmethod
    def set_new_show(cls,show_name):
        cls.new_show=show_name

# %%
hotstar1.new_show     # accessing class variable using class method
# Out:
# 'salar'

# %%
user=hotstar1("laxman@gmail.com",123)

# %%
user.get_show()
# Out:
# 'salar'

# %%
hotstar1.set_new_show("kalki")

                                #modifying of class variable with class method 
hotstar1.get_show()
# Out:
# 'kalki'

# %%
hotstar1.new_show
# Out:
# 'kalki'

# %% [markdown]
# - static method:
#    - this method can access any attribute (variable) (either class attribute or instance attribute)

# %%
class my_math:
    @staticmethod
    def add(x,y):
        return x+y

# %%
my_math.add(5,4)
# Out:
# 9

# %%
class netflex:
    new_show="kalki"


    def __init__(self,mail,password):
        self.mail=mail
        self.password=password
        self.service="Free"
        self.amount=0



    def get_password(self):
        return self.password



    @staticmethod
    def get_new_show():
        return netflex.new_show


    @staticmethod
    def get_mail(instance):
        return instance.mail

# %%
user=netflex("laxman@gmail.com",12345)

# %%
netflex.get_new_show()
# Out:
# 'kalki'

# %%
netflex.get_mail(user)
# Out:
# 'laxman@gmail.com'

# %% [markdown]
# - encapsulation:
#
#       - it hide sensitive data and protect from anotherized access

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - public member:
#    - public members are accessible everywhere
#       - self.name=name
#
#  - protected_member:
#     - this can be access within the class n its subclasses
#        - self._name=name
#
#  - private_member:
#      - this can be access within the class with getter and setter methods
#       - self.__name=name

# %% [markdown]
# - public_member

# %%
class mentor:

    def __init__(self):
        self.name="laxman"



obj=mentor()

print(obj.name)
# Out:
# laxman

# %% [markdown]
# - PROTECTED_MEMBER

# %%
class student:

    def __init__(self):
        self._college="clri"
obj=student()

print(obj._college)
# Out:
# clri

# %%
class father:

    def __init__(self):
        self._salary=60000

class son(father):

    def display(self):
        print(self._salary)   
obj=son()

obj.display()
# Out:
# 60000

# %% [markdown]
# - private member:
#     -

# %%
class bank:

    def __init__(self):
        self.__balance=100000



obj=bank()


print(obj.__balance)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 11
#       7
#       8 obj=bank()
#       9
#      10
# ---> 11 print(obj.__balance)
#
# AttributeError: 'bank' object has no attribute '__balance'

# %% [markdown]
# - Accessing private members using getter  method

# %%
class bank:

    def __init__(self):
        self.__balance=100000



    def get_balance(self):
        return self.__balance
    

obj=bank()


print(obj.get_balance())
# Out:
# 100000

# %% [markdown]
# - modifying of private data using setter method

# %%
class bank:

    def __init__(self):
        self.__balance=100000


    def set_balance(self,amount):
        self.__balance=amount


    def get_balance(self):
        return self.__balance



obj=bank()



obj.set_balance(200000)


print(obj.get_balance())
# Out:
# 200000

# %%
class netflex:

    def __init__(self):
        self.mail="lakshman@gmail.com"      # public
        self._plan="premium"                # protected
        self.__password=1234                 #private



    def get_password(self):
        return self.__password

    def set_password(self,new_password):
        self.__password=new_password

user=netflex()

#public
print(user.mail)

#protected

print(user._plan)

# private( try to acces but you will get)
# print(user.__password)
print(user.get_password())

user.set_password(5630)

print(user.get_password())
# Out:
# lakshman@gmail.com
# premium
# 1234
# 5630

# %% [markdown]
# - Health care example

# %%
class patient:


    def __init__(self):
        self.name="laxman"        # public
        self._bloodgroup = "B+"   # PROTECTED 
        self.__medical_report="Cancer"    # private


    def get_report(self):
        return self.__medical_report

pat=patient()


print(pat.name)

print(pat._bloodgroup)


print(pat.get_report())
# Out:
# laxman
# B+
# Cancer

# %% [markdown]
# - Abstraction
#
# - it is the process of hiding the internal implementation details and exposing only the essential functionality to the user
#
# - generally for impplementation of this using ABC and @abstractmethod

# %%
from abc import ABC, abstractmethod

#abstract class
class atm(ABC):


    @abstractmethod
    def withdraw(self):
        pass


#child class
class sbiatm(atm):

    def __init__(self,balance):
        self.balance=balance



    def withdraw(self):
        pin=int(input("enter pin :"))

        amount=int(input("enter the amount"))


        if pin==1234:
            if amount<=self.balance:
                self.balance-=amount
                print("transcation successful")
                print("please collect your cash") 
                print("available balance:", self.balance)

            else:
                print("insuffieent balance")
        else:
            print("invalidpin")
                   



# object
obj=sbiatm(100000)

obj.withdraw()
# Out:
# transcation successful
# please collect your cash
# available balance: 76632

# %%
from abc import ABC, abstractmethod



class hospital(ABC):

    @abstractmethod
    def treatment(self):
        pass


class cardio(hospital):
    def treatment(self):
        print("treating heart related diseases")


class neuro(hospital):
    def treatment(self):
        print("treament related brain & nervous diseases")



obj_1=cardio() 


obj_1.treatment()
# Out:
# treating heart related diseases

# %%
obj2=neuro()

obj2.treatment()
# Out:
# treament related brain & nervous diseases

# %% [markdown]
# - polymoriphsim:
#   - it is the ability of an object to take  many forms
#
#
#   example
#     -  the single person work as different roles
#
#
#     ![image.png](attachment:image.png)

# %%
class dog:

    def sound(self):
        print("dogs barks: Bow bow")

class cat:
    def sound(self):
        print("cats meows: Meow meow")

class cow:
     def sound(self):
        print("cow moos: Moo moo")

    

obj=dog()

obj1=cat()


obj2=cow()



obj.sound()
obj1.sound()

obj2.sound()
# Out:
# dogs barks: Bow bow
# cats meows: Meow meow
# cow moos: Moo moo

# %% [markdown]
# # inheritance :
#
#    - it acquring the properties from parents class(Base class) to child class ( derived class)
#
#   -  what is properties?
#      - behaviour from one class to anothers i.e  means it's attributes ( variables)  and methods ( functions)

# %% [markdown]
# - Type of inheritance

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - single inheritance

# %% [markdown]
# one base class and one derived class , here transfer the properties parent class to child class
#
# ![image.png](attachment:image.png)

# %%
class person():


    def __init__(self,name ,idnumber):
        self.name =name
        self.idnumber=idnumber

    def display(self):
        print(self.name)
        print(self.idnumber)


    def details(self):
        print("my name is ",self.name)
        print("my id number is ",self.idnumber)



class employee(person):

    def __init__(self, name, idnumber,salary, post):
        self.salary=salary
        self.post=post


        person.__init__(self, name,idnumber) 

          #     or

        #super().__init__(self,name, idnumber)
          

    def details1(self):
        print("my name is ",self.name)
        print("my id number is ",self.idnumber)
        print("post",self.post)




# creating obj

obj= employee("suhas",6987860,60000,"dentist")


        

obj.details()
print() 


obj.details1()
# Out:
# my name is  suhas
# my id number is  6987860
#
# my name is  suhas
# my id number is  6987860
# post dentist

# %% [markdown]
# - multiple inheritance:
#
#
#
#     ![image.png](attachment:image.png)

# %%
class father():
    def __init__(self,id):
        self.id=id


    def details(self):
        print("this is my id number",self.id)




class mother():
    def __init__(self,name):
        self.name=name

    def show(self):
        print("this is my name ",self.name)



class child(father,mother):
    def __init__(self, id,name,salary):
        father.__init__(self,id)
        mother.__init__(self,name)
        self.salary=salary


    def employee_details(self):
        print("this is my id number",self.id)
        print("this is my name ",self.name)
        print("this is my salary",self.salary)



# creating obj

obj=child(222,"suhas",75000)


obj.employee_details()

print()

obj.details()

print()

obj.show()
# Out:
# this is my id number 222
# this is my name  suhas
# this is my salary 75000
#
# this is my id number 222
#
# this is my name  suhas

# %% [markdown]
# - Multilevel inheritane:
#   - ![image.png](attachment:image.png)

# %%
class Grandparent:

    def __init__(self,grandparent_name):
        self.grandparent_name =grandparent_name


    def display_grandparent(self):
        print("grand parent:",self.grandparent_name)



class parent(Grandparent):

    def __init__(self, grandparent_name,parent_name):
        super().__init__(grandparent_name)
        self.parent_name=parent_name


    def display_parent(self):
        print("parent:",self.parent_name)




class child(parent):

    def __init__(self, grandparent_name, parent_name,child_name):
        super().__init__(grandparent_name, parent_name) 
        self.child_name=child_name



    def display_child(self):
        print("child:",self.child_name)


# creating obj

obj=child("ram","rahim","akbar") 



# calling all methods with obj

obj.display_grandparent()

obj.display_parent()

obj.display_child()
# Out:
# grand parent: ram
# parent: rahim
# child: akbar

# %% [markdown]
# - Hierarchical inheritance:
#   -  in hierarchical inheritance ,it has one parents has two or more childs that is called Hierarchical inheritance
#
#
#
#   ![image.png](attachment:image.png)

# %%
class parent():

    def __init__(self,id):
        self.id=id

    def details(self):
        print("this is my id number :" ,self.id)



class child1(parent):

    def __init__(self, id,name):
        super().__init__(id)
        self.name=name

    def employee_details(self):
        print("this is id number:",self.id)
        print("this is name:",self.name)


class child2(parent):

    def __init__(self, id,salary):
        super().__init__(id)
        self.salary=salary


    def employee_details1(self):
        print("this is id number :",self.id)
        print(" this is salary:",self.salary)


# creating obj for child1

obj=child1(222,"ravi")

obj.employee_details()

print()
# creating obj for child 2

obj1=child2(2223,70000)

obj1.employee_details1()
# Out:
# this is id number: 222
# this is name: ravi
#
# this is id number : 2223
#  this is salary: 70000

# %% [markdown]
# - Hybrid inheritance:
#
#   - Hybrid inheritance in Python is a combination of two or more types of inheritance,
#
#   - such as combining hierarchical inheritance with multiple inheritance
#
#   -  This structure often forms what is known as the "diamond problem"
#
#
#   ![image.png](attachment:image.png)

# %%
class school:
    def fun1(self):
        print("this function is in school")



class student1(school):
    def fun2(self):
        print("this  function for student 1")


class student2(school):
    def fun3(self):
        print(" this function for student 2")

class student3(student1, school):
    def fun4(self):
        print("this function for student 3") 

# creating obj

obj=student3()


obj.fun1()

obj.fun2()

obj.fun4()
# Out:
# this function is in school
# this  function for student 1
# this function for student 3
