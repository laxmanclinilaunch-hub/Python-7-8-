# %%
5
# Out:
# 5

# %%
b=5

print(b)
# Out:
# 5

# %%
_b=6

print(_b)
# Out:
# 6

# %% [markdown]
# 2.

# %%
v_7=7
print(v_7)
# Out:
# 7

# %%
_v7=9

print(_v7)
# Out:
# 9

# %% [markdown]
# 3.

# %%
7v_=0
# Out:
#   Cell In[10], line 1
#     7v_=0
#     ^
# SyntaxError: invalid decimal literal

# %%
7_b=89
# Out:
#   Cell In[11], line 1
#     7_b=89
#      ^
# SyntaxError: invalid decimal literal

# %%
bd=143

print(BD)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 bd=143
#       2
# ----> 3 print(BD)
#
# NameError: name 'BD' is not defined

# %%
BE=145

print(be)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 BE=145
#       2
# ----> 3 print(be)
#
# NameError: name 'be' is not defined

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
True=6

print(True)
# Out:
#   Cell In[16], line 1
#     True=6
#     ^
# SyntaxError: cannot assign to True

# %%
true=6
print(true)
# Out:
# 6

# %% [markdown]
# - Arthmetic operators

# %%
2+5
# Out:
# 7

# %%
5+245
# Out:
# 250

# %%
5-4
# Out:
# 1

# %%
198-190
# Out:
# 8

# %%
2*3
# Out:
# 6

# %% [markdown]
# - Divsion

# %%
3/2       # in the division operator, the result will be in float type
# Out:
# 1.5

# %%
25/5
# Out:
# 5.0

# %%
# floor division operator, the result will be in int type

3//2
# Out:
# 1

# %%
print(7/2)

print(7//2)
# Out:
# 3.5
# 3

# %%
print("divison",3/2)
print("floor division",3//2)

print("divison",3/4)
print("floor division",3//4)


print("divison",4/5)
print("floor division",4//5)
# Out:
# divison 1.5
# floor division 1
# divison 0.75
# floor division 0
# divison 0.8
# floor division 0

# %%
# modulus operator, the result will be in int type

y=5

x=3

z=y%x

print("modulus",z)
# Out:
# modulus 2

# %%
# exponent operator, the result will be in int type

2**3
# Out:
# 8

# %%
2**4
# Out:
# 16

# %% [markdown]
# - Comparsion operator

# %%
abc=True

a_bc=1


print(abc)

print(a_bc)

print("i'm telling here both are equal ",abc==a_bc)

print("i'm telling here both  ",abc>a_bc)

print("i'm telling here both  ",abc<a_bc)

print("i'm telling here both are  ",abc==a_bc)

print("i'm telling here both are  ",abc!=a_bc)

print("i'm telling here both are  ",abc>=a_bc)

print("i'm telling here both are  ",abc<=a_bc)
# Out:
# True
# 1
# i'm telling here both are equal  True
# i'm telling here both   False
# i'm telling here both   False
# i'm telling here both are   True
# i'm telling here both are   False
# i'm telling here both are   True
# i'm telling here both are   True

# %%
a=1

b=True

c=False

d=0

e=2


print(a==c)

print(a==b)

print(a==d)

print(a==e)

print(a!=c)

print(a!=b)

print(a!=d)

print(a!=e)

print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(b==c)
print(b!=c)

print(  e>d or e>c or e>b or e<a)
# Out:
# False
# True
# False
# False
# True
# False
# True
# True
# False
# False
# True
# True
# False
# True
# True

# %% [markdown]
# - logical operator

# %%
x=90

print(x)
# Out:
# 90

# %% [markdown]
# - and

# %% [markdown]
# **True and True = True**

# %%
x<900 and x<80      #  true and  false = false
# Out:
# False

# %%
x>9 and x<80    #  true and false = false
# Out:
# False

# %% [markdown]
# **or**

# %%
x=50

# %%
x>6 or x>10  #  true or false = true
# Out:
# True

# %%
x<6 or x<10  #  false or false = false
# Out:
# False

# %% [markdown]
# **not**

# %%
not(x>6 or x>10 )
# Out:
# False

# %%
not(x<6 or x<10 )
# Out:
# True

# %% [markdown]
# - Membership operator

# %%
x=[3,4,5,7,4,8, 145, "raise", "hello", "world", 5.6, 7.8, 9.0,4+6j,9]

print("ravi" in x )


print("hello" in x )


print("hello" not in x )
# Out:
# False
# True
# False
