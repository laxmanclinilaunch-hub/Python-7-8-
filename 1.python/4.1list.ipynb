# %% [markdown]
# - list are constructed with [ ] brackets , each item/ element separated by commas

# %%
a=["6",7, "ravi", "clr", True, False, 3+6j,0.5]


print(a)
# Out:
# ['6', 7, 'ravi', 'clr', True, False, (3+6j), 0.5]

# %% [markdown]
# - indexing ----> +ve , -ve

# %%
# i want to grab the first element which has index 0


a[0]
# Out:
# '6'

# %%
# grab the 3rd element from the  give  list 
a[2]
# Out:
# 'ravi'

# %%
a[-3]
# Out:
# False

# %%
a[-4]
# Out:
# True

# %%
b= ["accuracy", "precision", "recall", "f1score","auc_roc_score"]

b
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
# grab the 3rd element

b[2]
# Out:
# 'recall'

# %%
# grab the f1score

b[3]
# Out:
# 'f1score'

# %%
# grab the "pre" in precison


b[1][0:3]
# Out:
# 'pre'

# %%
type(b)
# Out:
# list

# %%
type(b[1][0:3])
# Out:
# str

# %%
c= ["accuracy", "precision", "recall", "f1score","auc_roc_score"]

c
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
c[:]
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
c[0:]
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
c[:5]
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
c[0:3]
# Out:
# ['accuracy', 'precision', 'recall']

# %%
c[::]
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
c[::1]
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
c[::-1]
# Out:
# ['auc_roc_score', 'f1score', 'recall', 'precision', 'accuracy']

# %%
c[0:5:2]
# Out:
# ['accuracy', 'recall', 'auc_roc_score']

# %%
c[0:5:-2]
# Out:
# []

# %%
c
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
c[-5:]
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
c[-5::+2]
# Out:
# ['accuracy', 'recall', 'auc_roc_score']

# %% [markdown]
# - reverse of string

# %%
a='python'

print(a)
print(c)
# Out:
# python
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
a[::-1]
# Out:
# 'nohtyp'

# %%
c[::-1]
# Out:
# ['auc_roc_score', 'f1score', 'recall', 'precision', 'accuracy']

# %%
metrics= ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
metrics
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %% [markdown]
# - string concatenate

# %%
z="ravi"

z
# Out:
# 'ravi'

# %%
z+"clr"
# Out:
# 'raviclr'

# %% [markdown]
# - list concatenatation

# %%
metrics+['clr']
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score', 'clr']

# %%
metrics
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
# we have to resign
metrics= metrics+['clr']

metrics
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score', 'clr', 'clr']

# %% [markdown]
# - append

# %%
metrics
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score', 'clr', 'clr']

# %%
metrics.append("clr22")

# %%
metrics
# Out:
# ['accuracy',
#  'precision',
#  'recall',
#  'f1score',
#  'auc_roc_score',
#  'clr',
#  'clr',
#  'clr22']

# %%
metrics.append([2,4,2,67])

# %%
metrics
# Out:
# ['accuracy',
#  'precision',
#  'recall',
#  'f1score',
#  'auc_roc_score',
#  'clr',
#  'clr',
#  'clr22',
#  [2, 4, 2, 67]]

# %% [markdown]
# - extend

# %%
metrics.extend(['clr23',45,5+6j])

# %%
metrics
# Out:
# ['accuracy',
#  'precision',
#  'recall',
#  'f1score',
#  'auc_roc_score',
#  'clr',
#  'clr',
#  'clr22',
#  [2, 4, 2, 67],
#  'clr23',
#  45,
#  (5+6j)]

# %% [markdown]
# - insert method

# %%
metrics= ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
metrics.insert(1,'insert')

# %%
metrics
# Out:
# ['accuracy', 'insert', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %% [markdown]
# - i want to CLR in 3rd index postion

# %%
metrics.insert(3,"clr")

# %%
metrics
# Out:
# ['accuracy',
#  'insert',
#  'precision',
#  'clr',
#  'recall',
#  'f1score',
#  'auc_roc_score']

# %% [markdown]
# - pop
#
# use pop() to "popoff" an item from the list
#
#
# by default it removes at the end of the list

# %%
metrics
# Out:
# ['accuracy',
#  'insert',
#  'precision',
#  'clr',
#  'recall',
#  'f1score',
#  'auc_roc_score']

# %%
metrics.pop()
# Out:
# 'auc_roc_score'

# %%
metrics
# Out:
# ['accuracy', 'insert', 'precision', 'clr', 'recall', 'f1score']

# %%
metrics.pop()
# Out:
# 'f1score'

# %%
metrics
# Out:
# ['accuracy', 'insert', 'precision', 'clr', 'recall']

# %%
metrics= ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
metrics
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
metrics.pop(2)
# Out:
# 'recall'

# %%
metrics
# Out:
# ['accuracy', 'precision', 'f1score', 'auc_roc_score']

# %%
metrics.pop(-1)
# Out:
# 'auc_roc_score'

# %%
metrics
# Out:
# ['accuracy', 'precision', 'f1score']

# %% [markdown]
# - remove

# %%
metrics= ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
metrics
# Out:
# ['accuracy', 'precision', 'recall', 'f1score', 'auc_roc_score']

# %%
metrics.remove("f1score")

# %%
metrics
# Out:
# ['accuracy', 'precision', 'recall', 'auc_roc_score']

# %% [markdown]
# - if you repearted values in the list , then the remove method remove first occurance of the

# %%
a= [1,2,1,2,34,5,3]


a.remove(1)

# %%
a
# Out:
# [2, 1, 2, 34, 5, 3]

# %%
a.remove(2)

# %%
a
# Out:
# [1, 2, 34, 5, 3]

# %%
my_list=[1,"r",3,4,5]


del my_list[2]

my_list
# Out:
# [1, 'r', 4, 5]

# %%
my_list=[1,"r",3,4,5]

del my_list


print(my_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 6
#       2
#       3 del my_list
#       4
#       5
# ----> 6 print(my_list)
#
# NameError: name 'my_list' is not defined

# %%
my_list=[1,"r",3,4,5]



my_list.clear()


print(my_list)
# Out:
# []

# %% [markdown]
# - count

# %%
a= [1,2,2,3,1,12,34,34,2]


a.count(1)
# Out:
# 2

# %%
a.count(2)
# Out:
# 3

# %% [markdown]
# - index

# %%
a= [1,2,2,3,1,12,34,34,2]



a.index(1)
# Out:
# 0

# %% [markdown]
# - sort

# %%
a= [1,2,2,3,1,12,34,34,2]


a.sort()

print(a)
# Out:
# [1, 1, 2, 2, 2, 3, 12, 34, 34]

# %%
a.sort(reverse= True)

a
# Out:
# [34, 34, 12, 3, 2, 2, 2, 1, 1]

# %% [markdown]
# - min / max / sum

# %%
a
# Out:
# [1, 1, 2, 2, 2, 3, 12, 34, 34]

# %%
min(a)
# Out:
# 1

# %%
max(a)
# Out:
# 34

# %%
sum(a)
# Out:
# 91
