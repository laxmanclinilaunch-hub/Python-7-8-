# %% [markdown]
# - tuples

# %% [markdown]
# the constriction of the tuples use () , and each  elements  separated by commas

# %%
ab=(1,5,"ravi",True, False , 7.8)


ab
# Out:
# (1, 5, 'ravi', True, False, 7.8)

# %%
type(ab)
# Out:
# tuple

# %% [markdown]
# - the () , is it mandatory for representing tuples ?

# %%
my_tuple=1,2,4


print(my_tuple)
# Out:
# (1, 2, 4)

# %%
type(my_tuple)
# Out:
# tuple

# %% [markdown]
# - indexing +ve , -ve

# %%
ab=(1,5,"ravi",True, False , 7.8)

# %%
# want to grab the first element 

ab[0]
# Out:
# 1

# %%
# grab the last element


print(ab[5])


print(ab[-1])
# Out:
# 7.8
# 7.8

# %%
# grab  the 3rd element 

ab[2]
# Out:
# 'ravi'

# %% [markdown]
# - slicing

# %%
abc = 1,2,3,9,145,10.5,"aditya","swathi","sujana"

abc
# Out:
# (1, 2, 3, 9, 145, 10.5, 'aditya', 'swathi', 'sujana')

# %%
abc[ : ]
# Out:
# (1, 2, 3, 9, 145, 10.5, 'aditya', 'swathi', 'sujana')

# %%
abc[0:]
# Out:
# (1, 2, 3, 9, 145, 10.5, 'aditya', 'swathi', 'sujana')

# %%
abc[:9]
# Out:
# (1, 2, 3, 9, 145, 10.5, 'aditya', 'swathi', 'sujana')

# %%
abc[:-6]
# Out:
# (1, 2, 3)

# %%
abc[-8:-6]
# Out:
# (2, 3)

# %%
abc[::]
# Out:
# (1, 2, 3, 9, 145, 10.5, 'aditya', 'swathi', 'sujana')

# %%
abc[::1]
# Out:
# (1, 2, 3, 9, 145, 10.5, 'aditya', 'swathi', 'sujana')

# %%
abc[0::1]
# Out:
# (1, 2, 3, 9, 145, 10.5, 'aditya', 'swathi', 'sujana')

# %%
abc[::3]
# Out:
# (1, 9, 'aditya')

# %%
abc[-9::]
# Out:
# (1, 2, 3, 9, 145, 10.5, 'aditya', 'swathi', 'sujana')

# %%
abc[-9:-2:]
# Out:
# (1, 2, 3, 9, 145, 10.5, 'aditya')

# %%
abc[-9:-2:1]
# Out:
# (1, 2, 3, 9, 145, 10.5, 'aditya')

# %%
abc[-9:-2:-1]
# Out:
# ()

# %% [markdown]
#  - is tuple mutiable or immutable  ?
#
#
# -  ans : immutable

# %% [markdown]
# - Methods

# %% [markdown]
# - index

# %%
abc
# Out:
# (1, 2, 3, 9, 145, 10.5, 'aditya', 'swathi', 'sujana')

# %%
abc.index(10.5)
# Out:
# 5

# %% [markdown]
# - count

# %%
abc.count('swathi')
# Out:
# 1

# %%
b=(1,2,2,3,312,13,1,2,12)

b[0]
# Out:
# 1

# %%
b[0]="swathi"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 b[0]="swathi"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# - Zip

# %%
city_list=["Delhi","patna","cuttack","guwathati"]


river_list=["yamuna","ganga","mahanadi","brahmaputra"]

# %%
c=zip(city_list,river_list)    #save the  memory

# %%
list(c)
# Out:
# [('Delhi', 'yamuna'),
#  ('patna', 'ganga'),
#  ('cuttack', 'mahanadi'),
#  ('guwathati', 'brahmaputra')]

# %% [markdown]
# - when to use
#
# where ever needs immutable nature , you have to apply tuple
