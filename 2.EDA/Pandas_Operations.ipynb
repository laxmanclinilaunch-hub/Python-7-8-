# %% [markdown]
# ## **Yesterday, we learnt a little about the very useful library Pandas widely used for Data Analysis. It is time to put the many utilities of this library in front of our eyes. We will be performing following manipulations and exploration of our data:**
#
# * ### Indexing and slicing operations
# * ### Manipulating columns
# * ### Exploring unique and missing values

# %%
# Import pandas package
import pandas as pd
import numpy as np

# %% [markdown]
# ## Let us read our data first

# %% [markdown]
# ### <u>Loading a CSV (Comma-Separated Values) file</u>

# %%
# loading csv File

df=pd.read_csv(r"C:\Users\LakshmanAIMLHYD\Desktop\AI&ML(7-8)\2.EDA\imdb_pandas_practice_dataset.csv")

df.head()
# Out:
#    id                     belongs_to_collection    budget  \
# 0   1                    Hot Tub Time Machine 2  14000000
# 1   2  The Princess Diaries 2: Royal Engagement  40000000
# 2   3                                  Whiplash   3300000
# 3   4                                   Kahaani   1200000
# 4   5                                Marine Boy         0
#
#                                        genres  \
# 0                        [{"name": "Comedy"}]
# 1     [{"name": "Comedy"}, {"name": "Drama"}]
# 2                         [{"name": "Drama"}]
# 3   [{"name": "Thriller"}, {"name": "Drama"}]
# 4  [{"name": "Action"}, {"name": "Thriller"}]
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  ...  \
# 0                                Time travel comedy.    6.575393  ...
# 1                  A princess prepares for marriage.    8.248895  ...
# 2       A young drummer faces a ruthless instructor.   64.299990  ...
# 3  A woman searches for her missing husband in Ko...    3.174936  ...
# 4        A former swimmer becomes involved in crime.    1.148070  ...
#
#   release_date runtime             spoken_languages    status  \
# 0      2/20/15    93.0        [{"name": "English"}]  Released
# 1       8/6/04   113.0        [{"name": "English"}]  Released
# 2     10/10/14   105.0        [{"name": "English"}]  Released
# 3       3/9/12   122.0  [{"name": "English|Hindi"}]  Released
# 4       2/5/09   118.0         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                                              NaN
# 4                                              NaN
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy               NaN
#
#                           cast  \
# 0    [{"name": "Rob Corddry"}]
# 1  [{"name": "Anne Hathaway"}]
# 2   [{"name": "Miles Teller"}]
# 3    [{"name": "Vidya Balan"}]
# 4   [{"name": "Kim Kang-woo"}]
#
#                                                crew   revenue
# 0       [{"name": "Steve Pink", "job": "Director"}]  12314651
# 1   [{"name": "Garry Marshall", "job": "Director"}]  95149435
# 2  [{"name": "Damien Chazelle", "job": "Director"}]  13092000
# 3      [{"name": "Sujoy Ghosh", "job": "Director"}]  16000000
# 4   [{"name": "Yoon Jong-chan", "job": "Director"}]   3923970
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='str')

# %%
df.shape
# Out:
# (30, 23)

# %%
df.tail()
# Out:
#     id        belongs_to_collection     budget  \
# 25  26                          RRR  550000000
# 26  27   Bahubali 2: The Conclusion  250000000
# 27  28                        Joker   55000000
# 28  29                   La La Land   30000000
# 29  30  Dilwale Dulhania Le Jayenge   40000000
#
#                                                genres homepage    imdb_id  \
# 25            [{"name": "Action"}, {"name": "Drama"}]      NaN  tt8178634
# 26            [{"name": "Action"}, {"name": "Drama"}]      NaN  tt4849438
# 27             [{"name": "Crime"}, {"name": "Drama"}]      NaN  tt7286456
# 28  [{"name": "Comedy"}, {"name": "Drama"}, {"name...      NaN  tt3783958
# 29           [{"name": "Drama"}, {"name": "Romance"}]      NaN  tt0112870
#
#    original_language               original_title  \
# 25                te                          RRR
# 26                te  Baahubali 2: The Conclusion
# 27                en                        Joker
# 28                en                   La La Land
# 29                hi  Dilwale Dulhania Le Jayenge
#
#                                              overview  popularity  ...  \
# 25   Two revolutionaries form an unlikely friendship.        60.3  ...
# 26               A kingdom seeks answers and revenge.        52.9  ...
# 27             A failed comedian descends into chaos.        70.9  ...
# 28  A musician and actress pursue dreams in Los An...        35.8  ...
# 29     A young couple challenges family expectations.        20.6  ...
#
#    release_date runtime       spoken_languages    status  \
# 25      3/25/22   187.0   [{"name": "Telugu"}]  Released
# 26      4/28/17   168.0   [{"name": "Telugu"}]  Released
# 27      10/4/19   122.0  [{"name": "English"}]  Released
# 28     12/25/16   128.0  [{"name": "English"}]  Released
# 29     10/20/95   181.0    [{"name": "Hindi"}]  Released
#
#                              tagline                        title  \
# 25               Rise. Roar. Revolt.                          RRR
# 26  Why did Kattappa kill Baahubali?  Baahubali 2: The Conclusion
# 27              Put on a happy face.                        Joker
# 28    Here's to the fools who dream.                   La La Land
# 29             Come... Fall in love.  Dilwale Dulhania Le Jayenge
#
#                  Keywords                              cast  \
# 25  friendship|revolution  [{"name": "N. T. Rama Rao Jr."}]
# 26            kingdom|war             [{"name": "Prabhas"}]
# 27            joker|crime     [{"name": "Joaquin Phoenix"}]
# 28      music|los angeles        [{"name": "Ryan Gosling"}]
# 29         romance|family      [{"name": "Shah Rukh Khan"}]
#
#                                                 crew     revenue
# 25  [{"name": "S. S. Rajamouli", "job": "Director"}]  1200000000
# 26  [{"name": "S. S. Rajamouli", "job": "Director"}]  1810000000
# 27    [{"name": "Todd Phillips", "job": "Director"}]  1074251311
# 28  [{"name": "Damien Chazelle", "job": "Director"}]   472000000
# 29    [{"name": "Aditya Chopra", "job": "Director"}]   120000000
#
# [5 rows x 23 columns]

# %%
df.production_countries.value_counts()
# Out:
# production_countries
# [{"iso_3166_1": "US"}]    18
# [{"iso_3166_1": "IN"}]     8
# [{"iso_3166_1": "KR"}]     2
# [{"iso_3166_1": "SE"}]     1
# [{"iso_3166_1": "JP"}]     1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     30 non-null     int64
#  1   belongs_to_collection  30 non-null     str
#  2   budget                 30 non-null     int64
#  3   genres                 29 non-null     str
#  4   homepage               9 non-null      str
#  5   imdb_id                30 non-null     str
#  6   original_language      30 non-null     str
#  7   original_title         30 non-null     str
#  8   overview               30 non-null     str
#  9   popularity             30 non-null     float64
#  10  poster_path            29 non-null     str
#  11  production_companies   27 non-null     str
#  12  production_countries   30 non-null     str
#  13  release_date           30 non-null     str
#  14  runtime                29 non-null     float64
#  15  spoken_languages       30 non-null     str
#  16  status                 30 non-null     str
#  17  tagline                25 non-null     str
#  18  title                  30 non-null     str
#  19  Keywords               29 non-null     str
#  20  cast                   30 non-null     str
#  21  crew                   30 non-null     str
#  22  revenue                30 non-null     int64
# dtypes: float64(2), int64(3), str(18)
# memory usage: 5.5 KB

# %% [markdown]
# # **Data set info / data insights**
#
# - genres    has 1 null value
#
# - homepage has 21 null values
#
# - imdb_id  has datatype wrong
#
# - poster_path  has one missing value
#
# - release_date has wrong type of data
#
# - runtime  has one null value
#
# - tagline has 5 null values
#
# - Keywords has one null value

# %% [markdown]
# # <u>**<code>describe()</code>**</u>
#
# ## This method gives the overall descriptive summary of the dataframe. This works only for numerical columns

# %%
df.describe().T
# Out:
#             count          mean           std      min           25%  \
# id           30.0  1.550000e+01  8.803408e+00  1.00000  8.250000e+00
# budget       30.0  1.009633e+08  1.492895e+08  0.00000  1.205000e+07
# popularity   30.0  3.904264e+01  3.146144e+01  1.14807  1.100908e+01
# runtime      29.0  1.326207e+02  4.006371e+01  0.00000  1.060000e+02
# revenue      30.0  5.554160e+08  7.579332e+08  0.00000  2.325000e+07
#
#                      50%           75%           max
# id          1.550000e+01  2.275000e+01  3.000000e+01
# budget      4.000000e+07  1.400000e+08  5.500000e+08
# popularity  3.035000e+01  6.925000e+01  9.530000e+01
# runtime     1.280000e+02  1.680000e+02  1.940000e+02
# revenue     2.347086e+08  8.046823e+08  2.797501e+09

# %%
df.describe(include="object").T
# Out:
# C:\Users\LakshmanAIMLHYD\AppData\Local\Temp\ipykernel_22452\1274302342.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object").T
#                       count unique  \
# belongs_to_collection    30     30
# genres                   29     20
# homepage                  9      9
# imdb_id                  30     30
# original_language        30      7
# original_title           30     30
# overview                 30     30
# poster_path              29     29
# production_companies     27     21
# production_countries     30      5
# release_date             30     30
# spoken_languages         30      8
# status                   30      2
# tagline                  25     25
# title                    30     30
# Keywords                 29     29
# cast                     30     27
# crew                     30     26
#
#                                                                      top freq
# belongs_to_collection                             Hot Tub Time Machine 2    1
# genres                           [{"name": "Comedy"}, {"name": "Drama"}]    4
# homepage                               http://sonyclassics.com/whiplash/    1
# imdb_id                                                        tt2637294    1
# original_language                                                     en   18
# original_title                                    Hot Tub Time Machine 2    1
# overview                                             Time travel comedy.    1
# poster_path                                                 /poster1.jpg    1
# production_companies                    [{"name": "Paramount Pictures"}]    4
# production_countries                              [{"iso_3166_1": "US"}]   18
# release_date                                                     2/20/15    1
# spoken_languages                                   [{"name": "English"}]   18
# status                                                          Released   29
# tagline                                       The Laws of Space and Time    1
# title                                             Hot Tub Time Machine 2    1
# Keywords                                                     time travel    1
# cast                                            [{"name": "Aamir Khan"}]    3
# crew                   [{"name": "Christopher Nolan", "job": "Directo...    3

# %% [markdown]
# - column names

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='str')

# %% [markdown]
# - check the duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#df.drop_duplicates()    # if duplicate exist we have to remove with this function

# %% [markdown]
# - check  Null values

# %%
df.isnull()
# Out:
#        id  belongs_to_collection  budget  genres  homepage  imdb_id  \
# 0   False                  False   False   False      True    False
# 1   False                  False   False   False      True    False
# 2   False                  False   False   False     False    False
# 3   False                  False   False   False     False    False
# 4   False                  False   False   False      True    False
# 5   False                  False   False   False     False    False
# 6   False                  False   False   False      True    False
# 7   False                  False   False   False     False    False
# 8   False                  False   False   False      True    False
# 9   False                  False   False   False     False    False
# 10  False                  False   False   False      True    False
# 11  False                  False   False   False      True    False
# 12  False                  False   False   False      True    False
# 13  False                  False   False   False      True    False
# 14  False                  False   False   False     False    False
# 15  False                  False   False   False     False    False
# 16  False                  False   False   False      True    False
# 17  False                  False   False   False      True    False
# 18  False                  False   False   False      True    False
# 19  False                  False   False   False      True    False
# 20  False                  False   False   False     False    False
# 21  False                  False   False   False      True    False
# 22  False                  False   False   False      True    False
# 23  False                  False   False    True      True    False
# 24  False                  False   False   False     False    False
# 25  False                  False   False   False      True    False
# 26  False                  False   False   False      True    False
# 27  False                  False   False   False      True    False
# 28  False                  False   False   False      True    False
# 29  False                  False   False   False      True    False
#
#     original_language  original_title  overview  popularity  ...  \
# 0               False           False     False       False  ...
# 1               False           False     False       False  ...
# 2               False           False     False       False  ...
# 3               False           False     False       False  ...
# 4               False           False     False       False  ...
# 5               False           False     False       False  ...
# 6               False           False     False       False  ...
# 7               False           False     False       False  ...
# 8               False           False     False       False  ...
# 9               False           False     False       False  ...
# 10              False           False     False       False  ...
# 11              False           False     False       False  ...
# 12              False           False     False       False  ...
# 13              False           False     False       False  ...
# 14              False           False     False       False  ...
# 15              False           False     False       False  ...
# 16              False           False     False       False  ...
# 17              False           False     False       False  ...
# 18              False           False     False       False  ...
# 19              False           False     False       False  ...
# 20              False           False     False       False  ...
# 21              False           False     False       False  ...
# 22              False           False     False       False  ...
# 23              False           False     False       False  ...
# 24              False           False     False       False  ...
# 25              False           False     False       False  ...
# 26              False           False     False       False  ...
# 27              False           False     False       False  ...
# 28              False           False     False       False  ...
# 29              False           False     False       False  ...
#
#     release_date  runtime  spoken_languages  status  tagline  title  Keywords  \
# 0          False    False             False   False    False  False     False
# 1          False    False             False   False    False  False     False
# 2          False    False             False   False    False  False     False
# 3          False    False             False   False     True  False     False
# 4          False    False             False   False     True  False      True
# 5          False    False             False   False    False  False     False
# 6          False    False             False   False    False  False     False
# 7          False    False             False   False    False  False     False
# 8          False    False             False   False    False  False     False
# 9          False    False             False   False    False  False     False
# 10         False    False             False   False    False  False     False
# 11         False    False             False   False    False  False     False
# 12         False    False             False   False     True  False     False
# 13         False    False             False   False    False  False     False
# 14         False    False             False   False    False  False     False
# 15         False    False             False   False    False  False     False
# 16         False    False             False   False    False  False     False
# 17         False    False             False   False    False  False     False
# 18         False    False             False   False    False  False     False
# 19         False    False             False   False    False  False     False
# 20         False    False             False   False    False  False     False
# 21         False    False             False   False    False  False     False
# 22         False    False             False   False     True  False     False
# 23         False     True             False   False     True  False     False
# 24         False    False             False   False    False  False     False
# 25         False    False             False   False    False  False     False
# 26         False    False             False   False    False  False     False
# 27         False    False             False   False    False  False     False
# 28         False    False             False   False    False  False     False
# 29         False    False             False   False    False  False     False
#
#      cast   crew  revenue
# 0   False  False    False
# 1   False  False    False
# 2   False  False    False
# 3   False  False    False
# 4   False  False    False
# 5   False  False    False
# 6   False  False    False
# 7   False  False    False
# 8   False  False    False
# 9   False  False    False
# 10  False  False    False
# 11  False  False    False
# 12  False  False    False
# 13  False  False    False
# 14  False  False    False
# 15  False  False    False
# 16  False  False    False
# 17  False  False    False
# 18  False  False    False
# 19  False  False    False
# 20  False  False    False
# 21  False  False    False
# 22  False  False    False
# 23  False  False    False
# 24  False  False    False
# 25  False  False    False
# 26  False  False    False
# 27  False  False    False
# 28  False  False    False
# 29  False  False    False
#
# [30 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# id                        0
# belongs_to_collection     0
# budget                    0
# genres                    1
# homepage                 21
# imdb_id                   0
# original_language         0
# original_title            0
# overview                  0
# popularity                0
# poster_path               1
# production_companies      3
# production_countries      0
# release_date              0
# runtime                   1
# spoken_languages          0
# status                    0
# tagline                   5
# title                     0
# Keywords                  1
# cast                      0
# crew                      0
# revenue                   0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# id                        0.000000
# belongs_to_collection     0.000000
# budget                    0.000000
# genres                    3.333333
# homepage                 70.000000
# imdb_id                   0.000000
# original_language         0.000000
# original_title            0.000000
# overview                  0.000000
# popularity                0.000000
# poster_path               3.333333
# production_companies     10.000000
# production_countries      0.000000
# release_date              0.000000
# runtime                   3.333333
# spoken_languages          0.000000
# status                    0.000000
# tagline                  16.666667
# title                     0.000000
# Keywords                  3.333333
# cast                      0.000000
# crew                      0.000000
# revenue                   0.000000
# dtype: float64

# %%
df.drop(columns=["homepage"],inplace=True)    # if the missing value are morethan or equal to 25% we have to remove

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'imdb_id',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'production_companies', 'production_countries',
#        'release_date', 'runtime', 'spoken_languages', 'status', 'tagline',
#        'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='str')

# %%
df.head(1)
# Out:
#    id   belongs_to_collection    budget                genres    imdb_id  \
# 0   1  Hot Tub Time Machine 2  14000000  [{"name": "Comedy"}]  tt2637294
#
#   original_language          original_title             overview  popularity  \
# 0                en  Hot Tub Time Machine 2  Time travel comedy.    6.575393
#
#     poster_path  ... release_date runtime       spoken_languages    status  \
# 0  /poster1.jpg  ...      2/20/15    93.0  [{"name": "English"}]  Released
#
#                       tagline                   title     Keywords  \
# 0  The Laws of Space and Time  Hot Tub Time Machine 2  time travel
#
#                         cast                                         crew  \
# 0  [{"name": "Rob Corddry"}]  [{"name": "Steve Pink", "job": "Director"}]
#
#     revenue
# 0  12314651
#
# [1 rows x 22 columns]

# %% [markdown]
# # - filling missing values

# %%
df.genres  =   df.genres.fillna(df.genres.mode()[0])

# %%
df["poster_path"]  =   df["poster_path"].fillna(df["poster_path"].mode()[0])

# %%
df.production_companies=df.production_companies.fillna(df.production_companies.mode()[0])

# %%
df.runtime=df.runtime.fillna(df.runtime.mean())

# %%
df.tagline=df.tagline.fillna(df.tagline.mode()[0])

# %%
df.Keywords=df.Keywords.fillna(df.Keywords.mode()[0])

# %%
df.isnull().sum()
# Out:
# id                       0
# belongs_to_collection    0
# budget                   0
# genres                   0
# imdb_id                  0
# original_language        0
# original_title           0
# overview                 0
# popularity               0
# poster_path              0
# production_companies     0
# production_countries     0
# release_date             0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# title                    0
# Keywords                 0
# cast                     0
# crew                     0
# revenue                  0
# dtype: int64

# %% [markdown]
# # - fix the datatype issue

# %%
df.dtypes
# Out:
# id                         int64
# belongs_to_collection        str
# budget                     int64
# genres                       str
# imdb_id                      str
# original_language            str
# original_title               str
# overview                     str
# popularity               float64
# poster_path                  str
# production_companies         str
# production_countries         str
# release_date                 str
# runtime                  float64
# spoken_languages             str
# status                       str
# tagline                      str
# title                        str
# Keywords                     str
# cast                         str
# crew                         str
# revenue                    int64
# dtype: object

# %%
df.imdb_id.value_counts()
# Out:
# imdb_id
# tt2637294     1
# tt0368933     1
# tt2582802     1
# tt1821480     1
# tt1380152     1
# tt1375666     1
# tt0468569     1
# tt1187043     1
# tt6751668     1
# tt0362227     1
# tt0105327     1
# tt0109403     1
# tt2364975     1
# tt0116908     1
# tt0343135     1
# tt1600195     1
# tt0816692     1
# tt5074352     1
# tt4154796     1
# tt0120338     1
# tt0245429     1
# tt0068646     1
# tt9000001     1
# tt9000002     1
# tt15327088    1
# tt8178634     1
# tt4849438     1
# tt7286456     1
# tt3783958     1
# tt0112870     1
# Name: count, dtype: int64

# %%
# remove the text in  IMDB_ID

df['imdb_id'] = df['imdb_id'].str.split().str[0].str.replace('tt', '', regex=False)

# %%
df['imdb_id'].value_counts()
# Out:
# imdb_id
# 2637294     1
# 0368933     1
# 2582802     1
# 1821480     1
# 1380152     1
# 1375666     1
# 0468569     1
# 1187043     1
# 6751668     1
# 0362227     1
# 0105327     1
# 0109403     1
# 2364975     1
# 0116908     1
# 0343135     1
# 1600195     1
# 0816692     1
# 5074352     1
# 4154796     1
# 0120338     1
# 0245429     1
# 0068646     1
# 9000001     1
# 9000002     1
# 15327088    1
# 8178634     1
# 4849438     1
# 7286456     1
# 3783958     1
# 0112870     1
# Name: count, dtype: int64

# %%
# change the datatype

df['imdb_id']=df['imdb_id'].astype("int64")

# %%
df.dtypes
# Out:
# id                         int64
# belongs_to_collection        str
# budget                     int64
# genres                       str
# imdb_id                    int64
# original_language            str
# original_title               str
# overview                     str
# popularity               float64
# poster_path                  str
# production_companies         str
# production_countries         str
# release_date                 str
# runtime                  float64
# spoken_languages             str
# status                       str
# tagline                      str
# title                        str
# Keywords                     str
# cast                         str
# crew                         str
# revenue                    int64
# dtype: object

# %%
df.release_date.value_counts()
# Out:
# release_date
# 2/20/15     1
# 8/6/04      1
# 10/10/14    1
# 3/9/12      1
# 2/5/09      1
# 7/16/10     1
# 7/18/08     1
# 12/25/09    1
# 5/30/19     1
# 6/17/04     1
# 9/18/92     1
# 4/22/94     1
# 3/28/13     1
# 10/11/96    1
# 1/16/04     1
# 9/22/11     1
# 11/7/14     1
# 12/23/16    1
# 4/26/19     1
# 12/19/97    1
# 7/20/01     1
# 3/24/72     1
# 8/15/20     1
# 10/10/18    1
# 9/30/22     1
# 3/25/22     1
# 4/28/17     1
# 10/4/19     1
# 12/25/16    1
# 10/20/95    1
# Name: count, dtype: int64

# %%
df.release_date=pd.to_datetime(df.release_date,errors="coerce")
# Out:
# C:\Users\LakshmanAIMLHYD\AppData\Local\Temp\ipykernel_22452\3125924932.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df.release_date=pd.to_datetime(df.release_date,errors="coerce")

# %%
df.dtypes
# Out:
# id                                int64
# belongs_to_collection            object
# budget                            int64
# genres                           object
# imdb_id                           int64
# original_language                object
# original_title                   object
# overview                         object
# popularity                      float64
# poster_path                      object
# production_companies             object
# production_countries             object
# release_date             datetime64[ns]
# runtime                         float64
# spoken_languages                 object
# status                           object
# tagline                          object
# title                            object
# Keywords                         object
# cast                             object
# crew                             object
# revenue                           int64
# dtype: object

# %%
df["release_date"].value_counts()
# Out:
# release_date
# 2015-02-20    1
# 2004-08-06    1
# 2014-10-10    1
# 2012-03-09    1
# 2009-02-05    1
# 2010-07-16    1
# 2008-07-18    1
# 2009-12-25    1
# 2019-05-30    1
# 2004-06-17    1
# 1992-09-18    1
# 1994-04-22    1
# 2013-03-28    1
# 1996-10-11    1
# 2004-01-16    1
# 2011-09-22    1
# 2014-11-07    1
# 2016-12-23    1
# 2019-04-26    1
# 1997-12-19    1
# 2001-07-20    1
# 2072-03-24    1
# 2020-08-15    1
# 2018-10-10    1
# 2022-09-30    1
# 2022-03-25    1
# 2017-04-28    1
# 2019-10-04    1
# 2016-12-25    1
# 1995-10-20    1
# Name: count, dtype: int64

# %% [markdown]
# # <u>**Indexing and Slicing**</u>

# %%
df.head()
# Out:
#    id                     belongs_to_collection    budget  \
# 0   1                    Hot Tub Time Machine 2  14000000
# 1   2  The Princess Diaries 2: Royal Engagement  40000000
# 2   3                                  Whiplash   3300000
# 3   4                                   Kahaani   1200000
# 4   5                                Marine Boy         0
#
#                                        genres  imdb_id original_language  \
# 0                        [{"name": "Comedy"}]  2637294                en
# 1     [{"name": "Comedy"}, {"name": "Drama"}]   368933                en
# 2                         [{"name": "Drama"}]  2582802                en
# 3   [{"name": "Thriller"}, {"name": "Drama"}]  1821480                hi
# 4  [{"name": "Action"}, {"name": "Thriller"}]  1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
#
#     poster_path  ... release_date runtime             spoken_languages  \
# 0  /poster1.jpg  ...   2015-02-20    93.0        [{"name": "English"}]
# 1  /poster2.jpg  ...   2004-08-06   113.0        [{"name": "English"}]
# 2  /poster3.jpg  ...   2014-10-10   105.0        [{"name": "English"}]
# 3  /poster4.jpg  ...   2012-03-09   122.0  [{"name": "English|Hindi"}]
# 4  /poster5.jpg  ...   2009-02-05   118.0         [{"name": "Korean"}]
#
#      status                                          tagline  \
# 0  Released                       The Laws of Space and Time
# 1  Released        It can take a lifetime to find true love.
# 2  Released  The road to greatness can take you to the edge.
# 3  Released                      Act like you own the place.
# 4  Released                      Act like you own the place.
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy    CIA|conspiracy
#
#                           cast  \
# 0    [{"name": "Rob Corddry"}]
# 1  [{"name": "Anne Hathaway"}]
# 2   [{"name": "Miles Teller"}]
# 3    [{"name": "Vidya Balan"}]
# 4   [{"name": "Kim Kang-woo"}]
#
#                                                crew   revenue
# 0       [{"name": "Steve Pink", "job": "Director"}]  12314651
# 1   [{"name": "Garry Marshall", "job": "Director"}]  95149435
# 2  [{"name": "Damien Chazelle", "job": "Director"}]  13092000
# 3      [{"name": "Sujoy Ghosh", "job": "Director"}]  16000000
# 4   [{"name": "Yoon Jong-chan", "job": "Director"}]   3923970
#
# [5 rows x 22 columns]

# %% [markdown]
# ## **<code>iloc</code>** gets rows (or columns) at particular positions in the index (so it only takes integers).

# %%
df.iloc[ 0:20 , 0:4 ]
# Out:
#     id                     belongs_to_collection     budget  \
# 0    1                    Hot Tub Time Machine 2   14000000
# 1    2  The Princess Diaries 2: Royal Engagement   40000000
# 2    3                                  Whiplash    3300000
# 3    4                                   Kahaani    1200000
# 4    5                                Marine Boy          0
# 5    6                                 Inception  160000000
# 6    7                           The Dark Knight  185000000
# 7    8                                  3 Idiots  550000000
# 8    9                                  Parasite   11400000
# 9   10                              The Terminal   60000000
# 10  11                               School Ties          0
# 11  12                                   Chasers          0
# 12  13                          We Are the Best!          0
# 13  14                   The Long Kiss Goodnight   65000000
# 14  15                          Along Came Polly   42000000
# 15  16                                 Abduction   35000000
# 16  17                              Interstellar  165000000
# 17  18                                    Dangal   70000000
# 18  19                         Avengers: Endgame  356000000
# 19  20                                   Titanic  200000000
#
#                                                genres
# 0                                [{"name": "Comedy"}]
# 1             [{"name": "Comedy"}, {"name": "Drama"}]
# 2                                 [{"name": "Drama"}]
# 3           [{"name": "Thriller"}, {"name": "Drama"}]
# 4          [{"name": "Action"}, {"name": "Thriller"}]
# 5            [{"name": "Action"}, {"name": "Sci-Fi"}]
# 6   [{"name": "Action"}, {"name": "Crime"}, {"name...
# 7             [{"name": "Comedy"}, {"name": "Drama"}]
# 8           [{"name": "Drama"}, {"name": "Thriller"}]
# 9             [{"name": "Comedy"}, {"name": "Drama"}]
# 10                                [{"name": "Drama"}]
# 11          [{"name": "Comedy"}, {"name": "Romance"}]
# 12             [{"name": "Drama"}, {"name": "Music"}]
# 13            [{"name": "Crime"}, {"name": "Action"}]
# 14          [{"name": "Comedy"}, {"name": "Romance"}]
# 15         [{"name": "Thriller"}, {"name": "Action"}]
# 16  [{"name": "Adventure"}, {"name": "Drama"}, {"n...
# 17             [{"name": "Drama"}, {"name": "Sport"}]
# 18  [{"name": "Action"}, {"name": "Adventure"}, {"...
# 19           [{"name": "Drama"}, {"name": "Romance"}]

# %%
df.head()
# Out:
#    id                     belongs_to_collection    budget  \
# 0   1                    Hot Tub Time Machine 2  14000000
# 1   2  The Princess Diaries 2: Royal Engagement  40000000
# 2   3                                  Whiplash   3300000
# 3   4                                   Kahaani   1200000
# 4   5                                Marine Boy         0
#
#                                        genres  imdb_id original_language  \
# 0                        [{"name": "Comedy"}]  2637294                en
# 1     [{"name": "Comedy"}, {"name": "Drama"}]   368933                en
# 2                         [{"name": "Drama"}]  2582802                en
# 3   [{"name": "Thriller"}, {"name": "Drama"}]  1821480                hi
# 4  [{"name": "Action"}, {"name": "Thriller"}]  1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
#
#     poster_path  ... release_date runtime             spoken_languages  \
# 0  /poster1.jpg  ...   2015-02-20    93.0        [{"name": "English"}]
# 1  /poster2.jpg  ...   2004-08-06   113.0        [{"name": "English"}]
# 2  /poster3.jpg  ...   2014-10-10   105.0        [{"name": "English"}]
# 3  /poster4.jpg  ...   2012-03-09   122.0  [{"name": "English|Hindi"}]
# 4  /poster5.jpg  ...   2009-02-05   118.0         [{"name": "Korean"}]
#
#      status                                          tagline  \
# 0  Released                       The Laws of Space and Time
# 1  Released        It can take a lifetime to find true love.
# 2  Released  The road to greatness can take you to the edge.
# 3  Released                      Act like you own the place.
# 4  Released                      Act like you own the place.
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy    CIA|conspiracy
#
#                           cast  \
# 0    [{"name": "Rob Corddry"}]
# 1  [{"name": "Anne Hathaway"}]
# 2   [{"name": "Miles Teller"}]
# 3    [{"name": "Vidya Balan"}]
# 4   [{"name": "Kim Kang-woo"}]
#
#                                                crew   revenue
# 0       [{"name": "Steve Pink", "job": "Director"}]  12314651
# 1   [{"name": "Garry Marshall", "job": "Director"}]  95149435
# 2  [{"name": "Damien Chazelle", "job": "Director"}]  13092000
# 3      [{"name": "Sujoy Ghosh", "job": "Director"}]  16000000
# 4   [{"name": "Yoon Jong-chan", "job": "Director"}]   3923970
#
# [5 rows x 22 columns]

# %%
df.iloc[0:6 ,2:5 ]
# Out:
#       budget                                      genres  imdb_id
# 0   14000000                        [{"name": "Comedy"}]  2637294
# 1   40000000     [{"name": "Comedy"}, {"name": "Drama"}]   368933
# 2    3300000                         [{"name": "Drama"}]  2582802
# 3    1200000   [{"name": "Thriller"}, {"name": "Drama"}]  1821480
# 4          0  [{"name": "Action"}, {"name": "Thriller"}]  1380152
# 5  160000000    [{"name": "Action"}, {"name": "Sci-Fi"}]  1375666

# %%
# Let us get a subset which consists of first 8 rows and first 4 columns
df.iloc[:,-3:]
# Out:
#                                  cast  \
# 0           [{"name": "Rob Corddry"}]
# 1         [{"name": "Anne Hathaway"}]
# 2          [{"name": "Miles Teller"}]
# 3           [{"name": "Vidya Balan"}]
# 4          [{"name": "Kim Kang-woo"}]
# 5     [{"name": "Leonardo DiCaprio"}]
# 6        [{"name": "Christian Bale"}]
# 7            [{"name": "Aamir Khan"}]
# 8          [{"name": "Song Kang-ho"}]
# 9             [{"name": "Tom Hanks"}]
# 10       [{"name": "Brendan Fraser"}]
# 11         [{"name": "Tom Berenger"}]
# 12      [{"name": "Mira Barkhammar"}]
# 13          [{"name": "Geena Davis"}]
# 14          [{"name": "Ben Stiller"}]
# 15       [{"name": "Taylor Lautner"}]
# 16  [{"name": "Matthew McConaughey"}]
# 17           [{"name": "Aamir Khan"}]
# 18    [{"name": "Robert Downey Jr."}]
# 19    [{"name": "Leonardo DiCaprio"}]
# 20         [{"name": "Rumi Hiiragi"}]
# 21        [{"name": "Marlon Brando"}]
# 22           [{"name": "Aamir Khan"}]
# 23              [{"name": "Unknown"}]
# 24        [{"name": "Rishab Shetty"}]
# 25   [{"name": "N. T. Rama Rao Jr."}]
# 26              [{"name": "Prabhas"}]
# 27      [{"name": "Joaquin Phoenix"}]
# 28         [{"name": "Ryan Gosling"}]
# 29       [{"name": "Shah Rukh Khan"}]
#
#                                                  crew     revenue
# 0         [{"name": "Steve Pink", "job": "Director"}]    12314651
# 1     [{"name": "Garry Marshall", "job": "Director"}]    95149435
# 2    [{"name": "Damien Chazelle", "job": "Director"}]    13092000
# 3        [{"name": "Sujoy Ghosh", "job": "Director"}]    16000000
# 4     [{"name": "Yoon Jong-chan", "job": "Director"}]     3923970
# 5   [{"name": "Christopher Nolan", "job": "Directo...   839000000
# 6   [{"name": "Christopher Nolan", "job": "Directo...  1004558444
# 7    [{"name": "Rajkumar Hirani", "job": "Director"}]  2000000000
# 8       [{"name": "Bong Joon Ho", "job": "Director"}]   258000000
# 9   [{"name": "Steven Spielberg", "job": "Director"}]   219417255
# 10     [{"name": "Robert Mandel", "job": "Director"}]    14715067
# 11     [{"name": "Dennis Hopper", "job": "Director"}]     1596687
# 12   [{"name": "Lukas Moodysson", "job": "Director"}]      180590
# 13      [{"name": "Renny Harlin", "job": "Director"}]    89456761
# 14      [{"name": "John Hamburg", "job": "Director"}]   171963386
# 15    [{"name": "John Singleton", "job": "Director"}]    82087155
# 16  [{"name": "Christopher Nolan", "job": "Directo...   701729206
# 17     [{"name": "Nitesh Tiwari", "job": "Director"}]   310000000
# 18     [{"name": "Anthony Russo", "job": "Director"}]  2797501328
# 19     [{"name": "James Cameron", "job": "Director"}]  2264743305
# 20    [{"name": "Hayao Miyazaki", "job": "Director"}]   395800000
# 21  [{"name": "Francis Ford Coppola", "job": "Dire...   250000000
# 22     [{"name": "Demo Director", "job": "Director"}]           0
# 23           [{"name": "Unknown", "job": "Director"}]    45000000
# 24     [{"name": "Rishab Shetty", "job": "Director"}]   400000000
# 25   [{"name": "S. S. Rajamouli", "job": "Director"}]  1200000000
# 26   [{"name": "S. S. Rajamouli", "job": "Director"}]  1810000000
# 27     [{"name": "Todd Phillips", "job": "Director"}]  1074251311
# 28   [{"name": "Damien Chazelle", "job": "Director"}]   472000000
# 29     [{"name": "Aditya Chopra", "job": "Director"}]   120000000

# %% [markdown]
# ## **<code>loc</code>** gets rows (or columns) with particular labels from the index.

# %%
# Now let us subset our dataframe in which we want to have first 8 rows identified with their rows labels and some named columns
df.loc[0:10,['budget','genres','runtime']]
# Out:
#        budget                                             genres  runtime
# 0    14000000                               [{"name": "Comedy"}]     93.0
# 1    40000000            [{"name": "Comedy"}, {"name": "Drama"}]    113.0
# 2     3300000                                [{"name": "Drama"}]    105.0
# 3     1200000          [{"name": "Thriller"}, {"name": "Drama"}]    122.0
# 4           0         [{"name": "Action"}, {"name": "Thriller"}]    118.0
# 5   160000000           [{"name": "Action"}, {"name": "Sci-Fi"}]    148.0
# 6   185000000  [{"name": "Action"}, {"name": "Crime"}, {"name...    152.0
# 7   550000000            [{"name": "Comedy"}, {"name": "Drama"}]    170.0
# 8    11400000          [{"name": "Drama"}, {"name": "Thriller"}]    132.0
# 9    60000000            [{"name": "Comedy"}, {"name": "Drama"}]    128.0
# 10          0                                [{"name": "Drama"}]    106.0

# %%
df.loc[0:5,['budget','genres','status']]
# Out:
#       budget                                      genres    status
# 0   14000000                        [{"name": "Comedy"}]  Released
# 1   40000000     [{"name": "Comedy"}, {"name": "Drama"}]  Released
# 2    3300000                         [{"name": "Drama"}]  Released
# 3    1200000   [{"name": "Thriller"}, {"name": "Drama"}]  Released
# 4          0  [{"name": "Action"}, {"name": "Thriller"}]  Released
# 5  160000000    [{"name": "Action"}, {"name": "Sci-Fi"}]  Released

# %%
df.loc[:,['budget','genres','runtime',"status","revenue","belongs_to_collection"]]
# Out:
#        budget                                             genres    runtime  \
# 0    14000000                               [{"name": "Comedy"}]   93.00000
# 1    40000000            [{"name": "Comedy"}, {"name": "Drama"}]  113.00000
# 2     3300000                                [{"name": "Drama"}]  105.00000
# 3     1200000          [{"name": "Thriller"}, {"name": "Drama"}]  122.00000
# 4           0         [{"name": "Action"}, {"name": "Thriller"}]  118.00000
# 5   160000000           [{"name": "Action"}, {"name": "Sci-Fi"}]  148.00000
# 6   185000000  [{"name": "Action"}, {"name": "Crime"}, {"name...  152.00000
# 7   550000000            [{"name": "Comedy"}, {"name": "Drama"}]  170.00000
# 8    11400000          [{"name": "Drama"}, {"name": "Thriller"}]  132.00000
# 9    60000000            [{"name": "Comedy"}, {"name": "Drama"}]  128.00000
# 10          0                                [{"name": "Drama"}]  106.00000
# 11          0          [{"name": "Comedy"}, {"name": "Romance"}]  102.00000
# 12          0             [{"name": "Drama"}, {"name": "Music"}]  102.00000
# 13   65000000            [{"name": "Crime"}, {"name": "Action"}]  120.00000
# 14   42000000          [{"name": "Comedy"}, {"name": "Romance"}]   90.00000
# 15   35000000         [{"name": "Thriller"}, {"name": "Action"}]  106.00000
# 16  165000000  [{"name": "Adventure"}, {"name": "Drama"}, {"n...  169.00000
# 17   70000000             [{"name": "Drama"}, {"name": "Sport"}]  161.00000
# 18  356000000  [{"name": "Action"}, {"name": "Adventure"}, {"...  181.00000
# 19  200000000           [{"name": "Drama"}, {"name": "Romance"}]  194.00000
# 20   19000000       [{"name": "Animation"}, {"name": "Fantasy"}]  125.00000
# 21    6000000             [{"name": "Crime"}, {"name": "Drama"}]  175.00000
# 22   80000000            [{"name": "Comedy"}, {"name": "Drama"}]    0.00000
# 23   25000000            [{"name": "Comedy"}, {"name": "Drama"}]  132.62069
# 24   16000000            [{"name": "Action"}, {"name": "Drama"}]  148.00000
# 25  550000000            [{"name": "Action"}, {"name": "Drama"}]  187.00000
# 26  250000000            [{"name": "Action"}, {"name": "Drama"}]  168.00000
# 27   55000000             [{"name": "Crime"}, {"name": "Drama"}]  122.00000
# 28   30000000  [{"name": "Comedy"}, {"name": "Drama"}, {"name...  128.00000
# 29   40000000           [{"name": "Drama"}, {"name": "Romance"}]  181.00000
#
#       status     revenue                     belongs_to_collection
# 0   Released    12314651                    Hot Tub Time Machine 2
# 1   Released    95149435  The Princess Diaries 2: Royal Engagement
# 2   Released    13092000                                  Whiplash
# 3   Released    16000000                                   Kahaani
# 4   Released     3923970                                Marine Boy
# 5   Released   839000000                                 Inception
# 6   Released  1004558444                           The Dark Knight
# 7   Released  2000000000                                  3 Idiots
# 8   Released   258000000                                  Parasite
# 9   Released   219417255                              The Terminal
# 10  Released    14715067                               School Ties
# 11  Released     1596687                                   Chasers
# 12  Released      180590                          We Are the Best!
# 13  Released    89456761                   The Long Kiss Goodnight
# 14  Released   171963386                          Along Came Polly
# 15  Released    82087155                                 Abduction
# 16  Released   701729206                              Interstellar
# 17  Released   310000000                                    Dangal
# 18  Released  2797501328                         Avengers: Endgame
# 19  Released  2264743305                                   Titanic
# 20  Released   395800000                             Spirited Away
# 21  Released   250000000                             The Godfather
# 22   Rumored           0                          3 Idiots Returns
# 23  Released    45000000                             Mystery Movie
# 24  Released   400000000                                   Kantara
# 25  Released  1200000000                                       RRR
# 26  Released  1810000000                Bahubali 2: The Conclusion
# 27  Released  1074251311                                     Joker
# 28  Released   472000000                                La La Land
# 29  Released   120000000               Dilwale Dulhania Le Jayenge

# %%
df[0:10]
# Out:
#    id                     belongs_to_collection     budget  \
# 0   1                    Hot Tub Time Machine 2   14000000
# 1   2  The Princess Diaries 2: Royal Engagement   40000000
# 2   3                                  Whiplash    3300000
# 3   4                                   Kahaani    1200000
# 4   5                                Marine Boy          0
# 5   6                                 Inception  160000000
# 6   7                           The Dark Knight  185000000
# 7   8                                  3 Idiots  550000000
# 8   9                                  Parasite   11400000
# 9  10                              The Terminal   60000000
#
#                                               genres  imdb_id  \
# 0                               [{"name": "Comedy"}]  2637294
# 1            [{"name": "Comedy"}, {"name": "Drama"}]   368933
# 2                                [{"name": "Drama"}]  2582802
# 3          [{"name": "Thriller"}, {"name": "Drama"}]  1821480
# 4         [{"name": "Action"}, {"name": "Thriller"}]  1380152
# 5           [{"name": "Action"}, {"name": "Sci-Fi"}]  1375666
# 6  [{"name": "Action"}, {"name": "Crime"}, {"name...   468569
# 7            [{"name": "Comedy"}, {"name": "Drama"}]  1187043
# 8          [{"name": "Drama"}, {"name": "Thriller"}]  6751668
# 9            [{"name": "Comedy"}, {"name": "Drama"}]   362227
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                Marine Boy
# 5                en                                 Inception
# 6                en                           The Dark Knight
# 7                hi                                  3 Idiots
# 8                ko                                  Parasite
# 9                en                              The Terminal
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
# 5            A thief enters dreams to steal secrets.   82.500000
# 6                            Batman faces the Joker.   90.100000
# 7           Three friends navigate college and life.   25.300000
# 8  Two families become entangled in a strange sit...   55.700000
# 9              A man becomes stranded in an airport.   14.092373
#
#      poster_path  ... release_date runtime             spoken_languages  \
# 0   /poster1.jpg  ...   2015-02-20    93.0        [{"name": "English"}]
# 1   /poster2.jpg  ...   2004-08-06   113.0        [{"name": "English"}]
# 2   /poster3.jpg  ...   2014-10-10   105.0        [{"name": "English"}]
# 3   /poster4.jpg  ...   2012-03-09   122.0  [{"name": "English|Hindi"}]
# 4   /poster5.jpg  ...   2009-02-05   118.0         [{"name": "Korean"}]
# 5   /poster6.jpg  ...   2010-07-16   148.0        [{"name": "English"}]
# 6   /poster7.jpg  ...   2008-07-18   152.0        [{"name": "English"}]
# 7   /poster8.jpg  ...   2009-12-25   170.0          [{"name": "Hindi"}]
# 8   /poster9.jpg  ...   2019-05-30   132.0         [{"name": "Korean"}]
# 9  /poster10.jpg  ...   2004-06-17   128.0        [{"name": "English"}]
#
#      status                                          tagline  \
# 0  Released                       The Laws of Space and Time
# 1  Released        It can take a lifetime to find true love.
# 2  Released  The road to greatness can take you to the edge.
# 3  Released                      Act like you own the place.
# 4  Released                      Act like you own the place.
# 5  Released             Your mind is the scene of the crime.
# 6  Released                                  Why so serious?
# 7  Released                                     All is well.
# 8  Released                      Act like you own the place.
# 9  Released                                 Life is waiting.
#
#                                       title            Keywords  \
# 0                    Hot Tub Time Machine 2         time travel
# 1  The Princess Diaries 2: Royal Engagement    princess|royalty
# 2                                  Whiplash          jazz|music
# 3                                   Kahaani     mystery|kolkata
# 4                                Marine Boy      CIA|conspiracy
# 5                                 Inception         dream|heist
# 6                           The Dark Knight        joker|batman
# 7                                  3 Idiots  college|friendship
# 8                                  Parasite        family|class
# 9                              The Terminal    airport|new york
#
#                               cast  \
# 0        [{"name": "Rob Corddry"}]
# 1      [{"name": "Anne Hathaway"}]
# 2       [{"name": "Miles Teller"}]
# 3        [{"name": "Vidya Balan"}]
# 4       [{"name": "Kim Kang-woo"}]
# 5  [{"name": "Leonardo DiCaprio"}]
# 6     [{"name": "Christian Bale"}]
# 7         [{"name": "Aamir Khan"}]
# 8       [{"name": "Song Kang-ho"}]
# 9          [{"name": "Tom Hanks"}]
#
#                                                 crew     revenue
# 0        [{"name": "Steve Pink", "job": "Director"}]    12314651
# 1    [{"name": "Garry Marshall", "job": "Director"}]    95149435
# 2   [{"name": "Damien Chazelle", "job": "Director"}]    13092000
# 3       [{"name": "Sujoy Ghosh", "job": "Director"}]    16000000
# 4    [{"name": "Yoon Jong-chan", "job": "Director"}]     3923970
# 5  [{"name": "Christopher Nolan", "job": "Directo...   839000000
# 6  [{"name": "Christopher Nolan", "job": "Directo...  1004558444
# 7   [{"name": "Rajkumar Hirani", "job": "Director"}]  2000000000
# 8      [{"name": "Bong Joon Ho", "job": "Director"}]   258000000
# 9  [{"name": "Steven Spielberg", "job": "Director"}]   219417255
#
# [10 rows x 22 columns]

# %%
df[['original_language','release_date','cast']]
# Out:
#    original_language release_date                               cast
# 0                 en   2015-02-20          [{"name": "Rob Corddry"}]
# 1                 en   2004-08-06        [{"name": "Anne Hathaway"}]
# 2                 en   2014-10-10         [{"name": "Miles Teller"}]
# 3                 hi   2012-03-09          [{"name": "Vidya Balan"}]
# 4                 ko   2009-02-05         [{"name": "Kim Kang-woo"}]
# 5                 en   2010-07-16    [{"name": "Leonardo DiCaprio"}]
# 6                 en   2008-07-18       [{"name": "Christian Bale"}]
# 7                 hi   2009-12-25           [{"name": "Aamir Khan"}]
# 8                 ko   2019-05-30         [{"name": "Song Kang-ho"}]
# 9                 en   2004-06-17            [{"name": "Tom Hanks"}]
# 10                en   1992-09-18       [{"name": "Brendan Fraser"}]
# 11                en   1994-04-22         [{"name": "Tom Berenger"}]
# 12                sv   2013-03-28      [{"name": "Mira Barkhammar"}]
# 13                en   1996-10-11          [{"name": "Geena Davis"}]
# 14                en   2004-01-16          [{"name": "Ben Stiller"}]
# 15                en   2011-09-22       [{"name": "Taylor Lautner"}]
# 16                en   2014-11-07  [{"name": "Matthew McConaughey"}]
# 17                hi   2016-12-23           [{"name": "Aamir Khan"}]
# 18                en   2019-04-26    [{"name": "Robert Downey Jr."}]
# 19                en   1997-12-19    [{"name": "Leonardo DiCaprio"}]
# 20                ja   2001-07-20         [{"name": "Rumi Hiiragi"}]
# 21                en   2072-03-24        [{"name": "Marlon Brando"}]
# 22                hi   2020-08-15           [{"name": "Aamir Khan"}]
# 23                en   2018-10-10              [{"name": "Unknown"}]
# 24                kn   2022-09-30        [{"name": "Rishab Shetty"}]
# 25                te   2022-03-25   [{"name": "N. T. Rama Rao Jr."}]
# 26                te   2017-04-28              [{"name": "Prabhas"}]
# 27                en   2019-10-04      [{"name": "Joaquin Phoenix"}]
# 28                en   2016-12-25         [{"name": "Ryan Gosling"}]
# 29                hi   1995-10-20       [{"name": "Shah Rukh Khan"}]

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='str')

# %%
df.head(1)
# Out:
#    id   belongs_to_collection    budget                genres  imdb_id  \
# 0   1  Hot Tub Time Machine 2  14000000  [{"name": "Comedy"}]  2637294
#
#   original_language          original_title             overview  popularity  \
# 0                en  Hot Tub Time Machine 2  Time travel comedy.    6.575393
#
#     poster_path  ... release_date runtime       spoken_languages    status  \
# 0  /poster1.jpg  ...   2015-02-20    93.0  [{"name": "English"}]  Released
#
#                       tagline                   title     Keywords  \
# 0  The Laws of Space and Time  Hot Tub Time Machine 2  time travel
#
#                         cast                                         crew  \
# 0  [{"name": "Rob Corddry"}]  [{"name": "Steve Pink", "job": "Director"}]
#
#     revenue
# 0  12314651
#
# [1 rows x 22 columns]

# %% [markdown]
# ## <b>In fact we can also perform boolean indexing on our dataframe</b>

# %%
df['original_language'] == 'en'
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# 15     True
# 16     True
# 17    False
# 18     True
# 19     True
# 20    False
# 21     True
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27     True
# 28     True
# 29    False
# Name: original_language, dtype: bool

# %%
# Boolean Indexing
english_movies = df[df['original_language'] == 'en']
english_movies.head()
# Out:
#    id                     belongs_to_collection     budget  \
# 0   1                    Hot Tub Time Machine 2   14000000
# 1   2  The Princess Diaries 2: Royal Engagement   40000000
# 2   3                                  Whiplash    3300000
# 5   6                                 Inception  160000000
# 6   7                           The Dark Knight  185000000
#
#                                               genres  imdb_id  \
# 0                               [{"name": "Comedy"}]  2637294
# 1            [{"name": "Comedy"}, {"name": "Drama"}]   368933
# 2                                [{"name": "Drama"}]  2582802
# 5           [{"name": "Action"}, {"name": "Sci-Fi"}]  1375666
# 6  [{"name": "Action"}, {"name": "Crime"}, {"name...   468569
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 5                en                                 Inception
# 6                en                           The Dark Knight
#
#                                        overview  popularity   poster_path  \
# 0                           Time travel comedy.    6.575393  /poster1.jpg
# 1             A princess prepares for marriage.    8.248895  /poster2.jpg
# 2  A young drummer faces a ruthless instructor.   64.299990  /poster3.jpg
# 5       A thief enters dreams to steal secrets.   82.500000  /poster6.jpg
# 6                       Batman faces the Joker.   90.100000  /poster7.jpg
#
#    ... release_date runtime       spoken_languages    status  \
# 0  ...   2015-02-20    93.0  [{"name": "English"}]  Released
# 1  ...   2004-08-06   113.0  [{"name": "English"}]  Released
# 2  ...   2014-10-10   105.0  [{"name": "English"}]  Released
# 5  ...   2010-07-16   148.0  [{"name": "English"}]  Released
# 6  ...   2008-07-18   152.0  [{"name": "English"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 5             Your mind is the scene of the crime.
# 6                                  Why so serious?
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 5                                 Inception       dream|heist
# 6                           The Dark Knight      joker|batman
#
#                               cast  \
# 0        [{"name": "Rob Corddry"}]
# 1      [{"name": "Anne Hathaway"}]
# 2       [{"name": "Miles Teller"}]
# 5  [{"name": "Leonardo DiCaprio"}]
# 6     [{"name": "Christian Bale"}]
#
#                                                 crew     revenue
# 0        [{"name": "Steve Pink", "job": "Director"}]    12314651
# 1    [{"name": "Garry Marshall", "job": "Director"}]    95149435
# 2   [{"name": "Damien Chazelle", "job": "Director"}]    13092000
# 5  [{"name": "Christopher Nolan", "job": "Directo...   839000000
# 6  [{"name": "Christopher Nolan", "job": "Directo...  1004558444
#
# [5 rows x 22 columns]

# %%
english_movies.shape
# Out:
# (18, 22)

# %%
non_english_movies = df[df['original_language'] != 'en']
non_english_movies.head()
# Out:
#     id belongs_to_collection     budget  \
# 3    4               Kahaani    1200000
# 4    5            Marine Boy          0
# 7    8              3 Idiots  550000000
# 8    9              Parasite   11400000
# 12  13      We Are the Best!          0
#
#                                         genres  imdb_id original_language  \
# 3    [{"name": "Thriller"}, {"name": "Drama"}]  1821480                hi
# 4   [{"name": "Action"}, {"name": "Thriller"}]  1380152                ko
# 7      [{"name": "Comedy"}, {"name": "Drama"}]  1187043                hi
# 8    [{"name": "Drama"}, {"name": "Thriller"}]  6751668                ko
# 12      [{"name": "Drama"}, {"name": "Music"}]  2364975                sv
#
#       original_title                                           overview  \
# 3            Kahaani  A woman searches for her missing husband in Ko...
# 4         Marine Boy        A former swimmer becomes involved in crime.
# 7           3 Idiots           Three friends navigate college and life.
# 8           Parasite  Two families become entangled in a strange sit...
# 12  We Are the Best!                      Three girls form a punk band.
#
#     popularity    poster_path  ... release_date runtime  \
# 3     3.174936   /poster4.jpg  ...   2012-03-09   122.0
# 4     1.148070   /poster5.jpg  ...   2009-02-05   118.0
# 7    25.300000   /poster8.jpg  ...   2009-12-25   170.0
# 8    55.700000   /poster9.jpg  ...   2019-05-30   132.0
# 12    3.727996  /poster13.jpg  ...   2013-03-28   102.0
#
#                spoken_languages    status                      tagline  \
# 3   [{"name": "English|Hindi"}]  Released  Act like you own the place.
# 4          [{"name": "Korean"}]  Released  Act like you own the place.
# 7           [{"name": "Hindi"}]  Released                 All is well.
# 8          [{"name": "Korean"}]  Released  Act like you own the place.
# 12        [{"name": "Swedish"}]  Released  Act like you own the place.
#
#                title            Keywords                           cast  \
# 3            Kahaani     mystery|kolkata      [{"name": "Vidya Balan"}]
# 4         Marine Boy      CIA|conspiracy     [{"name": "Kim Kang-woo"}]
# 7           3 Idiots  college|friendship       [{"name": "Aamir Khan"}]
# 8           Parasite        family|class     [{"name": "Song Kang-ho"}]
# 12  We Are the Best!         sweden|punk  [{"name": "Mira Barkhammar"}]
#
#                                                 crew     revenue
# 3       [{"name": "Sujoy Ghosh", "job": "Director"}]    16000000
# 4    [{"name": "Yoon Jong-chan", "job": "Director"}]     3923970
# 7   [{"name": "Rajkumar Hirani", "job": "Director"}]  2000000000
# 8      [{"name": "Bong Joon Ho", "job": "Director"}]   258000000
# 12  [{"name": "Lukas Moodysson", "job": "Director"}]      180590
#
# [5 rows x 22 columns]

# %%
long_movies = df[df['runtime'] > 120]
long_movies[['title','cast']]
# Out:
#                           title                               cast
# 3                       Kahaani          [{"name": "Vidya Balan"}]
# 5                     Inception    [{"name": "Leonardo DiCaprio"}]
# 6               The Dark Knight       [{"name": "Christian Bale"}]
# 7                      3 Idiots           [{"name": "Aamir Khan"}]
# 8                      Parasite         [{"name": "Song Kang-ho"}]
# 9                  The Terminal            [{"name": "Tom Hanks"}]
# 16                 Interstellar  [{"name": "Matthew McConaughey"}]
# 17                       Dangal           [{"name": "Aamir Khan"}]
# 18            Avengers: Endgame    [{"name": "Robert Downey Jr."}]
# 19                      Titanic    [{"name": "Leonardo DiCaprio"}]
# 20                Spirited Away         [{"name": "Rumi Hiiragi"}]
# 21                The Godfather        [{"name": "Marlon Brando"}]
# 23                Mystery Movie              [{"name": "Unknown"}]
# 24                      Kantara        [{"name": "Rishab Shetty"}]
# 25                          RRR   [{"name": "N. T. Rama Rao Jr."}]
# 26  Baahubali 2: The Conclusion              [{"name": "Prabhas"}]
# 27                        Joker      [{"name": "Joaquin Phoenix"}]
# 28                   La La Land         [{"name": "Ryan Gosling"}]
# 29  Dilwale Dulhania Le Jayenge       [{"name": "Shah Rukh Khan"}]

# %% [markdown]
# ## Infact we can match conditions for mutliple columns

# %%
long_movies = df[df['runtime'] > 120]

# %%
long_movies.tail()
# Out:
#     id        belongs_to_collection     budget  \
# 25  26                          RRR  550000000
# 26  27   Bahubali 2: The Conclusion  250000000
# 27  28                        Joker   55000000
# 28  29                   La La Land   30000000
# 29  30  Dilwale Dulhania Le Jayenge   40000000
#
#                                                genres homepage    imdb_id  \
# 25            [{"name": "Action"}, {"name": "Drama"}]      NaN  tt8178634
# 26            [{"name": "Action"}, {"name": "Drama"}]      NaN  tt4849438
# 27             [{"name": "Crime"}, {"name": "Drama"}]      NaN  tt7286456
# 28  [{"name": "Comedy"}, {"name": "Drama"}, {"name...      NaN  tt3783958
# 29           [{"name": "Drama"}, {"name": "Romance"}]      NaN  tt0112870
#
#    original_language               original_title  \
# 25                te                          RRR
# 26                te  Baahubali 2: The Conclusion
# 27                en                        Joker
# 28                en                   La La Land
# 29                hi  Dilwale Dulhania Le Jayenge
#
#                                              overview  popularity  ...  \
# 25   Two revolutionaries form an unlikely friendship.        60.3  ...
# 26               A kingdom seeks answers and revenge.        52.9  ...
# 27             A failed comedian descends into chaos.        70.9  ...
# 28  A musician and actress pursue dreams in Los An...        35.8  ...
# 29     A young couple challenges family expectations.        20.6  ...
#
#    release_date runtime       spoken_languages    status  \
# 25      3/25/22   187.0   [{"name": "Telugu"}]  Released
# 26      4/28/17   168.0   [{"name": "Telugu"}]  Released
# 27      10/4/19   122.0  [{"name": "English"}]  Released
# 28     12/25/16   128.0  [{"name": "English"}]  Released
# 29     10/20/95   181.0    [{"name": "Hindi"}]  Released
#
#                              tagline                        title  \
# 25               Rise. Roar. Revolt.                          RRR
# 26  Why did Kattappa kill Baahubali?  Baahubali 2: The Conclusion
# 27              Put on a happy face.                        Joker
# 28    Here's to the fools who dream.                   La La Land
# 29             Come... Fall in love.  Dilwale Dulhania Le Jayenge
#
#                  Keywords                              cast  \
# 25  friendship|revolution  [{"name": "N. T. Rama Rao Jr."}]
# 26            kingdom|war             [{"name": "Prabhas"}]
# 27            joker|crime     [{"name": "Joaquin Phoenix"}]
# 28      music|los angeles        [{"name": "Ryan Gosling"}]
# 29         romance|family      [{"name": "Shah Rukh Khan"}]
#
#                                                 crew     revenue
# 25  [{"name": "S. S. Rajamouli", "job": "Director"}]  1200000000
# 26  [{"name": "S. S. Rajamouli", "job": "Director"}]  1810000000
# 27    [{"name": "Todd Phillips", "job": "Director"}]  1074251311
# 28  [{"name": "Damien Chazelle", "job": "Director"}]   472000000
# 29    [{"name": "Aditya Chopra", "job": "Director"}]   120000000
#
# [5 rows x 23 columns]

# %%
(df['original_language']=='en') & (df['runtime'] > 120)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18     True
# 19     True
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28     True
# 29    False
# dtype: bool

# %%
long_english_movies = df[(df['original_language']=='en') & (df['runtime'] > 120)]
long_english_movies.head()
# Out:
#     id belongs_to_collection     budget  \
# 5    6             Inception  160000000
# 6    7       The Dark Knight  185000000
# 9   10          The Terminal   60000000
# 16  17          Interstellar  165000000
# 18  19     Avengers: Endgame  356000000
#
#                                                genres  imdb_id  \
# 5            [{"name": "Action"}, {"name": "Sci-Fi"}]  1375666
# 6   [{"name": "Action"}, {"name": "Crime"}, {"name...   468569
# 9             [{"name": "Comedy"}, {"name": "Drama"}]   362227
# 16  [{"name": "Adventure"}, {"name": "Drama"}, {"n...   816692
# 18  [{"name": "Action"}, {"name": "Adventure"}, {"...  4154796
#
#    original_language     original_title  \
# 5                 en          Inception
# 6                 en    The Dark Knight
# 9                 en       The Terminal
# 16                en       Interstellar
# 18                en  Avengers: Endgame
#
#                                          overview  popularity    poster_path  \
# 5         A thief enters dreams to steal secrets.   82.500000   /poster6.jpg
# 6                         Batman faces the Joker.   90.100000   /poster7.jpg
# 9           A man becomes stranded in an airport.   14.092373  /poster10.jpg
# 16  Explorers travel through a wormhole in space.   75.000000  /poster17.jpg
# 18  Heroes attempt to reverse a devastating loss.   88.200000  /poster19.jpg
#
#     ... release_date runtime       spoken_languages    status  \
# 5   ...   2010-07-16   148.0  [{"name": "English"}]  Released
# 6   ...   2008-07-18   152.0  [{"name": "English"}]  Released
# 9   ...   2004-06-17   128.0  [{"name": "English"}]  Released
# 16  ...   2014-11-07   169.0  [{"name": "English"}]  Released
# 18  ...   2019-04-26   181.0  [{"name": "English"}]  Released
#
#                                               tagline              title  \
# 5                Your mind is the scene of the crime.          Inception
# 6                                     Why so serious?    The Dark Knight
# 9                                    Life is waiting.       The Terminal
# 16  Mankind was born on Earth. It was never meant ...       Interstellar
# 18                                 Avenge the fallen.  Avengers: Endgame
#
#             Keywords                               cast  \
# 5        dream|heist    [{"name": "Leonardo DiCaprio"}]
# 6       joker|batman       [{"name": "Christian Bale"}]
# 9   airport|new york            [{"name": "Tom Hanks"}]
# 16    space|wormhole  [{"name": "Matthew McConaughey"}]
# 18  superhero|marvel    [{"name": "Robert Downey Jr."}]
#
#                                                  crew     revenue
# 5   [{"name": "Christopher Nolan", "job": "Directo...   839000000
# 6   [{"name": "Christopher Nolan", "job": "Directo...  1004558444
# 9   [{"name": "Steven Spielberg", "job": "Director"}]   219417255
# 16  [{"name": "Christopher Nolan", "job": "Directo...   701729206
# 18     [{"name": "Anthony Russo", "job": "Director"}]  2797501328
#
# [5 rows x 22 columns]

# %%
long_english_movies.shape
# Out:
# (9, 23)

# %% [markdown]
# # <u>**Next let us see how we can manipulate columns**</u>

# %%
df.shape
# Out:
# (30, 23)

# %% [markdown]
# ## **Let's say if you wanted a new column whose values were half the movie runtime**

# %%
df['runtime']
# Out:
# 0      93.0
# 1     113.0
# 2     105.0
# 3     122.0
# 4     118.0
# 5     148.0
# 6     152.0
# 7     170.0
# 8     132.0
# 9     128.0
# 10    106.0
# 11    102.0
# 12    102.0
# 13    120.0
# 14     90.0
# 15    106.0
# 16    169.0
# 17    161.0
# 18    181.0
# 19    194.0
# 20    125.0
# 21    175.0
# 22      0.0
# 23      NaN
# 24    148.0
# 25    187.0
# 26    168.0
# 27    122.0
# 28    128.0
# 29    181.0
# Name: runtime, dtype: float64

# %%
# Add new column which is just half the runtime
df['half_runtime'] = df['runtime'] * 0.5

# %%
df.head()
# Out:
#    id                     belongs_to_collection    budget  \
# 0   1                    Hot Tub Time Machine 2  14000000
# 1   2  The Princess Diaries 2: Royal Engagement  40000000
# 2   3                                  Whiplash   3300000
# 3   4                                   Kahaani   1200000
# 4   5                                Marine Boy         0
#
#                                        genres  imdb_id original_language  \
# 0                        [{"name": "Comedy"}]  2637294                en
# 1     [{"name": "Comedy"}, {"name": "Drama"}]   368933                en
# 2                         [{"name": "Drama"}]  2582802                en
# 3   [{"name": "Thriller"}, {"name": "Drama"}]  1821480                hi
# 4  [{"name": "Action"}, {"name": "Thriller"}]  1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
#
#     poster_path  ... runtime             spoken_languages    status  \
# 0  /poster1.jpg  ...    93.0        [{"name": "English"}]  Released
# 1  /poster2.jpg  ...   113.0        [{"name": "English"}]  Released
# 2  /poster3.jpg  ...   105.0        [{"name": "English"}]  Released
# 3  /poster4.jpg  ...   122.0  [{"name": "English|Hindi"}]  Released
# 4  /poster5.jpg  ...   118.0         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                      Act like you own the place.
# 4                      Act like you own the place.
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy    CIA|conspiracy
#
#                           cast  \
# 0    [{"name": "Rob Corddry"}]
# 1  [{"name": "Anne Hathaway"}]
# 2   [{"name": "Miles Teller"}]
# 3    [{"name": "Vidya Balan"}]
# 4   [{"name": "Kim Kang-woo"}]
#
#                                                crew   revenue half_runtime
# 0       [{"name": "Steve Pink", "job": "Director"}]  12314651         46.5
# 1   [{"name": "Garry Marshall", "job": "Director"}]  95149435         56.5
# 2  [{"name": "Damien Chazelle", "job": "Director"}]  13092000         52.5
# 3      [{"name": "Sujoy Ghosh", "job": "Director"}]  16000000         61.0
# 4   [{"name": "Yoon Jong-chan", "job": "Director"}]   3923970         59.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ## We can also create a new column by adding two existing columns

# %%
# Creating another new column by subtracting/adding two existing columns
df['movie_profit'] = df['revenue'] - df['budget']

# %%
df.head()
# Out:
#    id                     belongs_to_collection    budget  \
# 0   1                    Hot Tub Time Machine 2  14000000
# 1   2  The Princess Diaries 2: Royal Engagement  40000000
# 2   3                                  Whiplash   3300000
# 3   4                                   Kahaani   1200000
# 4   5                                Marine Boy         0
#
#                                        genres  imdb_id original_language  \
# 0                        [{"name": "Comedy"}]  2637294                en
# 1     [{"name": "Comedy"}, {"name": "Drama"}]   368933                en
# 2                         [{"name": "Drama"}]  2582802                en
# 3   [{"name": "Thriller"}, {"name": "Drama"}]  1821480                hi
# 4  [{"name": "Action"}, {"name": "Thriller"}]  1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
#
#     poster_path  ...             spoken_languages    status  \
# 0  /poster1.jpg  ...        [{"name": "English"}]  Released
# 1  /poster2.jpg  ...        [{"name": "English"}]  Released
# 2  /poster3.jpg  ...        [{"name": "English"}]  Released
# 3  /poster4.jpg  ...  [{"name": "English|Hindi"}]  Released
# 4  /poster5.jpg  ...         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                      Act like you own the place.
# 4                      Act like you own the place.
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy    CIA|conspiracy
#
#                           cast  \
# 0    [{"name": "Rob Corddry"}]
# 1  [{"name": "Anne Hathaway"}]
# 2   [{"name": "Miles Teller"}]
# 3    [{"name": "Vidya Balan"}]
# 4   [{"name": "Kim Kang-woo"}]
#
#                                                crew   revenue half_runtime  \
# 0       [{"name": "Steve Pink", "job": "Director"}]  12314651         46.5
# 1   [{"name": "Garry Marshall", "job": "Director"}]  95149435         56.5
# 2  [{"name": "Damien Chazelle", "job": "Director"}]  13092000         52.5
# 3      [{"name": "Sujoy Ghosh", "job": "Director"}]  16000000         61.0
# 4   [{"name": "Yoon Jong-chan", "job": "Director"}]   3923970         59.0
#
#   movie_profit
# 0     -1685349
# 1     55149435
# 2      9792000
# 3     14800000
# 4      3923970
#
# [5 rows x 24 columns]

# %% [markdown]
# ## **Next, we can also drop some columns which we want to drop**

# %%
# Remove column
df.drop(['id'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#                       belongs_to_collection    budget  \
# 0                    Hot Tub Time Machine 2  14000000
# 1  The Princess Diaries 2: Royal Engagement  40000000
# 2                                  Whiplash   3300000
# 3                                   Kahaani   1200000
# 4                                Marine Boy         0
#
#                                        genres  imdb_id original_language  \
# 0                        [{"name": "Comedy"}]  2637294                en
# 1     [{"name": "Comedy"}, {"name": "Drama"}]   368933                en
# 2                         [{"name": "Drama"}]  2582802                en
# 3   [{"name": "Thriller"}, {"name": "Drama"}]  1821480                hi
# 4  [{"name": "Action"}, {"name": "Thriller"}]  1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
#
#     poster_path                production_companies  ...  \
# 0  /poster1.jpg    [{"name": "Paramount Pictures"}]  ...
# 1  /poster2.jpg  [{"name": "Walt Disney Pictures"}]  ...
# 2  /poster3.jpg            [{"name": "Bold Films"}]  ...
# 3  /poster4.jpg    [{"name": "Paramount Pictures"}]  ...
# 4  /poster5.jpg    [{"name": "Paramount Pictures"}]  ...
#
#               spoken_languages    status  \
# 0        [{"name": "English"}]  Released
# 1        [{"name": "English"}]  Released
# 2        [{"name": "English"}]  Released
# 3  [{"name": "English|Hindi"}]  Released
# 4         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                      Act like you own the place.
# 4                      Act like you own the place.
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy    CIA|conspiracy
#
#                           cast  \
# 0    [{"name": "Rob Corddry"}]
# 1  [{"name": "Anne Hathaway"}]
# 2   [{"name": "Miles Teller"}]
# 3    [{"name": "Vidya Balan"}]
# 4   [{"name": "Kim Kang-woo"}]
#
#                                                crew   revenue half_runtime  \
# 0       [{"name": "Steve Pink", "job": "Director"}]  12314651         46.5
# 1   [{"name": "Garry Marshall", "job": "Director"}]  95149435         56.5
# 2  [{"name": "Damien Chazelle", "job": "Director"}]  13092000         52.5
# 3      [{"name": "Sujoy Ghosh", "job": "Director"}]  16000000         61.0
# 4   [{"name": "Yoon Jong-chan", "job": "Director"}]   3923970         59.0
#
#   movie_profit
# 0     -1685349
# 1     55149435
# 2      9792000
# 3     14800000
# 4      3923970
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
#              budget  popularity     runtime       revenue  half_runtime  \
# count  3.000000e+01   30.000000   29.000000  3.000000e+01     29.000000
# mean   1.009633e+08   39.042643  132.620690  5.554160e+08     66.310345
# std    1.492895e+08   31.461444   40.063712  7.579332e+08     20.031856
# min    0.000000e+00    1.148070    0.000000  0.000000e+00      0.000000
# 25%    1.205000e+07   11.009082  106.000000  2.325000e+07     53.000000
# 50%    4.000000e+07   30.350000  128.000000  2.347086e+08     64.000000
# 75%    1.400000e+08   69.249998  168.000000  8.046823e+08     84.000000
# max    5.500000e+08   95.300000  194.000000  2.797501e+09     97.000000
#
#        movie_profit
# count  3.000000e+01
# mean   4.544527e+08
# std    6.478400e+08
# min   -8.000000e+07
# 25%    1.610000e+07
# 50%    1.997086e+08
# 75%    6.216823e+08
# max    2.441501e+09

# %% [markdown]
# ## You can drop  multiple columns at once too.

# %%
df.drop(['half_runtime','poster_path'],axis=1,inplace=True)

# %%
df.drop(['crew'], axis = 1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 df.drop(['crew'], axis = 1, inplace=True)
#
# File c:\Users\LakshmanAIMLHYD\anaconda3\envs\laxman\Lib\site-packages\pandas\core\frame.py:6302, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6298                 weight  250.0   150.0
#    6299         falcon  speed   320.0   250.0
#    6300                 weight  1.0     0.8
#    6301         """
# -> 6302         return super().drop(
#    6303             labels=labels,
#    6304             axis=axis,
#    6305             index=index,
#
# File c:\Users\LakshmanAIMLHYD\anaconda3\envs\laxman\Lib\site-packages\pandas\core\generic.py:4632, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4628         obj = self
#    4629
#    4630         for axis, labels in axes.items():
#    4631             if labels is not None:
# -> 4632                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4633
#    4634         if inplace:
#    4635             self._update_inplace(obj)
#
# File c:\Users\LakshmanAIMLHYD\anaconda3\envs\laxman\Lib\site-packages\pandas\core\generic.py:4674, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4670                 if not isinstance(axis, MultiIndex):
#    4671                     raise AssertionError("axis must be a MultiIndex")
#    4672                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4673             else:
# -> 4674                 new_axis = axis.drop(labels, errors=errors)
#    4675             indexer = axis.get_indexer(new_axis)
#    4676
#    4677         # Case for non-unique axis
#
# File c:\Users\LakshmanAIMLHYD\anaconda3\envs\laxman\Lib\site-packages\pandas\core\indexes\base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: "['crew'] not found in axis"

# %%
df.head()
# Out:
#                       belongs_to_collection    budget  \
# 0                    Hot Tub Time Machine 2  14000000
# 1  The Princess Diaries 2: Royal Engagement  40000000
# 2                                  Whiplash   3300000
# 3                                   Kahaani   1200000
# 4                                Marine Boy         0
#
#                                        genres  imdb_id original_language  \
# 0                        [{"name": "Comedy"}]  2637294                en
# 1     [{"name": "Comedy"}, {"name": "Drama"}]   368933                en
# 2                         [{"name": "Drama"}]  2582802                en
# 3   [{"name": "Thriller"}, {"name": "Drama"}]  1821480                hi
# 4  [{"name": "Action"}, {"name": "Thriller"}]  1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
#
#                  production_companies    production_countries release_date  \
# 0    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]   2015-02-20
# 1  [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]   2004-08-06
# 2            [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]   2014-10-10
# 3    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "IN"}]   2012-03-09
# 4    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "KR"}]   2009-02-05
#
#    runtime             spoken_languages    status  \
# 0     93.0        [{"name": "English"}]  Released
# 1    113.0        [{"name": "English"}]  Released
# 2    105.0        [{"name": "English"}]  Released
# 3    122.0  [{"name": "English|Hindi"}]  Released
# 4    118.0         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                      Act like you own the place.
# 4                      Act like you own the place.
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy    CIA|conspiracy
#
#                           cast   revenue  movie_profit
# 0    [{"name": "Rob Corddry"}]  12314651      -1685349
# 1  [{"name": "Anne Hathaway"}]  95149435      55149435
# 2   [{"name": "Miles Teller"}]  13092000       9792000
# 3    [{"name": "Vidya Balan"}]  16000000      14800000
# 4   [{"name": "Kim Kang-woo"}]   3923970       3923970

# %% [markdown]
# ## **We can do a lot of basic operations as well**

# %%
# Find the sum of values in a column
df['budget'].sum()
# Out:
# np.int64(3028900000)

# %%
# What if there is a null value
df.loc[:1,'revenue'] = np.nan

# %%
df.iloc[:5]
# Out:
#                       belongs_to_collection    budget  \
# 0                    Hot Tub Time Machine 2  14000000
# 1  The Princess Diaries 2: Royal Engagement  40000000
# 2                                  Whiplash   3300000
# 3                                   Kahaani   1200000
# 4                                Marine Boy         0
#
#                                        genres  \
# 0                        [{"name": "Comedy"}]
# 1     [{"name": "Comedy"}, {"name": "Drama"}]
# 2                         [{"name": "Drama"}]
# 3   [{"name": "Thriller"}, {"name": "Drama"}]
# 4  [{"name": "Action"}, {"name": "Thriller"}]
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
#
#                  production_companies  ... release_date runtime  \
# 0    [{"name": "Paramount Pictures"}]  ...      2/20/15    93.0
# 1  [{"name": "Walt Disney Pictures"}]  ...       8/6/04   113.0
# 2            [{"name": "Bold Films"}]  ...     10/10/14   105.0
# 3                                 NaN  ...       3/9/12   122.0
# 4                                 NaN  ...       2/5/09   118.0
#
#               spoken_languages    status  \
# 0        [{"name": "English"}]  Released
# 1        [{"name": "English"}]  Released
# 2        [{"name": "English"}]  Released
# 3  [{"name": "English|Hindi"}]  Released
# 4         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                                              NaN
# 4                                              NaN
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy               NaN
#
#                           cast     revenue  movie_profit
# 0    [{"name": "Rob Corddry"}]         NaN      -1685349
# 1  [{"name": "Anne Hathaway"}]         NaN      55149435
# 2   [{"name": "Miles Teller"}]  13092000.0       9792000
# 3    [{"name": "Vidya Balan"}]  16000000.0      14800000
# 4   [{"name": "Kim Kang-woo"}]   3923970.0       3923970
#
# [5 rows x 21 columns]

# %%
df.set_index('runtime', inplace=True)

# %%
df.head()
# Out:
#                             belongs_to_collection    budget  \
# runtime
# 93.0                       Hot Tub Time Machine 2  14000000
# 113.0    The Princess Diaries 2: Royal Engagement  40000000
# 105.0                                    Whiplash   3300000
# 122.0                                     Kahaani   1200000
# 118.0                                  Marine Boy         0
#
#                                              genres original_language  \
# runtime
# 93.0                           [{"name": "Comedy"}]                en
# 113.0       [{"name": "Comedy"}, {"name": "Drama"}]                en
# 105.0                           [{"name": "Drama"}]                en
# 122.0     [{"name": "Thriller"}, {"name": "Drama"}]                hi
# 118.0    [{"name": "Action"}, {"name": "Thriller"}]                ko
#
#                                    original_title  \
# runtime
# 93.0                       Hot Tub Time Machine 2
# 113.0    The Princess Diaries 2: Royal Engagement
# 105.0                                    Whiplash
# 122.0                                     Kahaani
# 118.0                                  Marine Boy
#
#                                                   overview  popularity  \
# runtime
# 93.0                                   Time travel comedy.    6.575393
# 113.0                    A princess prepares for marriage.    8.248895
# 105.0         A young drummer faces a ruthless instructor.   64.299990
# 122.0    A woman searches for her missing husband in Ko...    3.174936
# 118.0          A former swimmer becomes involved in crime.    1.148070
#
#                        production_companies    production_countries  \
# runtime
# 93.0       [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# 113.0    [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]
# 105.0              [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]
# 122.0      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "IN"}]
# 118.0      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "KR"}]
#
#         release_date             spoken_languages    status  \
# runtime
# 93.0      2015-02-20        [{"name": "English"}]  Released
# 113.0     2004-08-06        [{"name": "English"}]  Released
# 105.0     2014-10-10        [{"name": "English"}]  Released
# 122.0     2012-03-09  [{"name": "English|Hindi"}]  Released
# 118.0     2009-02-05         [{"name": "Korean"}]  Released
#
#                                                  tagline  \
# runtime
# 93.0                          The Laws of Space and Time
# 113.0          It can take a lifetime to find true love.
# 105.0    The road to greatness can take you to the edge.
# 122.0                        Act like you own the place.
# 118.0                        Act like you own the place.
#
#                                             title          Keywords  \
# runtime
# 93.0                       Hot Tub Time Machine 2       time travel
# 113.0    The Princess Diaries 2: Royal Engagement  princess|royalty
# 105.0                                    Whiplash        jazz|music
# 122.0                                     Kahaani   mystery|kolkata
# 118.0                                  Marine Boy    CIA|conspiracy
#
#                                 cast     revenue  movie_profit
# runtime
# 93.0       [{"name": "Rob Corddry"}]         NaN      -1685349
# 113.0    [{"name": "Anne Hathaway"}]         NaN      55149435
# 105.0     [{"name": "Miles Teller"}]  13092000.0       9792000
# 122.0      [{"name": "Vidya Balan"}]  16000000.0      14800000
# 118.0     [{"name": "Kim Kang-woo"}]   3923970.0       3923970

# %%
df.iloc[:3]
# Out:
#                               belongs_to_collection    budget  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2  14000000
# tt0368933  The Princess Diaries 2: Royal Engagement  40000000
# tt2582802                                  Whiplash   3300000
#
#                                             genres  \
# imdb_id
# tt2637294                     [{"name": "Comedy"}]
# tt0368933  [{"name": "Comedy"}, {"name": "Drama"}]
# tt2582802                      [{"name": "Drama"}]
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# tt0368933                                NaN                en
# tt2582802  http://sonyclassics.com/whiplash/                en
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
#
#                                                overview  popularity  \
# imdb_id
# tt2637294                           Time travel comedy.    6.575393
# tt0368933             A princess prepares for marriage.    8.248895
# tt2582802  A young drummer faces a ruthless instructor.   64.299990
#
#                          production_companies    production_countries  \
# imdb_id
# tt2637294    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# tt0368933  [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]
# tt2582802            [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]
#
#           release_date  runtime       spoken_languages    status  \
# imdb_id
# tt2637294      2/20/15     93.0  [{"name": "English"}]  Released
# tt0368933       8/6/04    113.0  [{"name": "English"}]  Released
# tt2582802     10/10/14    105.0  [{"name": "English"}]  Released
#
#                                                    tagline  \
# imdb_id
# tt2637294                       The Laws of Space and Time
# tt0368933        It can take a lifetime to find true love.
# tt2582802  The road to greatness can take you to the edge.
#
#                                               title          Keywords  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2       time travel
# tt0368933  The Princess Diaries 2: Royal Engagement  princess|royalty
# tt2582802                                  Whiplash        jazz|music
#
#                                   cast     revenue  movie_profit
# imdb_id
# tt2637294    [{"name": "Rob Corddry"}]         NaN      -1685349
# tt0368933  [{"name": "Anne Hathaway"}]         NaN      55149435
# tt2582802   [{"name": "Miles Teller"}]  13092000.0       9792000

# %%
df.loc[['tt2637294','tt0368933']]
# Out:
#                               belongs_to_collection    budget  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2  14000000
# tt0368933  The Princess Diaries 2: Royal Engagement  40000000
#
#                                             genres homepage original_language  \
# imdb_id
# tt2637294                     [{"name": "Comedy"}]      NaN                en
# tt0368933  [{"name": "Comedy"}, {"name": "Drama"}]      NaN                en
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
#
#                                     overview  popularity  \
# imdb_id
# tt2637294                Time travel comedy.    6.575393
# tt0368933  A princess prepares for marriage.    8.248895
#
#                          production_companies    production_countries  \
# imdb_id
# tt2637294    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# tt0368933  [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]
#
#           release_date  runtime       spoken_languages    status  \
# imdb_id
# tt2637294      2/20/15     93.0  [{"name": "English"}]  Released
# tt0368933       8/6/04    113.0  [{"name": "English"}]  Released
#
#                                              tagline  \
# imdb_id
# tt2637294                 The Laws of Space and Time
# tt0368933  It can take a lifetime to find true love.
#
#                                               title          Keywords  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2       time travel
# tt0368933  The Princess Diaries 2: Royal Engagement  princess|royalty
#
#                                   cast  revenue  movie_profit
# imdb_id
# tt2637294    [{"name": "Rob Corddry"}]      NaN      -1685349
# tt0368933  [{"name": "Anne Hathaway"}]      NaN      55149435

# %%
df.head()
# Out:
#                               belongs_to_collection    budget  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2  14000000
# tt0368933  The Princess Diaries 2: Royal Engagement  40000000
# tt2582802                                  Whiplash   3300000
# tt1821480                                   Kahaani   1200000
# tt1380152                                Marine Boy         0
#
#                                                genres  \
# imdb_id
# tt2637294                        [{"name": "Comedy"}]
# tt0368933     [{"name": "Comedy"}, {"name": "Drama"}]
# tt2582802                         [{"name": "Drama"}]
# tt1821480   [{"name": "Thriller"}, {"name": "Drama"}]
# tt1380152  [{"name": "Action"}, {"name": "Thriller"}]
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# tt0368933                                NaN                en
# tt2582802  http://sonyclassics.com/whiplash/                en
# tt1821480         http://kahaanithefilm.com/                hi
# tt1380152                                NaN                ko
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                Marine Boy
#
#                                                     overview  popularity  \
# imdb_id
# tt2637294                                Time travel comedy.    6.575393
# tt0368933                  A princess prepares for marriage.    8.248895
# tt2582802       A young drummer faces a ruthless instructor.   64.299990
# tt1821480  A woman searches for her missing husband in Ko...    3.174936
# tt1380152        A former swimmer becomes involved in crime.    1.148070
#
#                          production_companies    production_countries  \
# imdb_id
# tt2637294    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# tt0368933  [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]
# tt2582802            [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]
# tt1821480                                 NaN  [{"iso_3166_1": "IN"}]
# tt1380152                                 NaN  [{"iso_3166_1": "KR"}]
#
#           release_date  runtime             spoken_languages    status  \
# imdb_id
# tt2637294      2/20/15     93.0        [{"name": "English"}]  Released
# tt0368933       8/6/04    113.0        [{"name": "English"}]  Released
# tt2582802     10/10/14    105.0        [{"name": "English"}]  Released
# tt1821480       3/9/12    122.0  [{"name": "English|Hindi"}]  Released
# tt1380152       2/5/09    118.0         [{"name": "Korean"}]  Released
#
#                                                    tagline  \
# imdb_id
# tt2637294                       The Laws of Space and Time
# tt0368933        It can take a lifetime to find true love.
# tt2582802  The road to greatness can take you to the edge.
# tt1821480                                              NaN
# tt1380152                                              NaN
#
#                                               title          Keywords  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2       time travel
# tt0368933  The Princess Diaries 2: Royal Engagement  princess|royalty
# tt2582802                                  Whiplash        jazz|music
# tt1821480                                   Kahaani   mystery|kolkata
# tt1380152                                Marine Boy               NaN
#
#                                   cast     revenue  movie_profit
# imdb_id
# tt2637294    [{"name": "Rob Corddry"}]         NaN      -1685349
# tt0368933  [{"name": "Anne Hathaway"}]         NaN      55149435
# tt2582802   [{"name": "Miles Teller"}]  13092000.0       9792000
# tt1821480    [{"name": "Vidya Balan"}]  16000000.0      14800000
# tt1380152   [{"name": "Kim Kang-woo"}]   3923970.0       3923970

# %%
df['runtime'].sum()
# Out:
# np.float64(3846.0)

# %%
df.head(1)
# Out:
#           belongs_to_collection    budget                genres  \
# runtime
# 93.0     Hot Tub Time Machine 2  14000000  [{"name": "Comedy"}]
#
#         original_language          original_title             overview  \
# runtime
# 93.0                   en  Hot Tub Time Machine 2  Time travel comedy.
#
#          popularity              production_companies    production_countries  \
# runtime
# 93.0       6.575393  [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
#
#         release_date       spoken_languages    status  \
# runtime
# 93.0      2015-02-20  [{"name": "English"}]  Released
#
#                             tagline                   title     Keywords  \
# runtime
# 93.0     The Laws of Space and Time  Hot Tub Time Machine 2  time travel
#
#                               cast  revenue  movie_profit
# runtime
# 93.0     [{"name": "Rob Corddry"}]      NaN      -1685349

# %%
print(f" The shortest popularity movie  is {df['popularity'].min()}")
print(f" The largest high  popularity movie  is {df['popularity'].max()}")
# Out:
#  The shortest popularity movie  is 1.14807
#  The largest high  popularity movie  is 95.3

# %%
df[df['original_language']== "hi"]
# Out:
#                belongs_to_collection     budget  \
# runtime
# 122.0                        Kahaani    1200000
# 170.0                       3 Idiots  550000000
# 161.0                         Dangal   70000000
# 0.0                 3 Idiots Returns   80000000
# 181.0    Dilwale Dulhania Le Jayenge   40000000
#
#                                             genres original_language  \
# runtime
# 122.0    [{"name": "Thriller"}, {"name": "Drama"}]                hi
# 170.0      [{"name": "Comedy"}, {"name": "Drama"}]                hi
# 161.0       [{"name": "Drama"}, {"name": "Sport"}]                hi
# 0.0        [{"name": "Comedy"}, {"name": "Drama"}]                hi
# 181.0     [{"name": "Drama"}, {"name": "Romance"}]                hi
#
#                       original_title  \
# runtime
# 122.0                        Kahaani
# 170.0                       3 Idiots
# 161.0                         Dangal
# 0.0                 3 Idiots Returns
# 181.0    Dilwale Dulhania Le Jayenge
#
#                                                   overview  popularity  \
# runtime
# 122.0    A woman searches for her missing husband in Ko...    3.174936
# 170.0             Three friends navigate college and life.   25.300000
# 161.0    A father trains his daughters to become wrestl...   35.400000
# 0.0                   Friends reunite years after college.   18.200000
# 181.0       A young couple challenges family expectations.   20.600000
#
#                          production_companies    production_countries  \
# runtime
# 122.0        [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "IN"}]
# 170.0        [{"name": "Vinod Chopra Films"}]  [{"iso_3166_1": "IN"}]
# 161.0    [{"name": "Aamir Khan Productions"}]  [{"iso_3166_1": "IN"}]
# 0.0                [{"name": "Demo Studios"}]  [{"iso_3166_1": "IN"}]
# 181.0            [{"name": "Yash Raj Films"}]  [{"iso_3166_1": "IN"}]
#
#         release_date             spoken_languages    status  \
# runtime
# 122.0     2012-03-09  [{"name": "English|Hindi"}]  Released
# 170.0     2009-12-25          [{"name": "Hindi"}]  Released
# 161.0     2016-12-23          [{"name": "Hindi"}]  Released
# 0.0       2020-08-15          [{"name": "Hindi"}]   Rumored
# 181.0     1995-10-20          [{"name": "Hindi"}]  Released
#
#                              tagline                        title  \
# runtime
# 122.0    Act like you own the place.                      Kahaani
# 170.0                   All is well.                     3 Idiots
# 161.0    Gold is pure. So is Dangal.                       Dangal
# 0.0      Act like you own the place.             3 Idiots Returns
# 181.0          Come... Fall in love.  Dilwale Dulhania Le Jayenge
#
#                    Keywords                          cast       revenue  \
# runtime
# 122.0       mystery|kolkata     [{"name": "Vidya Balan"}]  1.600000e+07
# 170.0    college|friendship      [{"name": "Aamir Khan"}]  2.000000e+09
# 161.0      wrestling|family      [{"name": "Aamir Khan"}]  3.100000e+08
# 0.0                 college      [{"name": "Aamir Khan"}]  0.000000e+00
# 181.0        romance|family  [{"name": "Shah Rukh Khan"}]  1.200000e+08
#
#          movie_profit
# runtime
# 122.0        14800000
# 170.0      1450000000
# 161.0       240000000
# 0.0         -80000000
# 181.0        80000000

# %% [markdown]
# # **<code>apply()</code>** method applies a function to every row in a pandas dataframe

# %%
# Suppose we want to convert the column network to uppercase

def to_uppercase(column):
  return column.upper()

# %%
df['Capitalized_title'] = df['title'].apply(to_uppercase)

# %%
df.head()
# Out:
#                             belongs_to_collection    budget  \
# runtime
# 93.0                       Hot Tub Time Machine 2  14000000
# 113.0    The Princess Diaries 2: Royal Engagement  40000000
# 105.0                                    Whiplash   3300000
# 122.0                                     Kahaani   1200000
# 118.0                                  Marine Boy         0
#
#                                              genres original_language  \
# runtime
# 93.0                           [{"name": "Comedy"}]                en
# 113.0       [{"name": "Comedy"}, {"name": "Drama"}]                en
# 105.0                           [{"name": "Drama"}]                en
# 122.0     [{"name": "Thriller"}, {"name": "Drama"}]                hi
# 118.0    [{"name": "Action"}, {"name": "Thriller"}]                ko
#
#                                    original_title  \
# runtime
# 93.0                       Hot Tub Time Machine 2
# 113.0    The Princess Diaries 2: Royal Engagement
# 105.0                                    Whiplash
# 122.0                                     Kahaani
# 118.0                                  Marine Boy
#
#                                                   overview  popularity  \
# runtime
# 93.0                                   Time travel comedy.    6.575393
# 113.0                    A princess prepares for marriage.    8.248895
# 105.0         A young drummer faces a ruthless instructor.   64.299990
# 122.0    A woman searches for her missing husband in Ko...    3.174936
# 118.0          A former swimmer becomes involved in crime.    1.148070
#
#                        production_companies    production_countries  \
# runtime
# 93.0       [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# 113.0    [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]
# 105.0              [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]
# 122.0      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "IN"}]
# 118.0      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "KR"}]
#
#         release_date             spoken_languages    status  \
# runtime
# 93.0      2015-02-20        [{"name": "English"}]  Released
# 113.0     2004-08-06        [{"name": "English"}]  Released
# 105.0     2014-10-10        [{"name": "English"}]  Released
# 122.0     2012-03-09  [{"name": "English|Hindi"}]  Released
# 118.0     2009-02-05         [{"name": "Korean"}]  Released
#
#                                                  tagline  \
# runtime
# 93.0                          The Laws of Space and Time
# 113.0          It can take a lifetime to find true love.
# 105.0    The road to greatness can take you to the edge.
# 122.0                        Act like you own the place.
# 118.0                        Act like you own the place.
#
#                                             title          Keywords  \
# runtime
# 93.0                       Hot Tub Time Machine 2       time travel
# 113.0    The Princess Diaries 2: Royal Engagement  princess|royalty
# 105.0                                    Whiplash        jazz|music
# 122.0                                     Kahaani   mystery|kolkata
# 118.0                                  Marine Boy    CIA|conspiracy
#
#                                 cast     revenue  movie_profit  \
# runtime
# 93.0       [{"name": "Rob Corddry"}]         NaN      -1685349
# 113.0    [{"name": "Anne Hathaway"}]         NaN      55149435
# 105.0     [{"name": "Miles Teller"}]  13092000.0       9792000
# 122.0      [{"name": "Vidya Balan"}]  16000000.0      14800000
# 118.0     [{"name": "Kim Kang-woo"}]   3923970.0       3923970
#
#                                 Capitalized_title
# runtime
# 93.0                       HOT TUB TIME MACHINE 2
# 113.0    THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# 105.0                                    WHIPLASH
# 122.0                                     KAHAANI
# 118.0                                  MARINE BOY

# %% [markdown]
# ## Another way to use <code>apply()</code> involves the use of <code>lambda()</code> function.
#
# * ### A <code>lambda()</code> function is a small anonymous function.
# * ### A <code>lambda()</code> function can take any number of arguments, but can only have one expression.

# %%
def add_two_numbers(a,b):
  return a+b

# %%
x = lambda a,b : a+b
x(1,5)
# Out:
# 6

# %%
# lambda function - Row wise operation
def revised_profit(revenue, budget):
  if revenue > 0:
    new_profit = revenue - budget
  else:
    new_profit = np.nan

  return new_profit

# %%
df['new_profit'] = df.apply(lambda x: revised_profit(x['revenue'], x['budget']),axis=1)

# %%
df.head()
# Out:
#                             belongs_to_collection    budget  \
# runtime
# 93.0                       Hot Tub Time Machine 2  14000000
# 113.0    The Princess Diaries 2: Royal Engagement  40000000
# 105.0                                    Whiplash   3300000
# 122.0                                     Kahaani   1200000
# 118.0                                  Marine Boy         0
#
#                                              genres original_language  \
# runtime
# 93.0                           [{"name": "Comedy"}]                en
# 113.0       [{"name": "Comedy"}, {"name": "Drama"}]                en
# 105.0                           [{"name": "Drama"}]                en
# 122.0     [{"name": "Thriller"}, {"name": "Drama"}]                hi
# 118.0    [{"name": "Action"}, {"name": "Thriller"}]                ko
#
#                                    original_title  \
# runtime
# 93.0                       Hot Tub Time Machine 2
# 113.0    The Princess Diaries 2: Royal Engagement
# 105.0                                    Whiplash
# 122.0                                     Kahaani
# 118.0                                  Marine Boy
#
#                                                   overview  popularity  \
# runtime
# 93.0                                   Time travel comedy.    6.575393
# 113.0                    A princess prepares for marriage.    8.248895
# 105.0         A young drummer faces a ruthless instructor.   64.299990
# 122.0    A woman searches for her missing husband in Ko...    3.174936
# 118.0          A former swimmer becomes involved in crime.    1.148070
#
#                        production_companies    production_countries  \
# runtime
# 93.0       [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# 113.0    [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]
# 105.0              [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]
# 122.0      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "IN"}]
# 118.0      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "KR"}]
#
#         release_date             spoken_languages    status  \
# runtime
# 93.0      2015-02-20        [{"name": "English"}]  Released
# 113.0     2004-08-06        [{"name": "English"}]  Released
# 105.0     2014-10-10        [{"name": "English"}]  Released
# 122.0     2012-03-09  [{"name": "English|Hindi"}]  Released
# 118.0     2009-02-05         [{"name": "Korean"}]  Released
#
#                                                  tagline  \
# runtime
# 93.0                          The Laws of Space and Time
# 113.0          It can take a lifetime to find true love.
# 105.0    The road to greatness can take you to the edge.
# 122.0                        Act like you own the place.
# 118.0                        Act like you own the place.
#
#                                             title          Keywords  \
# runtime
# 93.0                       Hot Tub Time Machine 2       time travel
# 113.0    The Princess Diaries 2: Royal Engagement  princess|royalty
# 105.0                                    Whiplash        jazz|music
# 122.0                                     Kahaani   mystery|kolkata
# 118.0                                  Marine Boy    CIA|conspiracy
#
#                                 cast     revenue  movie_profit  \
# runtime
# 93.0       [{"name": "Rob Corddry"}]         NaN      -1685349
# 113.0    [{"name": "Anne Hathaway"}]         NaN      55149435
# 105.0     [{"name": "Miles Teller"}]  13092000.0       9792000
# 122.0      [{"name": "Vidya Balan"}]  16000000.0      14800000
# 118.0     [{"name": "Kim Kang-woo"}]   3923970.0       3923970
#
#                                 Capitalized_title  new_profit
# runtime
# 93.0                       HOT TUB TIME MACHINE 2         NaN
# 113.0    THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT         NaN
# 105.0                                    WHIPLASH   9792000.0
# 122.0                                     KAHAANI  14800000.0
# 118.0                                  MARINE BOY   3923970.0

# %% [markdown]
# ## We can also sort our dataframe by some column values in either an ascending or descending order

# %%
# Sort values in descending order
df.sort_values('popularity', ascending=False)
# Out:
#                               belongs_to_collection     budget  \
# runtime
# 175.00000                             The Godfather    6000000
# 152.00000                           The Dark Knight  185000000
# 181.00000                         Avengers: Endgame  356000000
# 148.00000                                 Inception  160000000
# 194.00000                                   Titanic  200000000
# 169.00000                              Interstellar  165000000
# 125.00000                             Spirited Away   19000000
# 122.00000                                     Joker   55000000
# 105.00000                                  Whiplash    3300000
# 187.00000                                       RRR  550000000
# 132.00000                                  Parasite   11400000
# 168.00000                Bahubali 2: The Conclusion  250000000
# 148.00000                                   Kantara   16000000
# 128.00000                                La La Land   30000000
# 161.00000                                    Dangal   70000000
# 170.00000                                  3 Idiots  550000000
# 181.00000               Dilwale Dulhania Le Jayenge   40000000
# 0.00000                            3 Idiots Returns   80000000
# 90.00000                           Along Came Polly   42000000
# 120.00000                   The Long Kiss Goodnight   65000000
# 128.00000                              The Terminal   60000000
# 132.62069                             Mystery Movie   25000000
# 106.00000                                 Abduction   35000000
# 102.00000                                   Chasers          0
# 113.00000  The Princess Diaries 2: Royal Engagement   40000000
# 106.00000                               School Ties          0
# 93.00000                     Hot Tub Time Machine 2   14000000
# 102.00000                          We Are the Best!          0
# 122.00000                                   Kahaani    1200000
# 118.00000                                Marine Boy          0
#
#                                                       genres  \
# runtime
# 175.00000             [{"name": "Crime"}, {"name": "Drama"}]
# 152.00000  [{"name": "Action"}, {"name": "Crime"}, {"name...
# 181.00000  [{"name": "Action"}, {"name": "Adventure"}, {"...
# 148.00000           [{"name": "Action"}, {"name": "Sci-Fi"}]
# 194.00000           [{"name": "Drama"}, {"name": "Romance"}]
# 169.00000  [{"name": "Adventure"}, {"name": "Drama"}, {"n...
# 125.00000       [{"name": "Animation"}, {"name": "Fantasy"}]
# 122.00000             [{"name": "Crime"}, {"name": "Drama"}]
# 105.00000                                [{"name": "Drama"}]
# 187.00000            [{"name": "Action"}, {"name": "Drama"}]
# 132.00000          [{"name": "Drama"}, {"name": "Thriller"}]
# 168.00000            [{"name": "Action"}, {"name": "Drama"}]
# 148.00000            [{"name": "Action"}, {"name": "Drama"}]
# 128.00000  [{"name": "Comedy"}, {"name": "Drama"}, {"name...
# 161.00000             [{"name": "Drama"}, {"name": "Sport"}]
# 170.00000            [{"name": "Comedy"}, {"name": "Drama"}]
# 181.00000           [{"name": "Drama"}, {"name": "Romance"}]
# 0.00000              [{"name": "Comedy"}, {"name": "Drama"}]
# 90.00000           [{"name": "Comedy"}, {"name": "Romance"}]
# 120.00000            [{"name": "Crime"}, {"name": "Action"}]
# 128.00000            [{"name": "Comedy"}, {"name": "Drama"}]
# 132.62069            [{"name": "Comedy"}, {"name": "Drama"}]
# 106.00000         [{"name": "Thriller"}, {"name": "Action"}]
# 102.00000          [{"name": "Comedy"}, {"name": "Romance"}]
# 113.00000            [{"name": "Comedy"}, {"name": "Drama"}]
# 106.00000                                [{"name": "Drama"}]
# 93.00000                                [{"name": "Comedy"}]
# 102.00000             [{"name": "Drama"}, {"name": "Music"}]
# 122.00000          [{"name": "Thriller"}, {"name": "Drama"}]
# 118.00000         [{"name": "Action"}, {"name": "Thriller"}]
#
#           original_language                            original_title  \
# runtime
# 175.00000                en                             The Godfather
# 152.00000                en                           The Dark Knight
# 181.00000                en                         Avengers: Endgame
# 148.00000                en                                 Inception
# 194.00000                en                                   Titanic
# 169.00000                en                              Interstellar
# 125.00000                ja                             Spirited Away
# 122.00000                en                                     Joker
# 105.00000                en                                  Whiplash
# 187.00000                te                                       RRR
# 132.00000                ko                                  Parasite
# 168.00000                te               Baahubali 2: The Conclusion
# 148.00000                kn                                   Kantara
# 128.00000                en                                La La Land
# 161.00000                hi                                    Dangal
# 170.00000                hi                                  3 Idiots
# 181.00000                hi               Dilwale Dulhania Le Jayenge
# 0.00000                  hi                          3 Idiots Returns
# 90.00000                 en                          Along Came Polly
# 120.00000                en                   The Long Kiss Goodnight
# 128.00000                en                              The Terminal
# 132.62069                en                             Mystery Movie
# 106.00000                en                                 Abduction
# 102.00000                en                                   Chasers
# 113.00000                en  The Princess Diaries 2: Royal Engagement
# 106.00000                en                               School Ties
# 93.00000                 en                    Hot Tub Time Machine 2
# 102.00000                sv                          We Are the Best!
# 122.00000                hi                                   Kahaani
# 118.00000                ko                                Marine Boy
#
#                                                     overview  popularity  \
# runtime
# 175.00000  The aging patriarch transfers control of his e...   95.300000
# 152.00000                            Batman faces the Joker.   90.100000
# 181.00000      Heroes attempt to reverse a devastating loss.   88.200000
# 148.00000            A thief enters dreams to steal secrets.   82.500000
# 194.00000            A romance unfolds aboard a doomed ship.   78.500000
# 169.00000      Explorers travel through a wormhole in space.   75.000000
# 125.00000           A girl enters a mysterious spirit world.   72.100000
# 122.00000             A failed comedian descends into chaos.   70.900000
# 105.00000       A young drummer faces a ruthless instructor.   64.299990
# 187.00000   Two revolutionaries form an unlikely friendship.   60.300000
# 132.00000  Two families become entangled in a strange sit...   55.700000
# 168.00000               A kingdom seeks answers and revenge.   52.900000
# 148.00000  A village conflict involving tradition and nat...   42.700000
# 128.00000  A musician and actress pursue dreams in Los An...   35.800000
# 161.00000  A father trains his daughters to become wrestl...   35.400000
# 170.00000           Three friends navigate college and life.   25.300000
# 181.00000     A young couple challenges family expectations.   20.600000
# 0.00000                 Friends reunite years after college.   18.200000
# 90.00000               A cautious man finds unexpected love.   15.725542
# 120.00000              A woman discovers her forgotten past.   14.482345
# 128.00000              A man becomes stranded in an airport.   14.092373
# 132.62069                A mystery with incomplete metadata.   12.500000
# 106.00000  A young man searches for the truth about his i...   10.512109
# 102.00000                Two military men escort a prisoner.    9.853270
# 113.00000                  A princess prepares for marriage.    8.248895
# 106.00000      A student faces prejudice at an elite school.    7.438381
# 93.00000                                 Time travel comedy.    6.575393
# 102.00000                      Three girls form a punk band.    3.727996
# 122.00000  A woman searches for her missing husband in Ko...    3.174936
# 118.00000        A former swimmer becomes involved in crime.    1.148070
#
#                            production_companies    production_countries  \
# runtime
# 175.00000      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# 152.00000            [{"name": "Warner Bros."}]  [{"iso_3166_1": "US"}]
# 181.00000          [{"name": "Marvel Studios"}]  [{"iso_3166_1": "US"}]
# 148.00000            [{"name": "Warner Bros."}]  [{"iso_3166_1": "US"}]
# 194.00000        [{"name": "20th Century Fox"}]  [{"iso_3166_1": "US"}]
# 169.00000      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# 125.00000           [{"name": "Studio Ghibli"}]  [{"iso_3166_1": "JP"}]
# 122.00000            [{"name": "Warner Bros."}]  [{"iso_3166_1": "US"}]
# 105.00000              [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]
# 187.00000       [{"name": "DVV Entertainment"}]  [{"iso_3166_1": "IN"}]
# 132.00000            [{"name": "Barunson E&A"}]  [{"iso_3166_1": "KR"}]
# 168.00000        [{"name": "Arka Media Works"}]  [{"iso_3166_1": "IN"}]
# 148.00000           [{"name": "Hombale Films"}]  [{"iso_3166_1": "IN"}]
# 128.00000               [{"name": "Lionsgate"}]  [{"iso_3166_1": "US"}]
# 161.00000  [{"name": "Aamir Khan Productions"}]  [{"iso_3166_1": "IN"}]
# 170.00000      [{"name": "Vinod Chopra Films"}]  [{"iso_3166_1": "IN"}]
# 181.00000          [{"name": "Yash Raj Films"}]  [{"iso_3166_1": "IN"}]
# 0.00000              [{"name": "Demo Studios"}]  [{"iso_3166_1": "IN"}]
# 90.00000             [{"name": "Jersey Films"}]  [{"iso_3166_1": "US"}]
# 120.00000         [{"name": "New Line Cinema"}]  [{"iso_3166_1": "US"}]
# 128.00000          [{"name": "DreamWorks SKG"}]  [{"iso_3166_1": "US"}]
# 132.62069      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# 106.00000        [{"name": "Lions Gate Films"}]  [{"iso_3166_1": "US"}]
# 102.00000            [{"name": "Warner Bros."}]  [{"iso_3166_1": "US"}]
# 113.00000    [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]
# 106.00000      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# 93.00000       [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# 102.00000             [{"name": "Memfis Film"}]  [{"iso_3166_1": "SE"}]
# 122.00000      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "IN"}]
# 118.00000      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "KR"}]
#
#           release_date             spoken_languages    status  \
# runtime
# 175.00000   2072-03-24        [{"name": "English"}]  Released
# 152.00000   2008-07-18        [{"name": "English"}]  Released
# 181.00000   2019-04-26        [{"name": "English"}]  Released
# 148.00000   2010-07-16        [{"name": "English"}]  Released
# 194.00000   1997-12-19        [{"name": "English"}]  Released
# 169.00000   2014-11-07        [{"name": "English"}]  Released
# 125.00000   2001-07-20       [{"name": "Japanese"}]  Released
# 122.00000   2019-10-04        [{"name": "English"}]  Released
# 105.00000   2014-10-10        [{"name": "English"}]  Released
# 187.00000   2022-03-25         [{"name": "Telugu"}]  Released
# 132.00000   2019-05-30         [{"name": "Korean"}]  Released
# 168.00000   2017-04-28         [{"name": "Telugu"}]  Released
# 148.00000   2022-09-30        [{"name": "Kannada"}]  Released
# 128.00000   2016-12-25        [{"name": "English"}]  Released
# 161.00000   2016-12-23          [{"name": "Hindi"}]  Released
# 170.00000   2009-12-25          [{"name": "Hindi"}]  Released
# 181.00000   1995-10-20          [{"name": "Hindi"}]  Released
# 0.00000     2020-08-15          [{"name": "Hindi"}]   Rumored
# 90.00000    2004-01-16        [{"name": "English"}]  Released
# 120.00000   1996-10-11        [{"name": "English"}]  Released
# 128.00000   2004-06-17        [{"name": "English"}]  Released
# 132.62069   2018-10-10        [{"name": "English"}]  Released
# 106.00000   2011-09-22        [{"name": "English"}]  Released
# 102.00000   1994-04-22        [{"name": "English"}]  Released
# 113.00000   2004-08-06        [{"name": "English"}]  Released
# 106.00000   1992-09-18        [{"name": "English"}]  Released
# 93.00000    2015-02-20        [{"name": "English"}]  Released
# 102.00000   2013-03-28        [{"name": "Swedish"}]  Released
# 122.00000   2012-03-09  [{"name": "English|Hindi"}]  Released
# 118.00000   2009-02-05         [{"name": "Korean"}]  Released
#
#                                                      tagline  \
# runtime
# 175.00000                         An offer you can't refuse.
# 152.00000                                    Why so serious?
# 181.00000                                 Avenge the fallen.
# 148.00000               Your mind is the scene of the crime.
# 194.00000          Nothing on Earth could come between them.
# 169.00000  Mankind was born on Earth. It was never meant ...
# 125.00000       The tunnel led Chihiro to a mysterious town.
# 122.00000                               Put on a happy face.
# 105.00000    The road to greatness can take you to the edge.
# 187.00000                                Rise. Roar. Revolt.
# 132.00000                        Act like you own the place.
# 168.00000                   Why did Kattappa kill Baahubali?
# 148.00000             When tradition calls, destiny answers.
# 128.00000                     Here's to the fools who dream.
# 161.00000                        Gold is pure. So is Dangal.
# 170.00000                                       All is well.
# 181.00000                              Come... Fall in love.
# 0.00000                          Act like you own the place.
# 90.00000   For the most cautious man on Earth, life is ab...
# 120.00000               What's forgotten is not always gone.
# 128.00000                                   Life is waiting.
# 132.62069                        Act like you own the place.
# 106.00000          They stole his life. He's taking it back.
# 102.00000  It was supposed to be a routine prisoner trans...
# 113.00000          It can take a lifetime to find true love.
# 106.00000  Just because you’re accepted doesn’t mean you ...
# 93.00000                          The Laws of Space and Time
# 102.00000                        Act like you own the place.
# 122.00000                        Act like you own the place.
# 118.00000                        Act like you own the place.
#
#                                               title               Keywords  \
# runtime
# 175.00000                             The Godfather           mafia|family
# 152.00000                           The Dark Knight           joker|batman
# 181.00000                         Avengers: Endgame       superhero|marvel
# 148.00000                                 Inception            dream|heist
# 194.00000                                   Titanic           ship|romance
# 169.00000                              Interstellar         space|wormhole
# 125.00000                             Spirited Away           spirit|magic
# 122.00000                                     Joker            joker|crime
# 105.00000                                  Whiplash             jazz|music
# 187.00000                                       RRR  friendship|revolution
# 132.00000                                  Parasite           family|class
# 168.00000               Baahubali 2: The Conclusion            kingdom|war
# 148.00000                                   Kantara      village|tradition
# 128.00000                                La La Land      music|los angeles
# 161.00000                                    Dangal       wrestling|family
# 170.00000                                  3 Idiots     college|friendship
# 181.00000               Dilwale Dulhania Le Jayenge         romance|family
# 0.00000                            3 Idiots Returns                college
# 90.00000                           Along Came Polly             beach|love
# 120.00000                   The Long Kiss Goodnight   assassination|memory
# 128.00000                              The Terminal       airport|new york
# 132.62069                             Mystery Movie                mystery
# 106.00000                                 Abduction         CIA|conspiracy
# 102.00000                                   Chasers        prison|military
# 113.00000  The Princess Diaries 2: Royal Engagement       princess|royalty
# 106.00000                               School Ties           school|sport
# 93.00000                     Hot Tub Time Machine 2            time travel
# 102.00000                          We Are the Best!            sweden|punk
# 122.00000                                   Kahaani        mystery|kolkata
# 118.00000                                Marine Boy         CIA|conspiracy
#
#                                         cast       revenue  movie_profit  \
# runtime
# 175.00000        [{"name": "Marlon Brando"}]  2.500000e+08     244000000
# 152.00000       [{"name": "Christian Bale"}]  1.004558e+09     819558444
# 181.00000    [{"name": "Robert Downey Jr."}]  2.797501e+09    2441501328
# 148.00000    [{"name": "Leonardo DiCaprio"}]  8.390000e+08     679000000
# 194.00000    [{"name": "Leonardo DiCaprio"}]  2.264743e+09    2064743305
# 169.00000  [{"name": "Matthew McConaughey"}]  7.017292e+08     536729206
# 125.00000         [{"name": "Rumi Hiiragi"}]  3.958000e+08     376800000
# 122.00000      [{"name": "Joaquin Phoenix"}]  1.074251e+09    1019251311
# 105.00000         [{"name": "Miles Teller"}]  1.309200e+07       9792000
# 187.00000   [{"name": "N. T. Rama Rao Jr."}]  1.200000e+09     650000000
# 132.00000         [{"name": "Song Kang-ho"}]  2.580000e+08     246600000
# 168.00000              [{"name": "Prabhas"}]  1.810000e+09    1560000000
# 148.00000        [{"name": "Rishab Shetty"}]  4.000000e+08     384000000
# 128.00000         [{"name": "Ryan Gosling"}]  4.720000e+08     442000000
# 161.00000           [{"name": "Aamir Khan"}]  3.100000e+08     240000000
# 170.00000           [{"name": "Aamir Khan"}]  2.000000e+09    1450000000
# 181.00000       [{"name": "Shah Rukh Khan"}]  1.200000e+08      80000000
# 0.00000             [{"name": "Aamir Khan"}]  0.000000e+00     -80000000
# 90.00000           [{"name": "Ben Stiller"}]  1.719634e+08     129963386
# 120.00000          [{"name": "Geena Davis"}]  8.945676e+07      24456761
# 128.00000            [{"name": "Tom Hanks"}]  2.194173e+08     159417255
# 132.62069              [{"name": "Unknown"}]  4.500000e+07      20000000
# 106.00000       [{"name": "Taylor Lautner"}]  8.208716e+07      47087155
# 102.00000         [{"name": "Tom Berenger"}]  1.596687e+06       1596687
# 113.00000        [{"name": "Anne Hathaway"}]           NaN      55149435
# 106.00000       [{"name": "Brendan Fraser"}]  1.471507e+07      14715067
# 93.00000           [{"name": "Rob Corddry"}]           NaN      -1685349
# 102.00000      [{"name": "Mira Barkhammar"}]  1.805900e+05        180590
# 122.00000          [{"name": "Vidya Balan"}]  1.600000e+07      14800000
# 118.00000         [{"name": "Kim Kang-woo"}]  3.923970e+06       3923970
#
#                                   Capitalized_title    new_profit
# runtime
# 175.00000                             THE GODFATHER  2.440000e+08
# 152.00000                           THE DARK KNIGHT  8.195584e+08
# 181.00000                         AVENGERS: ENDGAME  2.441501e+09
# 148.00000                                 INCEPTION  6.790000e+08
# 194.00000                                   TITANIC  2.064743e+09
# 169.00000                              INTERSTELLAR  5.367292e+08
# 125.00000                             SPIRITED AWAY  3.768000e+08
# 122.00000                                     JOKER  1.019251e+09
# 105.00000                                  WHIPLASH  9.792000e+06
# 187.00000                                       RRR  6.500000e+08
# 132.00000                                  PARASITE  2.466000e+08
# 168.00000               BAAHUBALI 2: THE CONCLUSION  1.560000e+09
# 148.00000                                   KANTARA  3.840000e+08
# 128.00000                                LA LA LAND  4.420000e+08
# 161.00000                                    DANGAL  2.400000e+08
# 170.00000                                  3 IDIOTS  1.450000e+09
# 181.00000               DILWALE DULHANIA LE JAYENGE  8.000000e+07
# 0.00000                            3 IDIOTS RETURNS           NaN
# 90.00000                           ALONG CAME POLLY  1.299634e+08
# 120.00000                   THE LONG KISS GOODNIGHT  2.445676e+07
# 128.00000                              THE TERMINAL  1.594173e+08
# 132.62069                             MYSTERY MOVIE  2.000000e+07
# 106.00000                                 ABDUCTION  4.708716e+07
# 102.00000                                   CHASERS  1.596687e+06
# 113.00000  THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT           NaN
# 106.00000                               SCHOOL TIES  1.471507e+07
# 93.00000                     HOT TUB TIME MACHINE 2           NaN
# 102.00000                          WE ARE THE BEST!  1.805900e+05
# 122.00000                                   KAHAANI  1.480000e+07
# 118.00000                                MARINE BOY  3.923970e+06

# %%
# We can also sort by the combination of two columns
df.sort_values(['status','new_profit'], ascending=[False,True]).head()
# Out:
#         belongs_to_collection    budget  \
# runtime
# 0.0          3 Idiots Returns  80000000
# 102.0        We Are the Best!         0
# 102.0                 Chasers         0
# 118.0              Marine Boy         0
# 105.0                Whiplash   3300000
#
#                                              genres original_language  \
# runtime
# 0.0         [{"name": "Comedy"}, {"name": "Drama"}]                hi
# 102.0        [{"name": "Drama"}, {"name": "Music"}]                sv
# 102.0     [{"name": "Comedy"}, {"name": "Romance"}]                en
# 118.0    [{"name": "Action"}, {"name": "Thriller"}]                ko
# 105.0                           [{"name": "Drama"}]                en
#
#            original_title                                      overview  \
# runtime
# 0.0      3 Idiots Returns          Friends reunite years after college.
# 102.0    We Are the Best!                 Three girls form a punk band.
# 102.0             Chasers           Two military men escort a prisoner.
# 118.0          Marine Boy   A former swimmer becomes involved in crime.
# 105.0            Whiplash  A young drummer faces a ruthless instructor.
#
#          popularity              production_companies    production_countries  \
# runtime
# 0.0       18.200000        [{"name": "Demo Studios"}]  [{"iso_3166_1": "IN"}]
# 102.0      3.727996         [{"name": "Memfis Film"}]  [{"iso_3166_1": "SE"}]
# 102.0      9.853270        [{"name": "Warner Bros."}]  [{"iso_3166_1": "US"}]
# 118.0      1.148070  [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "KR"}]
# 105.0     64.299990          [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]
#
#         release_date       spoken_languages    status  \
# runtime
# 0.0       2020-08-15    [{"name": "Hindi"}]   Rumored
# 102.0     2013-03-28  [{"name": "Swedish"}]  Released
# 102.0     1994-04-22  [{"name": "English"}]  Released
# 118.0     2009-02-05   [{"name": "Korean"}]  Released
# 105.0     2014-10-10  [{"name": "English"}]  Released
#
#                                                    tagline             title  \
# runtime
# 0.0                            Act like you own the place.  3 Idiots Returns
# 102.0                          Act like you own the place.  We Are the Best!
# 102.0    It was supposed to be a routine prisoner trans...           Chasers
# 118.0                          Act like you own the place.        Marine Boy
# 105.0      The road to greatness can take you to the edge.          Whiplash
#
#                 Keywords                           cast     revenue  \
# runtime
# 0.0              college       [{"name": "Aamir Khan"}]         0.0
# 102.0        sweden|punk  [{"name": "Mira Barkhammar"}]    180590.0
# 102.0    prison|military     [{"name": "Tom Berenger"}]   1596687.0
# 118.0     CIA|conspiracy     [{"name": "Kim Kang-woo"}]   3923970.0
# 105.0         jazz|music     [{"name": "Miles Teller"}]  13092000.0
#
#          movie_profit Capitalized_title  new_profit
# runtime
# 0.0         -80000000  3 IDIOTS RETURNS         NaN
# 102.0          180590  WE ARE THE BEST!    180590.0
# 102.0         1596687           CHASERS   1596687.0
# 118.0         3923970        MARINE BOY   3923970.0
# 105.0         9792000          WHIPLASH   9792000.0

# %% [markdown]
# # <b>Let us explore some datetime operations and functions

# %% [markdown]
# Directive
#
# * #### <b>%a</b>	Weekday as locale’s abbreviated name.	Sun, Mon, …, Sat (en_US)
# So, Mo, …, Sa (de_DE)
# * #### <b>%A</b>	Weekday as locale’s full name.	Sunday, Monday, …, Saturday (en_US)
# Sonntag, Montag, …, Samstag (de_DE)
# * #### <b>%w</b>	Weekday as a decimal number, where 0 is Sunday and 6 is Saturday.	0, 1, 2, 3, 4, 5, 6
# * #### <b>%d</b>	Day of the month as a zero-padded decimal number.	01, 02, …, 31
# * #### <b>%b</b>	Month as locale’s abbreviated name.	Jan, Feb, …, Dec (en_US)
# Jan, Feb, …, Dez (de_DE)
# * #### <b>%B</b>	Month as locale’s full name.	January, February, …, December (en_US)
# Januar, Februar, …, Dezember (de_DE)
# * #### <b>%m</b>	Month as a zero-padded decimal number.	01, 02 … 12
# * #### <b>%y</b>	Year without century as a zero-padded decimal number.	01, 02, … 99
# * #### <b>%Y</b>	Year with century as a decimal number.	0001, 0002, … , 9999
# * #### <b>%H</b>	Hour (24-hour clock) as a zero-padded decimal number.	01, 02, … , 23
# * #### <b>%I</b>	Hour (12-hour clock) as a zero-padded decimal number.	01, 02, … , 12
# * #### <b>%p</b>	Locale’s equivalent of either AM or PM.	AM, PM (en_US)
# am, pm (de_DE)
# * #### <b>%M</b>	Minute as a zero-padded decimal number.	01, 02, … , 59
# * #### <b>%S</b>	Second as a zero-padded decimal number.	01, 02, … , 59
# * #### <b>%f</b>	Microsecond as a decimal number, zero-padded on the left.	000000, 000001, …, 999999

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 30 entries, tt2637294 to tt0112870
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  30 non-null     str
#  1   budget                 30 non-null     int64
#  2   genres                 29 non-null     str
#  3   homepage               9 non-null      str
#  4   original_language      30 non-null     str
#  5   original_title         30 non-null     str
#  6   overview               30 non-null     str
#  7   popularity             30 non-null     float64
#  8   production_companies   27 non-null     str
#  9   production_countries   30 non-null     str
#  10  release_date           30 non-null     str
#  11  runtime                29 non-null     float64
#  12  spoken_languages       30 non-null     str
#  13  status                 30 non-null     str
#  14  tagline                25 non-null     str
#  15  title                  30 non-null     str
#  16  Keywords               29 non-null     str
#  17  cast                   30 non-null     str
#  18  revenue                28 non-null     float64
#  19  movie_profit           30 non-null     int64
#  20  Capitalized_title      30 non-null     str
#  21  new_profit             27 non-null     float64
# dtypes: float64(4), int64(2), str(16)
# memory usage: 6.4+ KB

# %%
df['release_date'][0:5]
# Out:
# imdb_id
# tt2637294     2/20/15
# tt0368933      8/6/04
# tt2582802    10/10/14
# tt1821480      3/9/12
# tt1380152      2/5/09
# Name: release_date, dtype: str
