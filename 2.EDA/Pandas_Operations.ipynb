# %% [markdown]
# ## **Yesterday, we learnt a little about the very useful library Pandas widely used for Data Analysis. It is time to put the many utilities of this library in front of our eyes. We will be performing following manipulations and exploration of our data:**
#
# * ### Indexing and slicing operations
# * ### Manipulating columns
# * ### Exploring unique and missing values

# %%
# Import pandas package
import pandas as pd
import numpy as np

# %% [markdown]
# ## Let us read our data first

# %% [markdown]
# ### <u>Loading a CSV (Comma-Separated Values) file</u>

# %%
# loading csv File

df=pd.read_csv(r"C:\Users\LakshmanAIMLHYD\Desktop\AI&ML(7-8)\2.EDA\imdb_pandas_practice_dataset.csv")

df.head()
# Out:
#    id                     belongs_to_collection    budget  \
# 0   1                    Hot Tub Time Machine 2  14000000
# 1   2  The Princess Diaries 2: Royal Engagement  40000000
# 2   3                                  Whiplash   3300000
# 3   4                                   Kahaani   1200000
# 4   5                                Marine Boy         0
#
#                                        genres  \
# 0                        [{"name": "Comedy"}]
# 1     [{"name": "Comedy"}, {"name": "Drama"}]
# 2                         [{"name": "Drama"}]
# 3   [{"name": "Thriller"}, {"name": "Drama"}]
# 4  [{"name": "Action"}, {"name": "Thriller"}]
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  ...  \
# 0                                Time travel comedy.    6.575393  ...
# 1                  A princess prepares for marriage.    8.248895  ...
# 2       A young drummer faces a ruthless instructor.   64.299990  ...
# 3  A woman searches for her missing husband in Ko...    3.174936  ...
# 4        A former swimmer becomes involved in crime.    1.148070  ...
#
#   release_date runtime             spoken_languages    status  \
# 0      2/20/15    93.0        [{"name": "English"}]  Released
# 1       8/6/04   113.0        [{"name": "English"}]  Released
# 2     10/10/14   105.0        [{"name": "English"}]  Released
# 3       3/9/12   122.0  [{"name": "English|Hindi"}]  Released
# 4       2/5/09   118.0         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                                              NaN
# 4                                              NaN
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy               NaN
#
#                           cast  \
# 0    [{"name": "Rob Corddry"}]
# 1  [{"name": "Anne Hathaway"}]
# 2   [{"name": "Miles Teller"}]
# 3    [{"name": "Vidya Balan"}]
# 4   [{"name": "Kim Kang-woo"}]
#
#                                                crew   revenue
# 0       [{"name": "Steve Pink", "job": "Director"}]  12314651
# 1   [{"name": "Garry Marshall", "job": "Director"}]  95149435
# 2  [{"name": "Damien Chazelle", "job": "Director"}]  13092000
# 3      [{"name": "Sujoy Ghosh", "job": "Director"}]  16000000
# 4   [{"name": "Yoon Jong-chan", "job": "Director"}]   3923970
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df.shape
# Out:
# (30, 23)

# %%
df.tail()
# Out:
#     id        belongs_to_collection     budget  \
# 25  26                          RRR  550000000
# 26  27   Bahubali 2: The Conclusion  250000000
# 27  28                        Joker   55000000
# 28  29                   La La Land   30000000
# 29  30  Dilwale Dulhania Le Jayenge   40000000
#
#                                                genres homepage    imdb_id  \
# 25            [{"name": "Action"}, {"name": "Drama"}]      NaN  tt8178634
# 26            [{"name": "Action"}, {"name": "Drama"}]      NaN  tt4849438
# 27             [{"name": "Crime"}, {"name": "Drama"}]      NaN  tt7286456
# 28  [{"name": "Comedy"}, {"name": "Drama"}, {"name...      NaN  tt3783958
# 29           [{"name": "Drama"}, {"name": "Romance"}]      NaN  tt0112870
#
#    original_language               original_title  \
# 25                te                          RRR
# 26                te  Baahubali 2: The Conclusion
# 27                en                        Joker
# 28                en                   La La Land
# 29                hi  Dilwale Dulhania Le Jayenge
#
#                                              overview  popularity  ...  \
# 25   Two revolutionaries form an unlikely friendship.        60.3  ...
# 26               A kingdom seeks answers and revenge.        52.9  ...
# 27             A failed comedian descends into chaos.        70.9  ...
# 28  A musician and actress pursue dreams in Los An...        35.8  ...
# 29     A young couple challenges family expectations.        20.6  ...
#
#    release_date runtime       spoken_languages    status  \
# 25      3/25/22   187.0   [{"name": "Telugu"}]  Released
# 26      4/28/17   168.0   [{"name": "Telugu"}]  Released
# 27      10/4/19   122.0  [{"name": "English"}]  Released
# 28     12/25/16   128.0  [{"name": "English"}]  Released
# 29     10/20/95   181.0    [{"name": "Hindi"}]  Released
#
#                              tagline                        title  \
# 25               Rise. Roar. Revolt.                          RRR
# 26  Why did Kattappa kill Baahubali?  Baahubali 2: The Conclusion
# 27              Put on a happy face.                        Joker
# 28    Here's to the fools who dream.                   La La Land
# 29             Come... Fall in love.  Dilwale Dulhania Le Jayenge
#
#                  Keywords                              cast  \
# 25  friendship|revolution  [{"name": "N. T. Rama Rao Jr."}]
# 26            kingdom|war             [{"name": "Prabhas"}]
# 27            joker|crime     [{"name": "Joaquin Phoenix"}]
# 28      music|los angeles        [{"name": "Ryan Gosling"}]
# 29         romance|family      [{"name": "Shah Rukh Khan"}]
#
#                                                 crew     revenue
# 25  [{"name": "S. S. Rajamouli", "job": "Director"}]  1200000000
# 26  [{"name": "S. S. Rajamouli", "job": "Director"}]  1810000000
# 27    [{"name": "Todd Phillips", "job": "Director"}]  1074251311
# 28  [{"name": "Damien Chazelle", "job": "Director"}]   472000000
# 29    [{"name": "Aditya Chopra", "job": "Director"}]   120000000
#
# [5 rows x 23 columns]

# %%
df.production_countries.value_counts()
# Out:
# production_countries
# [{"iso_3166_1": "US"}]    18
# [{"iso_3166_1": "IN"}]     8
# [{"iso_3166_1": "KR"}]     2
# [{"iso_3166_1": "SE"}]     1
# [{"iso_3166_1": "JP"}]     1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     30 non-null     int64
#  1   belongs_to_collection  30 non-null     object
#  2   budget                 30 non-null     int64
#  3   genres                 29 non-null     object
#  4   homepage               9 non-null      object
#  5   imdb_id                30 non-null     object
#  6   original_language      30 non-null     object
#  7   original_title         30 non-null     object
#  8   overview               30 non-null     object
#  9   popularity             30 non-null     float64
#  10  poster_path            29 non-null     object
#  11  production_companies   27 non-null     object
#  12  production_countries   30 non-null     object
#  13  release_date           30 non-null     object
#  14  runtime                29 non-null     float64
#  15  spoken_languages       30 non-null     object
#  16  status                 30 non-null     object
#  17  tagline                25 non-null     object
#  18  title                  30 non-null     object
#  19  Keywords               29 non-null     object
#  20  cast                   30 non-null     object
#  21  crew                   30 non-null     object
#  22  revenue                30 non-null     int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 5.5+ KB

# %% [markdown]
# # **Data set info / data insights**
#
# - genres    has 1 null value
#
# - homepage has 21 null values
#
# - imdb_id  has datatype wrong
#
# - poster_path  has one missing value
#
# - release_date has wrong type of data
#
# - runtime  has one null value
#
# - tagline has 5 null values
#
# - Keywords has one null value

# %% [markdown]
# # <u>**<code>describe()</code>**</u>
#
# ## This method gives the overall descriptive summary of the dataframe. This works only for numerical columns

# %%
df.describe().T
# Out:
#             count          mean           std      min           25%  \
# id           30.0  1.550000e+01  8.803408e+00  1.00000  8.250000e+00
# budget       30.0  1.009633e+08  1.492895e+08  0.00000  1.205000e+07
# popularity   30.0  3.904264e+01  3.146144e+01  1.14807  1.100908e+01
# runtime      29.0  1.326207e+02  4.006371e+01  0.00000  1.060000e+02
# revenue      30.0  5.554160e+08  7.579332e+08  0.00000  2.325000e+07
#
#                      50%           75%           max
# id          1.550000e+01  2.275000e+01  3.000000e+01
# budget      4.000000e+07  1.400000e+08  5.500000e+08
# popularity  3.035000e+01  6.925000e+01  9.530000e+01
# runtime     1.280000e+02  1.680000e+02  1.940000e+02
# revenue     2.347086e+08  8.046823e+08  2.797501e+09

# %%
df.describe(include="object").T
# Out:
#                       count unique  \
# belongs_to_collection    30     30
# genres                   29     20
# homepage                  9      9
# imdb_id                  30     30
# original_language        30      7
# original_title           30     30
# overview                 30     30
# poster_path              29     29
# production_companies     27     21
# production_countries     30      5
# release_date             30     30
# spoken_languages         30      8
# status                   30      2
# tagline                  25     25
# title                    30     30
# Keywords                 29     29
# cast                     30     27
# crew                     30     26
#
#                                                                      top freq
# belongs_to_collection                             Hot Tub Time Machine 2    1
# genres                           [{"name": "Comedy"}, {"name": "Drama"}]    4
# homepage                               http://sonyclassics.com/whiplash/    1
# imdb_id                                                        tt2637294    1
# original_language                                                     en   18
# original_title                                    Hot Tub Time Machine 2    1
# overview                                             Time travel comedy.    1
# poster_path                                                 /poster1.jpg    1
# production_companies                    [{"name": "Paramount Pictures"}]    4
# production_countries                              [{"iso_3166_1": "US"}]   18
# release_date                                                     2/20/15    1
# spoken_languages                                   [{"name": "English"}]   18
# status                                                          Released   29
# tagline                                       The Laws of Space and Time    1
# title                                             Hot Tub Time Machine 2    1
# Keywords                                                     time travel    1
# cast                                            [{"name": "Aamir Khan"}]    3
# crew                   [{"name": "Christopher Nolan", "job": "Directo...    3

# %% [markdown]
# - column names

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %% [markdown]
# - check the duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#df.drop_duplicates()    # if duplicate exist we have to remove with this function

# %% [markdown]
# - check  Null values

# %%
df.isnull()
# Out:
#        id  belongs_to_collection  budget  genres  homepage  imdb_id  \
# 0   False                  False   False   False      True    False
# 1   False                  False   False   False      True    False
# 2   False                  False   False   False     False    False
# 3   False                  False   False   False     False    False
# 4   False                  False   False   False      True    False
# 5   False                  False   False   False     False    False
# 6   False                  False   False   False      True    False
# 7   False                  False   False   False     False    False
# 8   False                  False   False   False      True    False
# 9   False                  False   False   False     False    False
# 10  False                  False   False   False      True    False
# 11  False                  False   False   False      True    False
# 12  False                  False   False   False      True    False
# 13  False                  False   False   False      True    False
# 14  False                  False   False   False     False    False
# 15  False                  False   False   False     False    False
# 16  False                  False   False   False      True    False
# 17  False                  False   False   False      True    False
# 18  False                  False   False   False      True    False
# 19  False                  False   False   False      True    False
# 20  False                  False   False   False     False    False
# 21  False                  False   False   False      True    False
# 22  False                  False   False   False      True    False
# 23  False                  False   False    True      True    False
# 24  False                  False   False   False     False    False
# 25  False                  False   False   False      True    False
# 26  False                  False   False   False      True    False
# 27  False                  False   False   False      True    False
# 28  False                  False   False   False      True    False
# 29  False                  False   False   False      True    False
#
#     original_language  original_title  overview  popularity  ...  \
# 0               False           False     False       False  ...
# 1               False           False     False       False  ...
# 2               False           False     False       False  ...
# 3               False           False     False       False  ...
# 4               False           False     False       False  ...
# 5               False           False     False       False  ...
# 6               False           False     False       False  ...
# 7               False           False     False       False  ...
# 8               False           False     False       False  ...
# 9               False           False     False       False  ...
# 10              False           False     False       False  ...
# 11              False           False     False       False  ...
# 12              False           False     False       False  ...
# 13              False           False     False       False  ...
# 14              False           False     False       False  ...
# 15              False           False     False       False  ...
# 16              False           False     False       False  ...
# 17              False           False     False       False  ...
# 18              False           False     False       False  ...
# 19              False           False     False       False  ...
# 20              False           False     False       False  ...
# 21              False           False     False       False  ...
# 22              False           False     False       False  ...
# 23              False           False     False       False  ...
# 24              False           False     False       False  ...
# 25              False           False     False       False  ...
# 26              False           False     False       False  ...
# 27              False           False     False       False  ...
# 28              False           False     False       False  ...
# 29              False           False     False       False  ...
#
#     release_date  runtime  spoken_languages  status  tagline  title  Keywords  \
# 0          False    False             False   False    False  False     False
# 1          False    False             False   False    False  False     False
# 2          False    False             False   False    False  False     False
# 3          False    False             False   False     True  False     False
# 4          False    False             False   False     True  False      True
# 5          False    False             False   False    False  False     False
# 6          False    False             False   False    False  False     False
# 7          False    False             False   False    False  False     False
# 8          False    False             False   False    False  False     False
# 9          False    False             False   False    False  False     False
# 10         False    False             False   False    False  False     False
# 11         False    False             False   False    False  False     False
# 12         False    False             False   False     True  False     False
# 13         False    False             False   False    False  False     False
# 14         False    False             False   False    False  False     False
# 15         False    False             False   False    False  False     False
# 16         False    False             False   False    False  False     False
# 17         False    False             False   False    False  False     False
# 18         False    False             False   False    False  False     False
# 19         False    False             False   False    False  False     False
# 20         False    False             False   False    False  False     False
# 21         False    False             False   False    False  False     False
# 22         False    False             False   False     True  False     False
# 23         False     True             False   False     True  False     False
# 24         False    False             False   False    False  False     False
# 25         False    False             False   False    False  False     False
# 26         False    False             False   False    False  False     False
# 27         False    False             False   False    False  False     False
# 28         False    False             False   False    False  False     False
# 29         False    False             False   False    False  False     False
#
#      cast   crew  revenue
# 0   False  False    False
# 1   False  False    False
# 2   False  False    False
# 3   False  False    False
# 4   False  False    False
# 5   False  False    False
# 6   False  False    False
# 7   False  False    False
# 8   False  False    False
# 9   False  False    False
# 10  False  False    False
# 11  False  False    False
# 12  False  False    False
# 13  False  False    False
# 14  False  False    False
# 15  False  False    False
# 16  False  False    False
# 17  False  False    False
# 18  False  False    False
# 19  False  False    False
# 20  False  False    False
# 21  False  False    False
# 22  False  False    False
# 23  False  False    False
# 24  False  False    False
# 25  False  False    False
# 26  False  False    False
# 27  False  False    False
# 28  False  False    False
# 29  False  False    False
#
# [30 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# id                        0
# belongs_to_collection     0
# budget                    0
# genres                    1
# homepage                 21
# imdb_id                   0
# original_language         0
# original_title            0
# overview                  0
# popularity                0
# poster_path               1
# production_companies      3
# production_countries      0
# release_date              0
# runtime                   1
# spoken_languages          0
# status                    0
# tagline                   5
# title                     0
# Keywords                  1
# cast                      0
# crew                      0
# revenue                   0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# id                        0.000000
# belongs_to_collection     0.000000
# budget                    0.000000
# genres                    3.333333
# homepage                 70.000000
# imdb_id                   0.000000
# original_language         0.000000
# original_title            0.000000
# overview                  0.000000
# popularity                0.000000
# poster_path               3.333333
# production_companies     10.000000
# production_countries      0.000000
# release_date              0.000000
# runtime                   3.333333
# spoken_languages          0.000000
# status                    0.000000
# tagline                  16.666667
# title                     0.000000
# Keywords                  3.333333
# cast                      0.000000
# crew                      0.000000
# revenue                   0.000000
# dtype: float64

# %%
df.drop(columns=["homepage"],inplace=True)    # if the missing value are morethan or equal to 25% we have to remove

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'imdb_id',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'production_companies', 'production_countries',
#        'release_date', 'runtime', 'spoken_languages', 'status', 'tagline',
#        'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    id   belongs_to_collection    budget                genres    imdb_id  \
# 0   1  Hot Tub Time Machine 2  14000000  [{"name": "Comedy"}]  tt2637294
#
#   original_language          original_title             overview  popularity  \
# 0                en  Hot Tub Time Machine 2  Time travel comedy.    6.575393
#
#     poster_path  ... release_date runtime       spoken_languages    status  \
# 0  /poster1.jpg  ...      2/20/15    93.0  [{"name": "English"}]  Released
#
#                       tagline                   title     Keywords  \
# 0  The Laws of Space and Time  Hot Tub Time Machine 2  time travel
#
#                         cast                                         crew  \
# 0  [{"name": "Rob Corddry"}]  [{"name": "Steve Pink", "job": "Director"}]
#
#     revenue
# 0  12314651
#
# [1 rows x 22 columns]

# %% [markdown]
# # - filling missing values

# %%
df.genres  =   df.genres.fillna(df.genres.mode()[0])

# %%
df["poster_path"]  =   df["poster_path"].fillna(df["poster_path"].mode()[0])

# %%
df.production_companies=df.production_companies.fillna(df.production_companies.mode()[0])

# %%
df.runtime=df.runtime.fillna(df.runtime.mean())

# %%
df.tagline=df.tagline.fillna(df.tagline.mode()[0])

# %%
df.Keywords=df.Keywords.fillna(df.Keywords.mode()[0])

# %%
df.isnull().sum()
# Out:
# id                       0
# belongs_to_collection    0
# budget                   0
# genres                   0
# imdb_id                  0
# original_language        0
# original_title           0
# overview                 0
# popularity               0
# poster_path              0
# production_companies     0
# production_countries     0
# release_date             0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# title                    0
# Keywords                 0
# cast                     0
# crew                     0
# revenue                  0
# dtype: int64

# %% [markdown]
# # - fix the datatype issue

# %%
df.dtypes
# Out:
# id                         int64
# belongs_to_collection     object
# budget                     int64
# genres                    object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# Keywords                  object
# cast                      object
# crew                      object
# revenue                    int64
# dtype: object

# %%
df.imdb_id.value_counts()
# Out:
# imdb_id
# tt2637294     1
# tt0368933     1
# tt3783958     1
# tt7286456     1
# tt4849438     1
# tt8178634     1
# tt15327088    1
# tt9000002     1
# tt9000001     1
# tt0068646     1
# tt0245429     1
# tt0120338     1
# tt4154796     1
# tt5074352     1
# tt0816692     1
# tt1600195     1
# tt0343135     1
# tt0116908     1
# tt2364975     1
# tt0109403     1
# tt0105327     1
# tt0362227     1
# tt6751668     1
# tt1187043     1
# tt0468569     1
# tt1375666     1
# tt1380152     1
# tt1821480     1
# tt2582802     1
# tt0112870     1
# Name: count, dtype: int64

# %%
# remove the text in  IMDB_ID

df['imdb_id'] = df['imdb_id'].str.split().str[0].str.replace('tt', '', regex=False)

# %%
df['imdb_id'].value_counts()
# Out:
# imdb_id
# 2637294     1
# 0368933     1
# 3783958     1
# 7286456     1
# 4849438     1
# 8178634     1
# 15327088    1
# 9000002     1
# 9000001     1
# 0068646     1
# 0245429     1
# 0120338     1
# 4154796     1
# 5074352     1
# 0816692     1
# 1600195     1
# 0343135     1
# 0116908     1
# 2364975     1
# 0109403     1
# 0105327     1
# 0362227     1
# 6751668     1
# 1187043     1
# 0468569     1
# 1375666     1
# 1380152     1
# 1821480     1
# 2582802     1
# 0112870     1
# Name: count, dtype: int64

# %%
# change the datatype

df['imdb_id']=df['imdb_id'].astype("int64")

# %%
df.dtypes
# Out:
# id                         int64
# belongs_to_collection     object
# budget                     int64
# genres                    object
# imdb_id                    int64
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# Keywords                  object
# cast                      object
# crew                      object
# revenue                    int64
# dtype: object

# %%
df.release_date.value_counts()
# Out:
# release_date
# 2/20/15     1
# 8/6/04      1
# 12/25/16    1
# 10/4/19     1
# 4/28/17     1
# 3/25/22     1
# 9/30/22     1
# 10/10/18    1
# 8/15/20     1
# 3/24/72     1
# 7/20/01     1
# 12/19/97    1
# 4/26/19     1
# 12/23/16    1
# 11/7/14     1
# 9/22/11     1
# 1/16/04     1
# 10/11/96    1
# 3/28/13     1
# 4/22/94     1
# 9/18/92     1
# 6/17/04     1
# 5/30/19     1
# 12/25/09    1
# 7/18/08     1
# 7/16/10     1
# 2/5/09      1
# 3/9/12      1
# 10/10/14    1
# 10/20/95    1
# Name: count, dtype: int64

# %%
df.release_date=pd.to_datetime(df.release_date,errors="coerce")
# Out:
# C:\Users\LakshmanAIMLHYD\AppData\Local\Temp\ipykernel_13612\3125924932.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df.release_date=pd.to_datetime(df.release_date,errors="coerce")

# %%
df.dtypes
# Out:
# id                                int64
# belongs_to_collection            object
# budget                            int64
# genres                           object
# imdb_id                           int64
# original_language                object
# original_title                   object
# overview                         object
# popularity                      float64
# poster_path                      object
# production_companies             object
# production_countries             object
# release_date             datetime64[ns]
# runtime                         float64
# spoken_languages                 object
# status                           object
# tagline                          object
# title                            object
# Keywords                         object
# cast                             object
# crew                             object
# revenue                           int64
# dtype: object

# %%
df.year=df.release_date.dt.year
# Out:
# C:\Users\LakshmanAIMLHYD\AppData\Local\Temp\ipykernel_13612\3651849922.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.year=df.release_date.dt.year

# %%
df.month=df.release_date.dt.month
# Out:
# C:\Users\LakshmanAIMLHYD\AppData\Local\Temp\ipykernel_13612\2720067362.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.month=df.release_date.dt.month

# %%
df.day=df.release_date.dt.day
# Out:
# C:\Users\LakshmanAIMLHYD\AppData\Local\Temp\ipykernel_13612\4083887189.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.day=df.release_date.dt.day

# %%
df.head(1)
# Out:
#    id   belongs_to_collection    budget                genres  imdb_id  \
# 0   1  Hot Tub Time Machine 2  14000000  [{"name": "Comedy"}]  2637294
#
#   original_language          original_title             overview  popularity  \
# 0                en  Hot Tub Time Machine 2  Time travel comedy.    6.575393
#
#     poster_path  ... release_date runtime       spoken_languages    status  \
# 0  /poster1.jpg  ...   2015-02-20    93.0  [{"name": "English"}]  Released
#
#                       tagline                   title     Keywords  \
# 0  The Laws of Space and Time  Hot Tub Time Machine 2  time travel
#
#                         cast                                         crew  \
# 0  [{"name": "Rob Corddry"}]  [{"name": "Steve Pink", "job": "Director"}]
#
#     revenue
# 0  12314651
#
# [1 rows x 22 columns]

# %% [markdown]
# # <u>**Indexing and Slicing**</u>

# %%
df.head()
# Out:
#    id                     belongs_to_collection    budget  \
# 0   1                    Hot Tub Time Machine 2  14000000
# 1   2  The Princess Diaries 2: Royal Engagement  40000000
# 2   3                                  Whiplash   3300000
# 3   4                                   Kahaani   1200000
# 4   5                                Marine Boy         0
#
#                                        genres  \
# 0                        [{"name": "Comedy"}]
# 1     [{"name": "Comedy"}, {"name": "Drama"}]
# 2                         [{"name": "Drama"}]
# 3   [{"name": "Thriller"}, {"name": "Drama"}]
# 4  [{"name": "Action"}, {"name": "Thriller"}]
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  ...  \
# 0                                Time travel comedy.    6.575393  ...
# 1                  A princess prepares for marriage.    8.248895  ...
# 2       A young drummer faces a ruthless instructor.   64.299990  ...
# 3  A woman searches for her missing husband in Ko...    3.174936  ...
# 4        A former swimmer becomes involved in crime.    1.148070  ...
#
#   release_date runtime             spoken_languages    status  \
# 0      2/20/15    93.0        [{"name": "English"}]  Released
# 1       8/6/04   113.0        [{"name": "English"}]  Released
# 2     10/10/14   105.0        [{"name": "English"}]  Released
# 3       3/9/12   122.0  [{"name": "English|Hindi"}]  Released
# 4       2/5/09   118.0         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                                              NaN
# 4                                              NaN
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy               NaN
#
#                           cast  \
# 0    [{"name": "Rob Corddry"}]
# 1  [{"name": "Anne Hathaway"}]
# 2   [{"name": "Miles Teller"}]
# 3    [{"name": "Vidya Balan"}]
# 4   [{"name": "Kim Kang-woo"}]
#
#                                                crew   revenue
# 0       [{"name": "Steve Pink", "job": "Director"}]  12314651
# 1   [{"name": "Garry Marshall", "job": "Director"}]  95149435
# 2  [{"name": "Damien Chazelle", "job": "Director"}]  13092000
# 3      [{"name": "Sujoy Ghosh", "job": "Director"}]  16000000
# 4   [{"name": "Yoon Jong-chan", "job": "Director"}]   3923970
#
# [5 rows x 23 columns]

# %% [markdown]
# ## **<code>iloc</code>** gets rows (or columns) at particular positions in the index (so it only takes integers).

# %%
# Let us get a subset which consists of first 8 rows and first 4 columns
df.iloc[:,-3:]
# Out:
#                                  cast  \
# 0           [{"name": "Rob Corddry"}]
# 1         [{"name": "Anne Hathaway"}]
# 2          [{"name": "Miles Teller"}]
# 3           [{"name": "Vidya Balan"}]
# 4          [{"name": "Kim Kang-woo"}]
# 5     [{"name": "Leonardo DiCaprio"}]
# 6        [{"name": "Christian Bale"}]
# 7            [{"name": "Aamir Khan"}]
# 8          [{"name": "Song Kang-ho"}]
# 9             [{"name": "Tom Hanks"}]
# 10       [{"name": "Brendan Fraser"}]
# 11         [{"name": "Tom Berenger"}]
# 12      [{"name": "Mira Barkhammar"}]
# 13          [{"name": "Geena Davis"}]
# 14          [{"name": "Ben Stiller"}]
# 15       [{"name": "Taylor Lautner"}]
# 16  [{"name": "Matthew McConaughey"}]
# 17           [{"name": "Aamir Khan"}]
# 18    [{"name": "Robert Downey Jr."}]
# 19    [{"name": "Leonardo DiCaprio"}]
# 20         [{"name": "Rumi Hiiragi"}]
# 21        [{"name": "Marlon Brando"}]
# 22           [{"name": "Aamir Khan"}]
# 23              [{"name": "Unknown"}]
# 24        [{"name": "Rishab Shetty"}]
# 25   [{"name": "N. T. Rama Rao Jr."}]
# 26              [{"name": "Prabhas"}]
# 27      [{"name": "Joaquin Phoenix"}]
# 28         [{"name": "Ryan Gosling"}]
# 29       [{"name": "Shah Rukh Khan"}]
#
#                                                  crew     revenue
# 0         [{"name": "Steve Pink", "job": "Director"}]    12314651
# 1     [{"name": "Garry Marshall", "job": "Director"}]    95149435
# 2    [{"name": "Damien Chazelle", "job": "Director"}]    13092000
# 3        [{"name": "Sujoy Ghosh", "job": "Director"}]    16000000
# 4     [{"name": "Yoon Jong-chan", "job": "Director"}]     3923970
# 5   [{"name": "Christopher Nolan", "job": "Directo...   839000000
# 6   [{"name": "Christopher Nolan", "job": "Directo...  1004558444
# 7    [{"name": "Rajkumar Hirani", "job": "Director"}]  2000000000
# 8       [{"name": "Bong Joon Ho", "job": "Director"}]   258000000
# 9   [{"name": "Steven Spielberg", "job": "Director"}]   219417255
# 10     [{"name": "Robert Mandel", "job": "Director"}]    14715067
# 11     [{"name": "Dennis Hopper", "job": "Director"}]     1596687
# 12   [{"name": "Lukas Moodysson", "job": "Director"}]      180590
# 13      [{"name": "Renny Harlin", "job": "Director"}]    89456761
# 14      [{"name": "John Hamburg", "job": "Director"}]   171963386
# 15    [{"name": "John Singleton", "job": "Director"}]    82087155
# 16  [{"name": "Christopher Nolan", "job": "Directo...   701729206
# 17     [{"name": "Nitesh Tiwari", "job": "Director"}]   310000000
# 18     [{"name": "Anthony Russo", "job": "Director"}]  2797501328
# 19     [{"name": "James Cameron", "job": "Director"}]  2264743305
# 20    [{"name": "Hayao Miyazaki", "job": "Director"}]   395800000
# 21  [{"name": "Francis Ford Coppola", "job": "Dire...   250000000
# 22     [{"name": "Demo Director", "job": "Director"}]           0
# 23           [{"name": "Unknown", "job": "Director"}]    45000000
# 24     [{"name": "Rishab Shetty", "job": "Director"}]   400000000
# 25   [{"name": "S. S. Rajamouli", "job": "Director"}]  1200000000
# 26   [{"name": "S. S. Rajamouli", "job": "Director"}]  1810000000
# 27     [{"name": "Todd Phillips", "job": "Director"}]  1074251311
# 28   [{"name": "Damien Chazelle", "job": "Director"}]   472000000
# 29     [{"name": "Aditya Chopra", "job": "Director"}]   120000000

# %% [markdown]
# ## **<code>loc</code>** gets rows (or columns) with particular labels from the index.

# %%
# Now let us subset our dataframe in which we want to have first 8 rows identified with their rows labels and some named columns
df.loc[50:60,['budget','genres','runtime']]
# Out:
# Empty DataFrame
# Columns: [budget, genres, runtime]
# Index: []

# %%
df.loc[:,['budget','genres','runtime']]
# Out:
#        budget                                             genres  runtime
# 0    14000000                               [{"name": "Comedy"}]     93.0
# 1    40000000            [{"name": "Comedy"}, {"name": "Drama"}]    113.0
# 2     3300000                                [{"name": "Drama"}]    105.0
# 3     1200000          [{"name": "Thriller"}, {"name": "Drama"}]    122.0
# 4           0         [{"name": "Action"}, {"name": "Thriller"}]    118.0
# 5   160000000           [{"name": "Action"}, {"name": "Sci-Fi"}]    148.0
# 6   185000000  [{"name": "Action"}, {"name": "Crime"}, {"name...    152.0
# 7   550000000            [{"name": "Comedy"}, {"name": "Drama"}]    170.0
# 8    11400000          [{"name": "Drama"}, {"name": "Thriller"}]    132.0
# 9    60000000            [{"name": "Comedy"}, {"name": "Drama"}]    128.0
# 10          0                                [{"name": "Drama"}]    106.0
# 11          0          [{"name": "Comedy"}, {"name": "Romance"}]    102.0
# 12          0             [{"name": "Drama"}, {"name": "Music"}]    102.0
# 13   65000000            [{"name": "Crime"}, {"name": "Action"}]    120.0
# 14   42000000          [{"name": "Comedy"}, {"name": "Romance"}]     90.0
# 15   35000000         [{"name": "Thriller"}, {"name": "Action"}]    106.0
# 16  165000000  [{"name": "Adventure"}, {"name": "Drama"}, {"n...    169.0
# 17   70000000             [{"name": "Drama"}, {"name": "Sport"}]    161.0
# 18  356000000  [{"name": "Action"}, {"name": "Adventure"}, {"...    181.0
# 19  200000000           [{"name": "Drama"}, {"name": "Romance"}]    194.0
# 20   19000000       [{"name": "Animation"}, {"name": "Fantasy"}]    125.0
# 21    6000000             [{"name": "Crime"}, {"name": "Drama"}]    175.0
# 22   80000000            [{"name": "Comedy"}, {"name": "Drama"}]      0.0
# 23   25000000                                                NaN      NaN
# 24   16000000            [{"name": "Action"}, {"name": "Drama"}]    148.0
# 25  550000000            [{"name": "Action"}, {"name": "Drama"}]    187.0
# 26  250000000            [{"name": "Action"}, {"name": "Drama"}]    168.0
# 27   55000000             [{"name": "Crime"}, {"name": "Drama"}]    122.0
# 28   30000000  [{"name": "Comedy"}, {"name": "Drama"}, {"name...    128.0
# 29   40000000           [{"name": "Drama"}, {"name": "Romance"}]    181.0

# %%
df[0:10]
# Out:
#    id                     belongs_to_collection     budget  \
# 0   1                    Hot Tub Time Machine 2   14000000
# 1   2  The Princess Diaries 2: Royal Engagement   40000000
# 2   3                                  Whiplash    3300000
# 3   4                                   Kahaani    1200000
# 4   5                                Marine Boy          0
# 5   6                                 Inception  160000000
# 6   7                           The Dark Knight  185000000
# 7   8                                  3 Idiots  550000000
# 8   9                                  Parasite   11400000
# 9  10                              The Terminal   60000000
#
#                                               genres  \
# 0                               [{"name": "Comedy"}]
# 1            [{"name": "Comedy"}, {"name": "Drama"}]
# 2                                [{"name": "Drama"}]
# 3          [{"name": "Thriller"}, {"name": "Drama"}]
# 4         [{"name": "Action"}, {"name": "Thriller"}]
# 5           [{"name": "Action"}, {"name": "Sci-Fi"}]
# 6  [{"name": "Action"}, {"name": "Crime"}, {"name...
# 7            [{"name": "Comedy"}, {"name": "Drama"}]
# 8          [{"name": "Drama"}, {"name": "Thriller"}]
# 9            [{"name": "Comedy"}, {"name": "Drama"}]
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 4                                   NaN  tt1380152                ko
# 5         https://example.com/inception  tt1375666                en
# 6                                   NaN  tt0468569                en
# 7           https://example.com/3idiots  tt1187043                hi
# 8                                   NaN  tt6751668                ko
# 9  http://www.theterminal-themovie.com/  tt0362227                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
# 5                                 Inception
# 6                           The Dark Knight
# 7                                  3 Idiots
# 8                                  Parasite
# 9                              The Terminal
#
#                                             overview  popularity  ...  \
# 0                                Time travel comedy.    6.575393  ...
# 1                  A princess prepares for marriage.    8.248895  ...
# 2       A young drummer faces a ruthless instructor.   64.299990  ...
# 3  A woman searches for her missing husband in Ko...    3.174936  ...
# 4        A former swimmer becomes involved in crime.    1.148070  ...
# 5            A thief enters dreams to steal secrets.   82.500000  ...
# 6                            Batman faces the Joker.   90.100000  ...
# 7           Three friends navigate college and life.   25.300000  ...
# 8  Two families become entangled in a strange sit...   55.700000  ...
# 9              A man becomes stranded in an airport.   14.092373  ...
#
#   release_date runtime             spoken_languages    status  \
# 0      2/20/15    93.0        [{"name": "English"}]  Released
# 1       8/6/04   113.0        [{"name": "English"}]  Released
# 2     10/10/14   105.0        [{"name": "English"}]  Released
# 3       3/9/12   122.0  [{"name": "English|Hindi"}]  Released
# 4       2/5/09   118.0         [{"name": "Korean"}]  Released
# 5      7/16/10   148.0        [{"name": "English"}]  Released
# 6      7/18/08   152.0        [{"name": "English"}]  Released
# 7     12/25/09   170.0          [{"name": "Hindi"}]  Released
# 8      5/30/19   132.0         [{"name": "Korean"}]  Released
# 9      6/17/04   128.0        [{"name": "English"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                                              NaN
# 4                                              NaN
# 5             Your mind is the scene of the crime.
# 6                                  Why so serious?
# 7                                     All is well.
# 8                      Act like you own the place.
# 9                                 Life is waiting.
#
#                                       title            Keywords  \
# 0                    Hot Tub Time Machine 2         time travel
# 1  The Princess Diaries 2: Royal Engagement    princess|royalty
# 2                                  Whiplash          jazz|music
# 3                                   Kahaani     mystery|kolkata
# 4                                Marine Boy                 NaN
# 5                                 Inception         dream|heist
# 6                           The Dark Knight        joker|batman
# 7                                  3 Idiots  college|friendship
# 8                                  Parasite        family|class
# 9                              The Terminal    airport|new york
#
#                               cast  \
# 0        [{"name": "Rob Corddry"}]
# 1      [{"name": "Anne Hathaway"}]
# 2       [{"name": "Miles Teller"}]
# 3        [{"name": "Vidya Balan"}]
# 4       [{"name": "Kim Kang-woo"}]
# 5  [{"name": "Leonardo DiCaprio"}]
# 6     [{"name": "Christian Bale"}]
# 7         [{"name": "Aamir Khan"}]
# 8       [{"name": "Song Kang-ho"}]
# 9          [{"name": "Tom Hanks"}]
#
#                                                 crew     revenue
# 0        [{"name": "Steve Pink", "job": "Director"}]    12314651
# 1    [{"name": "Garry Marshall", "job": "Director"}]    95149435
# 2   [{"name": "Damien Chazelle", "job": "Director"}]    13092000
# 3       [{"name": "Sujoy Ghosh", "job": "Director"}]    16000000
# 4    [{"name": "Yoon Jong-chan", "job": "Director"}]     3923970
# 5  [{"name": "Christopher Nolan", "job": "Directo...   839000000
# 6  [{"name": "Christopher Nolan", "job": "Directo...  1004558444
# 7   [{"name": "Rajkumar Hirani", "job": "Director"}]  2000000000
# 8      [{"name": "Bong Joon Ho", "job": "Director"}]   258000000
# 9  [{"name": "Steven Spielberg", "job": "Director"}]   219417255
#
# [10 rows x 23 columns]

# %%
df[['original_language','release_date','cast']]
# Out:
#    original_language release_date                               cast
# 0                 en      2/20/15          [{"name": "Rob Corddry"}]
# 1                 en       8/6/04        [{"name": "Anne Hathaway"}]
# 2                 en     10/10/14         [{"name": "Miles Teller"}]
# 3                 hi       3/9/12          [{"name": "Vidya Balan"}]
# 4                 ko       2/5/09         [{"name": "Kim Kang-woo"}]
# 5                 en      7/16/10    [{"name": "Leonardo DiCaprio"}]
# 6                 en      7/18/08       [{"name": "Christian Bale"}]
# 7                 hi     12/25/09           [{"name": "Aamir Khan"}]
# 8                 ko      5/30/19         [{"name": "Song Kang-ho"}]
# 9                 en      6/17/04            [{"name": "Tom Hanks"}]
# 10                en      9/18/92       [{"name": "Brendan Fraser"}]
# 11                en      4/22/94         [{"name": "Tom Berenger"}]
# 12                sv      3/28/13      [{"name": "Mira Barkhammar"}]
# 13                en     10/11/96          [{"name": "Geena Davis"}]
# 14                en      1/16/04          [{"name": "Ben Stiller"}]
# 15                en      9/22/11       [{"name": "Taylor Lautner"}]
# 16                en      11/7/14  [{"name": "Matthew McConaughey"}]
# 17                hi     12/23/16           [{"name": "Aamir Khan"}]
# 18                en      4/26/19    [{"name": "Robert Downey Jr."}]
# 19                en     12/19/97    [{"name": "Leonardo DiCaprio"}]
# 20                ja      7/20/01         [{"name": "Rumi Hiiragi"}]
# 21                en      3/24/72        [{"name": "Marlon Brando"}]
# 22                hi      8/15/20           [{"name": "Aamir Khan"}]
# 23                en     10/10/18              [{"name": "Unknown"}]
# 24                kn      9/30/22        [{"name": "Rishab Shetty"}]
# 25                te      3/25/22   [{"name": "N. T. Rama Rao Jr."}]
# 26                te      4/28/17              [{"name": "Prabhas"}]
# 27                en      10/4/19      [{"name": "Joaquin Phoenix"}]
# 28                en     12/25/16         [{"name": "Ryan Gosling"}]
# 29                hi     10/20/95       [{"name": "Shah Rukh Khan"}]

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='str')

# %% [markdown]
# ## <b>In fact we can also perform boolean indexing on our dataframe</b>

# %%
df['original_language'] == 'en'
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# 15     True
# 16     True
# 17    False
# 18     True
# 19     True
# 20    False
# 21     True
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27     True
# 28     True
# 29    False
# Name: original_language, dtype: bool

# %%
# Boolean Indexing
english_movies = df[df['original_language'] == 'en']
english_movies.head()
# Out:
#    id                     belongs_to_collection     budget  \
# 0   1                    Hot Tub Time Machine 2   14000000
# 1   2  The Princess Diaries 2: Royal Engagement   40000000
# 2   3                                  Whiplash    3300000
# 5   6                                 Inception  160000000
# 6   7                           The Dark Knight  185000000
#
#                                               genres  \
# 0                               [{"name": "Comedy"}]
# 1            [{"name": "Comedy"}, {"name": "Drama"}]
# 2                                [{"name": "Drama"}]
# 5           [{"name": "Action"}, {"name": "Sci-Fi"}]
# 6  [{"name": "Action"}, {"name": "Crime"}, {"name...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 5      https://example.com/inception  tt1375666                en
# 6                                NaN  tt0468569                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 5                                 Inception
# 6                           The Dark Knight
#
#                                        overview  popularity  ... release_date  \
# 0                           Time travel comedy.    6.575393  ...      2/20/15
# 1             A princess prepares for marriage.    8.248895  ...       8/6/04
# 2  A young drummer faces a ruthless instructor.   64.299990  ...     10/10/14
# 5       A thief enters dreams to steal secrets.   82.500000  ...      7/16/10
# 6                       Batman faces the Joker.   90.100000  ...      7/18/08
#
#   runtime       spoken_languages    status  \
# 0    93.0  [{"name": "English"}]  Released
# 1   113.0  [{"name": "English"}]  Released
# 2   105.0  [{"name": "English"}]  Released
# 5   148.0  [{"name": "English"}]  Released
# 6   152.0  [{"name": "English"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 5             Your mind is the scene of the crime.
# 6                                  Why so serious?
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 5                                 Inception       dream|heist
# 6                           The Dark Knight      joker|batman
#
#                               cast  \
# 0        [{"name": "Rob Corddry"}]
# 1      [{"name": "Anne Hathaway"}]
# 2       [{"name": "Miles Teller"}]
# 5  [{"name": "Leonardo DiCaprio"}]
# 6     [{"name": "Christian Bale"}]
#
#                                                 crew     revenue
# 0        [{"name": "Steve Pink", "job": "Director"}]    12314651
# 1    [{"name": "Garry Marshall", "job": "Director"}]    95149435
# 2   [{"name": "Damien Chazelle", "job": "Director"}]    13092000
# 5  [{"name": "Christopher Nolan", "job": "Directo...   839000000
# 6  [{"name": "Christopher Nolan", "job": "Directo...  1004558444
#
# [5 rows x 23 columns]

# %%
english_movies.shape
# Out:
# (18, 23)

# %%
non_english_movies = df[df['original_language'] != 'en']
non_english_movies.head()
# Out:
#     id belongs_to_collection     budget  \
# 3    4               Kahaani    1200000
# 4    5            Marine Boy          0
# 7    8              3 Idiots  550000000
# 8    9              Parasite   11400000
# 12  13      We Are the Best!          0
#
#                                         genres                     homepage  \
# 3    [{"name": "Thriller"}, {"name": "Drama"}]   http://kahaanithefilm.com/
# 4   [{"name": "Action"}, {"name": "Thriller"}]                          NaN
# 7      [{"name": "Comedy"}, {"name": "Drama"}]  https://example.com/3idiots
# 8    [{"name": "Drama"}, {"name": "Thriller"}]                          NaN
# 12      [{"name": "Drama"}, {"name": "Music"}]                          NaN
#
#       imdb_id original_language    original_title  \
# 3   tt1821480                hi           Kahaani
# 4   tt1380152                ko        Marine Boy
# 7   tt1187043                hi          3 Idiots
# 8   tt6751668                ko          Parasite
# 12  tt2364975                sv  We Are the Best!
#
#                                              overview  popularity  ...  \
# 3   A woman searches for her missing husband in Ko...    3.174936  ...
# 4         A former swimmer becomes involved in crime.    1.148070  ...
# 7            Three friends navigate college and life.   25.300000  ...
# 8   Two families become entangled in a strange sit...   55.700000  ...
# 12                      Three girls form a punk band.    3.727996  ...
#
#    release_date runtime             spoken_languages    status  \
# 3        3/9/12   122.0  [{"name": "English|Hindi"}]  Released
# 4        2/5/09   118.0         [{"name": "Korean"}]  Released
# 7      12/25/09   170.0          [{"name": "Hindi"}]  Released
# 8       5/30/19   132.0         [{"name": "Korean"}]  Released
# 12      3/28/13   102.0        [{"name": "Swedish"}]  Released
#
#                         tagline             title            Keywords  \
# 3                           NaN           Kahaani     mystery|kolkata
# 4                           NaN        Marine Boy                 NaN
# 7                  All is well.          3 Idiots  college|friendship
# 8   Act like you own the place.          Parasite        family|class
# 12                          NaN  We Are the Best!         sweden|punk
#
#                              cast  \
# 3       [{"name": "Vidya Balan"}]
# 4      [{"name": "Kim Kang-woo"}]
# 7        [{"name": "Aamir Khan"}]
# 8      [{"name": "Song Kang-ho"}]
# 12  [{"name": "Mira Barkhammar"}]
#
#                                                 crew     revenue
# 3       [{"name": "Sujoy Ghosh", "job": "Director"}]    16000000
# 4    [{"name": "Yoon Jong-chan", "job": "Director"}]     3923970
# 7   [{"name": "Rajkumar Hirani", "job": "Director"}]  2000000000
# 8      [{"name": "Bong Joon Ho", "job": "Director"}]   258000000
# 12  [{"name": "Lukas Moodysson", "job": "Director"}]      180590
#
# [5 rows x 23 columns]

# %%
long_movies = df[df['runtime'] > 120]
long_movies[['title','cast']]
# Out:
#                           title                               cast
# 3                       Kahaani          [{"name": "Vidya Balan"}]
# 5                     Inception    [{"name": "Leonardo DiCaprio"}]
# 6               The Dark Knight       [{"name": "Christian Bale"}]
# 7                      3 Idiots           [{"name": "Aamir Khan"}]
# 8                      Parasite         [{"name": "Song Kang-ho"}]
# 9                  The Terminal            [{"name": "Tom Hanks"}]
# 16                 Interstellar  [{"name": "Matthew McConaughey"}]
# 17                       Dangal           [{"name": "Aamir Khan"}]
# 18            Avengers: Endgame    [{"name": "Robert Downey Jr."}]
# 19                      Titanic    [{"name": "Leonardo DiCaprio"}]
# 20                Spirited Away         [{"name": "Rumi Hiiragi"}]
# 21                The Godfather        [{"name": "Marlon Brando"}]
# 24                      Kantara        [{"name": "Rishab Shetty"}]
# 25                          RRR   [{"name": "N. T. Rama Rao Jr."}]
# 26  Baahubali 2: The Conclusion              [{"name": "Prabhas"}]
# 27                        Joker      [{"name": "Joaquin Phoenix"}]
# 28                   La La Land         [{"name": "Ryan Gosling"}]
# 29  Dilwale Dulhania Le Jayenge       [{"name": "Shah Rukh Khan"}]

# %% [markdown]
# ## Infact we can match conditions for mutliple columns

# %%
long_movies = df[df['runtime'] > 120]

# %%
long_movies.tail()
# Out:
#     id        belongs_to_collection     budget  \
# 25  26                          RRR  550000000
# 26  27   Bahubali 2: The Conclusion  250000000
# 27  28                        Joker   55000000
# 28  29                   La La Land   30000000
# 29  30  Dilwale Dulhania Le Jayenge   40000000
#
#                                                genres homepage    imdb_id  \
# 25            [{"name": "Action"}, {"name": "Drama"}]      NaN  tt8178634
# 26            [{"name": "Action"}, {"name": "Drama"}]      NaN  tt4849438
# 27             [{"name": "Crime"}, {"name": "Drama"}]      NaN  tt7286456
# 28  [{"name": "Comedy"}, {"name": "Drama"}, {"name...      NaN  tt3783958
# 29           [{"name": "Drama"}, {"name": "Romance"}]      NaN  tt0112870
#
#    original_language               original_title  \
# 25                te                          RRR
# 26                te  Baahubali 2: The Conclusion
# 27                en                        Joker
# 28                en                   La La Land
# 29                hi  Dilwale Dulhania Le Jayenge
#
#                                              overview  popularity  ...  \
# 25   Two revolutionaries form an unlikely friendship.        60.3  ...
# 26               A kingdom seeks answers and revenge.        52.9  ...
# 27             A failed comedian descends into chaos.        70.9  ...
# 28  A musician and actress pursue dreams in Los An...        35.8  ...
# 29     A young couple challenges family expectations.        20.6  ...
#
#    release_date runtime       spoken_languages    status  \
# 25      3/25/22   187.0   [{"name": "Telugu"}]  Released
# 26      4/28/17   168.0   [{"name": "Telugu"}]  Released
# 27      10/4/19   122.0  [{"name": "English"}]  Released
# 28     12/25/16   128.0  [{"name": "English"}]  Released
# 29     10/20/95   181.0    [{"name": "Hindi"}]  Released
#
#                              tagline                        title  \
# 25               Rise. Roar. Revolt.                          RRR
# 26  Why did Kattappa kill Baahubali?  Baahubali 2: The Conclusion
# 27              Put on a happy face.                        Joker
# 28    Here's to the fools who dream.                   La La Land
# 29             Come... Fall in love.  Dilwale Dulhania Le Jayenge
#
#                  Keywords                              cast  \
# 25  friendship|revolution  [{"name": "N. T. Rama Rao Jr."}]
# 26            kingdom|war             [{"name": "Prabhas"}]
# 27            joker|crime     [{"name": "Joaquin Phoenix"}]
# 28      music|los angeles        [{"name": "Ryan Gosling"}]
# 29         romance|family      [{"name": "Shah Rukh Khan"}]
#
#                                                 crew     revenue
# 25  [{"name": "S. S. Rajamouli", "job": "Director"}]  1200000000
# 26  [{"name": "S. S. Rajamouli", "job": "Director"}]  1810000000
# 27    [{"name": "Todd Phillips", "job": "Director"}]  1074251311
# 28  [{"name": "Damien Chazelle", "job": "Director"}]   472000000
# 29    [{"name": "Aditya Chopra", "job": "Director"}]   120000000
#
# [5 rows x 23 columns]

# %%
(df['original_language']=='en') & (df['runtime'] > 120)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18     True
# 19     True
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28     True
# 29    False
# dtype: bool

# %%
long_english_movies = df[(df['original_language']=='en') & (df['runtime'] > 120)]
long_english_movies.head()
# Out:
#     id belongs_to_collection     budget  \
# 5    6             Inception  160000000
# 6    7       The Dark Knight  185000000
# 9   10          The Terminal   60000000
# 16  17          Interstellar  165000000
# 18  19     Avengers: Endgame  356000000
#
#                                                genres  \
# 5            [{"name": "Action"}, {"name": "Sci-Fi"}]
# 6   [{"name": "Action"}, {"name": "Crime"}, {"name...
# 9             [{"name": "Comedy"}, {"name": "Drama"}]
# 16  [{"name": "Adventure"}, {"name": "Drama"}, {"n...
# 18  [{"name": "Action"}, {"name": "Adventure"}, {"...
#
#                                 homepage    imdb_id original_language  \
# 5          https://example.com/inception  tt1375666                en
# 6                                    NaN  tt0468569                en
# 9   http://www.theterminal-themovie.com/  tt0362227                en
# 16                                   NaN  tt0816692                en
# 18                                   NaN  tt4154796                en
#
#        original_title                                       overview  \
# 5           Inception        A thief enters dreams to steal secrets.
# 6     The Dark Knight                        Batman faces the Joker.
# 9        The Terminal          A man becomes stranded in an airport.
# 16       Interstellar  Explorers travel through a wormhole in space.
# 18  Avengers: Endgame  Heroes attempt to reverse a devastating loss.
#
#     popularity  ... release_date runtime       spoken_languages    status  \
# 5    82.500000  ...      7/16/10   148.0  [{"name": "English"}]  Released
# 6    90.100000  ...      7/18/08   152.0  [{"name": "English"}]  Released
# 9    14.092373  ...      6/17/04   128.0  [{"name": "English"}]  Released
# 16   75.000000  ...      11/7/14   169.0  [{"name": "English"}]  Released
# 18   88.200000  ...      4/26/19   181.0  [{"name": "English"}]  Released
#
#                                               tagline              title  \
# 5                Your mind is the scene of the crime.          Inception
# 6                                     Why so serious?    The Dark Knight
# 9                                    Life is waiting.       The Terminal
# 16  Mankind was born on Earth. It was never meant ...       Interstellar
# 18                                 Avenge the fallen.  Avengers: Endgame
#
#             Keywords                               cast  \
# 5        dream|heist    [{"name": "Leonardo DiCaprio"}]
# 6       joker|batman       [{"name": "Christian Bale"}]
# 9   airport|new york            [{"name": "Tom Hanks"}]
# 16    space|wormhole  [{"name": "Matthew McConaughey"}]
# 18  superhero|marvel    [{"name": "Robert Downey Jr."}]
#
#                                                  crew     revenue
# 5   [{"name": "Christopher Nolan", "job": "Directo...   839000000
# 6   [{"name": "Christopher Nolan", "job": "Directo...  1004558444
# 9   [{"name": "Steven Spielberg", "job": "Director"}]   219417255
# 16  [{"name": "Christopher Nolan", "job": "Directo...   701729206
# 18     [{"name": "Anthony Russo", "job": "Director"}]  2797501328
#
# [5 rows x 23 columns]

# %%
long_english_movies.shape
# Out:
# (9, 23)

# %% [markdown]
# # <u>**Next let us see how we can manipulate columns**</u>

# %%
df.shape
# Out:
# (30, 23)

# %% [markdown]
# ## **Let's say if you wanted a new column whose values were half the movie runtime**

# %%
df['runtime']
# Out:
# 0      93.0
# 1     113.0
# 2     105.0
# 3     122.0
# 4     118.0
# 5     148.0
# 6     152.0
# 7     170.0
# 8     132.0
# 9     128.0
# 10    106.0
# 11    102.0
# 12    102.0
# 13    120.0
# 14     90.0
# 15    106.0
# 16    169.0
# 17    161.0
# 18    181.0
# 19    194.0
# 20    125.0
# 21    175.0
# 22      0.0
# 23      NaN
# 24    148.0
# 25    187.0
# 26    168.0
# 27    122.0
# 28    128.0
# 29    181.0
# Name: runtime, dtype: float64

# %%
# Add new column which is just half the runtime
df['half_runtime'] = df['runtime'] * 0.5

# %%
df.head()
# Out:
#    id                     belongs_to_collection    budget  \
# 0   1                    Hot Tub Time Machine 2  14000000
# 1   2  The Princess Diaries 2: Royal Engagement  40000000
# 2   3                                  Whiplash   3300000
# 3   4                                   Kahaani   1200000
# 4   5                                Marine Boy         0
#
#                                        genres  \
# 0                        [{"name": "Comedy"}]
# 1     [{"name": "Comedy"}, {"name": "Drama"}]
# 2                         [{"name": "Drama"}]
# 3   [{"name": "Thriller"}, {"name": "Drama"}]
# 4  [{"name": "Action"}, {"name": "Thriller"}]
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  ... runtime  \
# 0                                Time travel comedy.    6.575393  ...    93.0
# 1                  A princess prepares for marriage.    8.248895  ...   113.0
# 2       A young drummer faces a ruthless instructor.   64.299990  ...   105.0
# 3  A woman searches for her missing husband in Ko...    3.174936  ...   122.0
# 4        A former swimmer becomes involved in crime.    1.148070  ...   118.0
#
#               spoken_languages    status  \
# 0        [{"name": "English"}]  Released
# 1        [{"name": "English"}]  Released
# 2        [{"name": "English"}]  Released
# 3  [{"name": "English|Hindi"}]  Released
# 4         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                                              NaN
# 4                                              NaN
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy               NaN
#
#                           cast  \
# 0    [{"name": "Rob Corddry"}]
# 1  [{"name": "Anne Hathaway"}]
# 2   [{"name": "Miles Teller"}]
# 3    [{"name": "Vidya Balan"}]
# 4   [{"name": "Kim Kang-woo"}]
#
#                                                crew   revenue half_runtime
# 0       [{"name": "Steve Pink", "job": "Director"}]  12314651         46.5
# 1   [{"name": "Garry Marshall", "job": "Director"}]  95149435         56.5
# 2  [{"name": "Damien Chazelle", "job": "Director"}]  13092000         52.5
# 3      [{"name": "Sujoy Ghosh", "job": "Director"}]  16000000         61.0
# 4   [{"name": "Yoon Jong-chan", "job": "Director"}]   3923970         59.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## We can also create a new column by adding two existing columns

# %%
# Creating another new column by subtracting/adding two existing columns
df['movie_profit'] = df['revenue'] - df['budget']

# %%
df.head()
# Out:
#    id                     belongs_to_collection    budget  \
# 0   1                    Hot Tub Time Machine 2  14000000
# 1   2  The Princess Diaries 2: Royal Engagement  40000000
# 2   3                                  Whiplash   3300000
# 3   4                                   Kahaani   1200000
# 4   5                                Marine Boy         0
#
#                                        genres  \
# 0                        [{"name": "Comedy"}]
# 1     [{"name": "Comedy"}, {"name": "Drama"}]
# 2                         [{"name": "Drama"}]
# 3   [{"name": "Thriller"}, {"name": "Drama"}]
# 4  [{"name": "Action"}, {"name": "Thriller"}]
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  ...  \
# 0                                Time travel comedy.    6.575393  ...
# 1                  A princess prepares for marriage.    8.248895  ...
# 2       A young drummer faces a ruthless instructor.   64.299990  ...
# 3  A woman searches for her missing husband in Ko...    3.174936  ...
# 4        A former swimmer becomes involved in crime.    1.148070  ...
#
#               spoken_languages    status  \
# 0        [{"name": "English"}]  Released
# 1        [{"name": "English"}]  Released
# 2        [{"name": "English"}]  Released
# 3  [{"name": "English|Hindi"}]  Released
# 4         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                                              NaN
# 4                                              NaN
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy               NaN
#
#                           cast  \
# 0    [{"name": "Rob Corddry"}]
# 1  [{"name": "Anne Hathaway"}]
# 2   [{"name": "Miles Teller"}]
# 3    [{"name": "Vidya Balan"}]
# 4   [{"name": "Kim Kang-woo"}]
#
#                                                crew   revenue half_runtime  \
# 0       [{"name": "Steve Pink", "job": "Director"}]  12314651         46.5
# 1   [{"name": "Garry Marshall", "job": "Director"}]  95149435         56.5
# 2  [{"name": "Damien Chazelle", "job": "Director"}]  13092000         52.5
# 3      [{"name": "Sujoy Ghosh", "job": "Director"}]  16000000         61.0
# 4   [{"name": "Yoon Jong-chan", "job": "Director"}]   3923970         59.0
#
#   movie_profit
# 0     -1685349
# 1     55149435
# 2      9792000
# 3     14800000
# 4      3923970
#
# [5 rows x 25 columns]

# %% [markdown]
# ## **Next, we can also drop some columns which we want to drop**

# %%
# Remove column
df.drop(['id'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#                       belongs_to_collection    budget  \
# 0                    Hot Tub Time Machine 2  14000000
# 1  The Princess Diaries 2: Royal Engagement  40000000
# 2                                  Whiplash   3300000
# 3                                   Kahaani   1200000
# 4                                Marine Boy         0
#
#                                        genres  \
# 0                        [{"name": "Comedy"}]
# 1     [{"name": "Comedy"}, {"name": "Drama"}]
# 2                         [{"name": "Drama"}]
# 3   [{"name": "Thriller"}, {"name": "Drama"}]
# 4  [{"name": "Action"}, {"name": "Thriller"}]
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
#
#     poster_path  ...             spoken_languages    status  \
# 0  /poster1.jpg  ...        [{"name": "English"}]  Released
# 1  /poster2.jpg  ...        [{"name": "English"}]  Released
# 2  /poster3.jpg  ...        [{"name": "English"}]  Released
# 3  /poster4.jpg  ...  [{"name": "English|Hindi"}]  Released
# 4  /poster5.jpg  ...         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                                              NaN
# 4                                              NaN
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy               NaN
#
#                           cast  \
# 0    [{"name": "Rob Corddry"}]
# 1  [{"name": "Anne Hathaway"}]
# 2   [{"name": "Miles Teller"}]
# 3    [{"name": "Vidya Balan"}]
# 4   [{"name": "Kim Kang-woo"}]
#
#                                                crew   revenue half_runtime  \
# 0       [{"name": "Steve Pink", "job": "Director"}]  12314651         46.5
# 1   [{"name": "Garry Marshall", "job": "Director"}]  95149435         56.5
# 2  [{"name": "Damien Chazelle", "job": "Director"}]  13092000         52.5
# 3      [{"name": "Sujoy Ghosh", "job": "Director"}]  16000000         61.0
# 4   [{"name": "Yoon Jong-chan", "job": "Director"}]   3923970         59.0
#
#   movie_profit
# 0     -1685349
# 1     55149435
# 2      9792000
# 3     14800000
# 4      3923970
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#              budget  popularity     runtime       revenue  half_runtime  \
# count  3.000000e+01   30.000000   29.000000  3.000000e+01     29.000000
# mean   1.009633e+08   39.042643  132.620690  5.554160e+08     66.310345
# std    1.492895e+08   31.461444   40.063712  7.579332e+08     20.031856
# min    0.000000e+00    1.148070    0.000000  0.000000e+00      0.000000
# 25%    1.205000e+07   11.009082  106.000000  2.325000e+07     53.000000
# 50%    4.000000e+07   30.350000  128.000000  2.347086e+08     64.000000
# 75%    1.400000e+08   69.249998  168.000000  8.046823e+08     84.000000
# max    5.500000e+08   95.300000  194.000000  2.797501e+09     97.000000
#
#        movie_profit
# count  3.000000e+01
# mean   4.544527e+08
# std    6.478400e+08
# min   -8.000000e+07
# 25%    1.610000e+07
# 50%    1.997086e+08
# 75%    6.216823e+08
# max    2.441501e+09

# %% [markdown]
# ## You can drop  multiple columns at once too.

# %%
df.drop(['half_runtime','poster_path'],axis=1,inplace=True)

# %%
df.drop(['crew'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#                       belongs_to_collection    budget  \
# 0                    Hot Tub Time Machine 2  14000000
# 1  The Princess Diaries 2: Royal Engagement  40000000
# 2                                  Whiplash   3300000
# 3                                   Kahaani   1200000
# 4                                Marine Boy         0
#
#                                        genres  \
# 0                        [{"name": "Comedy"}]
# 1     [{"name": "Comedy"}, {"name": "Drama"}]
# 2                         [{"name": "Drama"}]
# 3   [{"name": "Thriller"}, {"name": "Drama"}]
# 4  [{"name": "Action"}, {"name": "Thriller"}]
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
#
#                  production_companies  ... release_date runtime  \
# 0    [{"name": "Paramount Pictures"}]  ...      2/20/15    93.0
# 1  [{"name": "Walt Disney Pictures"}]  ...       8/6/04   113.0
# 2            [{"name": "Bold Films"}]  ...     10/10/14   105.0
# 3                                 NaN  ...       3/9/12   122.0
# 4                                 NaN  ...       2/5/09   118.0
#
#               spoken_languages    status  \
# 0        [{"name": "English"}]  Released
# 1        [{"name": "English"}]  Released
# 2        [{"name": "English"}]  Released
# 3  [{"name": "English|Hindi"}]  Released
# 4         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                                              NaN
# 4                                              NaN
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy               NaN
#
#                           cast   revenue  movie_profit
# 0    [{"name": "Rob Corddry"}]  12314651      -1685349
# 1  [{"name": "Anne Hathaway"}]  95149435      55149435
# 2   [{"name": "Miles Teller"}]  13092000       9792000
# 3    [{"name": "Vidya Balan"}]  16000000      14800000
# 4   [{"name": "Kim Kang-woo"}]   3923970       3923970
#
# [5 rows x 21 columns]

# %% [markdown]
# ## **We can do a lot of basic operations as well**

# %%
# Find the sum of values in a column
df['budget'].sum()
# Out:
# np.int64(3028900000)

# %%
# What if there is a null value
df.loc[:1,'revenue'] = np.nan

# %%
df.iloc[:5]
# Out:
#                       belongs_to_collection    budget  \
# 0                    Hot Tub Time Machine 2  14000000
# 1  The Princess Diaries 2: Royal Engagement  40000000
# 2                                  Whiplash   3300000
# 3                                   Kahaani   1200000
# 4                                Marine Boy         0
#
#                                        genres  \
# 0                        [{"name": "Comedy"}]
# 1     [{"name": "Comedy"}, {"name": "Drama"}]
# 2                         [{"name": "Drama"}]
# 3   [{"name": "Thriller"}, {"name": "Drama"}]
# 4  [{"name": "Action"}, {"name": "Thriller"}]
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
#
#                  production_companies  ... release_date runtime  \
# 0    [{"name": "Paramount Pictures"}]  ...      2/20/15    93.0
# 1  [{"name": "Walt Disney Pictures"}]  ...       8/6/04   113.0
# 2            [{"name": "Bold Films"}]  ...     10/10/14   105.0
# 3                                 NaN  ...       3/9/12   122.0
# 4                                 NaN  ...       2/5/09   118.0
#
#               spoken_languages    status  \
# 0        [{"name": "English"}]  Released
# 1        [{"name": "English"}]  Released
# 2        [{"name": "English"}]  Released
# 3  [{"name": "English|Hindi"}]  Released
# 4         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                                              NaN
# 4                                              NaN
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy               NaN
#
#                           cast     revenue  movie_profit
# 0    [{"name": "Rob Corddry"}]         NaN      -1685349
# 1  [{"name": "Anne Hathaway"}]         NaN      55149435
# 2   [{"name": "Miles Teller"}]  13092000.0       9792000
# 3    [{"name": "Vidya Balan"}]  16000000.0      14800000
# 4   [{"name": "Kim Kang-woo"}]   3923970.0       3923970
#
# [5 rows x 21 columns]

# %%
df.set_index('imdb_id', inplace=True)

# %%
df.head()
# Out:
#                               belongs_to_collection    budget  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2  14000000
# tt0368933  The Princess Diaries 2: Royal Engagement  40000000
# tt2582802                                  Whiplash   3300000
# tt1821480                                   Kahaani   1200000
# tt1380152                                Marine Boy         0
#
#                                                genres  \
# imdb_id
# tt2637294                        [{"name": "Comedy"}]
# tt0368933     [{"name": "Comedy"}, {"name": "Drama"}]
# tt2582802                         [{"name": "Drama"}]
# tt1821480   [{"name": "Thriller"}, {"name": "Drama"}]
# tt1380152  [{"name": "Action"}, {"name": "Thriller"}]
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# tt0368933                                NaN                en
# tt2582802  http://sonyclassics.com/whiplash/                en
# tt1821480         http://kahaanithefilm.com/                hi
# tt1380152                                NaN                ko
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                Marine Boy
#
#                                                     overview  popularity  \
# imdb_id
# tt2637294                                Time travel comedy.    6.575393
# tt0368933                  A princess prepares for marriage.    8.248895
# tt2582802       A young drummer faces a ruthless instructor.   64.299990
# tt1821480  A woman searches for her missing husband in Ko...    3.174936
# tt1380152        A former swimmer becomes involved in crime.    1.148070
#
#                          production_companies    production_countries  \
# imdb_id
# tt2637294    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# tt0368933  [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]
# tt2582802            [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]
# tt1821480                                 NaN  [{"iso_3166_1": "IN"}]
# tt1380152                                 NaN  [{"iso_3166_1": "KR"}]
#
#           release_date  runtime             spoken_languages    status  \
# imdb_id
# tt2637294      2/20/15     93.0        [{"name": "English"}]  Released
# tt0368933       8/6/04    113.0        [{"name": "English"}]  Released
# tt2582802     10/10/14    105.0        [{"name": "English"}]  Released
# tt1821480       3/9/12    122.0  [{"name": "English|Hindi"}]  Released
# tt1380152       2/5/09    118.0         [{"name": "Korean"}]  Released
#
#                                                    tagline  \
# imdb_id
# tt2637294                       The Laws of Space and Time
# tt0368933        It can take a lifetime to find true love.
# tt2582802  The road to greatness can take you to the edge.
# tt1821480                                              NaN
# tt1380152                                              NaN
#
#                                               title          Keywords  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2       time travel
# tt0368933  The Princess Diaries 2: Royal Engagement  princess|royalty
# tt2582802                                  Whiplash        jazz|music
# tt1821480                                   Kahaani   mystery|kolkata
# tt1380152                                Marine Boy               NaN
#
#                                   cast     revenue  movie_profit
# imdb_id
# tt2637294    [{"name": "Rob Corddry"}]         NaN      -1685349
# tt0368933  [{"name": "Anne Hathaway"}]         NaN      55149435
# tt2582802   [{"name": "Miles Teller"}]  13092000.0       9792000
# tt1821480    [{"name": "Vidya Balan"}]  16000000.0      14800000
# tt1380152   [{"name": "Kim Kang-woo"}]   3923970.0       3923970

# %%
df.iloc[:3]
# Out:
#                               belongs_to_collection    budget  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2  14000000
# tt0368933  The Princess Diaries 2: Royal Engagement  40000000
# tt2582802                                  Whiplash   3300000
#
#                                             genres  \
# imdb_id
# tt2637294                     [{"name": "Comedy"}]
# tt0368933  [{"name": "Comedy"}, {"name": "Drama"}]
# tt2582802                      [{"name": "Drama"}]
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# tt0368933                                NaN                en
# tt2582802  http://sonyclassics.com/whiplash/                en
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
#
#                                                overview  popularity  \
# imdb_id
# tt2637294                           Time travel comedy.    6.575393
# tt0368933             A princess prepares for marriage.    8.248895
# tt2582802  A young drummer faces a ruthless instructor.   64.299990
#
#                          production_companies    production_countries  \
# imdb_id
# tt2637294    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# tt0368933  [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]
# tt2582802            [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]
#
#           release_date  runtime       spoken_languages    status  \
# imdb_id
# tt2637294      2/20/15     93.0  [{"name": "English"}]  Released
# tt0368933       8/6/04    113.0  [{"name": "English"}]  Released
# tt2582802     10/10/14    105.0  [{"name": "English"}]  Released
#
#                                                    tagline  \
# imdb_id
# tt2637294                       The Laws of Space and Time
# tt0368933        It can take a lifetime to find true love.
# tt2582802  The road to greatness can take you to the edge.
#
#                                               title          Keywords  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2       time travel
# tt0368933  The Princess Diaries 2: Royal Engagement  princess|royalty
# tt2582802                                  Whiplash        jazz|music
#
#                                   cast     revenue  movie_profit
# imdb_id
# tt2637294    [{"name": "Rob Corddry"}]         NaN      -1685349
# tt0368933  [{"name": "Anne Hathaway"}]         NaN      55149435
# tt2582802   [{"name": "Miles Teller"}]  13092000.0       9792000

# %%
df.loc[['tt2637294','tt0368933']]
# Out:
#                               belongs_to_collection    budget  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2  14000000
# tt0368933  The Princess Diaries 2: Royal Engagement  40000000
#
#                                             genres homepage original_language  \
# imdb_id
# tt2637294                     [{"name": "Comedy"}]      NaN                en
# tt0368933  [{"name": "Comedy"}, {"name": "Drama"}]      NaN                en
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
#
#                                     overview  popularity  \
# imdb_id
# tt2637294                Time travel comedy.    6.575393
# tt0368933  A princess prepares for marriage.    8.248895
#
#                          production_companies    production_countries  \
# imdb_id
# tt2637294    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# tt0368933  [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]
#
#           release_date  runtime       spoken_languages    status  \
# imdb_id
# tt2637294      2/20/15     93.0  [{"name": "English"}]  Released
# tt0368933       8/6/04    113.0  [{"name": "English"}]  Released
#
#                                              tagline  \
# imdb_id
# tt2637294                 The Laws of Space and Time
# tt0368933  It can take a lifetime to find true love.
#
#                                               title          Keywords  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2       time travel
# tt0368933  The Princess Diaries 2: Royal Engagement  princess|royalty
#
#                                   cast  revenue  movie_profit
# imdb_id
# tt2637294    [{"name": "Rob Corddry"}]      NaN      -1685349
# tt0368933  [{"name": "Anne Hathaway"}]      NaN      55149435

# %%
df.head()
# Out:
#                               belongs_to_collection    budget  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2  14000000
# tt0368933  The Princess Diaries 2: Royal Engagement  40000000
# tt2582802                                  Whiplash   3300000
# tt1821480                                   Kahaani   1200000
# tt1380152                                Marine Boy         0
#
#                                                genres  \
# imdb_id
# tt2637294                        [{"name": "Comedy"}]
# tt0368933     [{"name": "Comedy"}, {"name": "Drama"}]
# tt2582802                         [{"name": "Drama"}]
# tt1821480   [{"name": "Thriller"}, {"name": "Drama"}]
# tt1380152  [{"name": "Action"}, {"name": "Thriller"}]
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# tt0368933                                NaN                en
# tt2582802  http://sonyclassics.com/whiplash/                en
# tt1821480         http://kahaanithefilm.com/                hi
# tt1380152                                NaN                ko
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                Marine Boy
#
#                                                     overview  popularity  \
# imdb_id
# tt2637294                                Time travel comedy.    6.575393
# tt0368933                  A princess prepares for marriage.    8.248895
# tt2582802       A young drummer faces a ruthless instructor.   64.299990
# tt1821480  A woman searches for her missing husband in Ko...    3.174936
# tt1380152        A former swimmer becomes involved in crime.    1.148070
#
#                          production_companies    production_countries  \
# imdb_id
# tt2637294    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# tt0368933  [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]
# tt2582802            [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]
# tt1821480                                 NaN  [{"iso_3166_1": "IN"}]
# tt1380152                                 NaN  [{"iso_3166_1": "KR"}]
#
#           release_date  runtime             spoken_languages    status  \
# imdb_id
# tt2637294      2/20/15     93.0        [{"name": "English"}]  Released
# tt0368933       8/6/04    113.0        [{"name": "English"}]  Released
# tt2582802     10/10/14    105.0        [{"name": "English"}]  Released
# tt1821480       3/9/12    122.0  [{"name": "English|Hindi"}]  Released
# tt1380152       2/5/09    118.0         [{"name": "Korean"}]  Released
#
#                                                    tagline  \
# imdb_id
# tt2637294                       The Laws of Space and Time
# tt0368933        It can take a lifetime to find true love.
# tt2582802  The road to greatness can take you to the edge.
# tt1821480                                              NaN
# tt1380152                                              NaN
#
#                                               title          Keywords  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2       time travel
# tt0368933  The Princess Diaries 2: Royal Engagement  princess|royalty
# tt2582802                                  Whiplash        jazz|music
# tt1821480                                   Kahaani   mystery|kolkata
# tt1380152                                Marine Boy               NaN
#
#                                   cast     revenue  movie_profit
# imdb_id
# tt2637294    [{"name": "Rob Corddry"}]         NaN      -1685349
# tt0368933  [{"name": "Anne Hathaway"}]         NaN      55149435
# tt2582802   [{"name": "Miles Teller"}]  13092000.0       9792000
# tt1821480    [{"name": "Vidya Balan"}]  16000000.0      14800000
# tt1380152   [{"name": "Kim Kang-woo"}]   3923970.0       3923970

# %%
df['runtime'].sum()
# Out:
# np.float64(3846.0)

# %%
print(f" The shortest movie length is {df['runtime'].min()}")
print(f" The largest movie length is {df['runtime'].max()}")
# Out:
#  The shortest movie length is 0.0
#  The largest movie length is 194.0

# %%
df[df['runtime']== 0.0]
# Out:
#           belongs_to_collection    budget  \
# imdb_id
# tt9000001      3 Idiots Returns  80000000
#
#                                             genres homepage original_language  \
# imdb_id
# tt9000001  [{"name": "Comedy"}, {"name": "Drama"}]      NaN                hi
#
#              original_title                              overview  popularity  \
# imdb_id
# tt9000001  3 Idiots Returns  Friends reunite years after college.        18.2
#
#                  production_companies    production_countries release_date  \
# imdb_id
# tt9000001  [{"name": "Demo Studios"}]  [{"iso_3166_1": "IN"}]      8/15/20
#
#            runtime     spoken_languages   status tagline             title  \
# imdb_id
# tt9000001      0.0  [{"name": "Hindi"}]  Rumored     NaN  3 Idiots Returns
#
#           Keywords                      cast  revenue  movie_profit
# imdb_id
# tt9000001  college  [{"name": "Aamir Khan"}]      0.0     -80000000

# %% [markdown]
# # **<code>apply()</code>** method applies a function to every row in a pandas dataframe

# %%
# Suppose we want to convert the column network to uppercase

def to_uppercase(column):
  return column.upper()

# %%
df['Capitalized_title'] = df['title'].apply(to_uppercase)

# %%
df.head()
# Out:
#                               belongs_to_collection    budget  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2  14000000
# tt0368933  The Princess Diaries 2: Royal Engagement  40000000
# tt2582802                                  Whiplash   3300000
# tt1821480                                   Kahaani   1200000
# tt1380152                                Marine Boy         0
#
#                                                genres  \
# imdb_id
# tt2637294                        [{"name": "Comedy"}]
# tt0368933     [{"name": "Comedy"}, {"name": "Drama"}]
# tt2582802                         [{"name": "Drama"}]
# tt1821480   [{"name": "Thriller"}, {"name": "Drama"}]
# tt1380152  [{"name": "Action"}, {"name": "Thriller"}]
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# tt0368933                                NaN                en
# tt2582802  http://sonyclassics.com/whiplash/                en
# tt1821480         http://kahaanithefilm.com/                hi
# tt1380152                                NaN                ko
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                Marine Boy
#
#                                                     overview  popularity  \
# imdb_id
# tt2637294                                Time travel comedy.    6.575393
# tt0368933                  A princess prepares for marriage.    8.248895
# tt2582802       A young drummer faces a ruthless instructor.   64.299990
# tt1821480  A woman searches for her missing husband in Ko...    3.174936
# tt1380152        A former swimmer becomes involved in crime.    1.148070
#
#                          production_companies    production_countries  ...  \
# imdb_id                                                                ...
# tt2637294    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]  ...
# tt0368933  [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]  ...
# tt2582802            [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]  ...
# tt1821480                                 NaN  [{"iso_3166_1": "IN"}]  ...
# tt1380152                                 NaN  [{"iso_3166_1": "KR"}]  ...
#
#           runtime             spoken_languages    status  \
# imdb_id
# tt2637294    93.0        [{"name": "English"}]  Released
# tt0368933   113.0        [{"name": "English"}]  Released
# tt2582802   105.0        [{"name": "English"}]  Released
# tt1821480   122.0  [{"name": "English|Hindi"}]  Released
# tt1380152   118.0         [{"name": "Korean"}]  Released
#
#                                                    tagline  \
# imdb_id
# tt2637294                       The Laws of Space and Time
# tt0368933        It can take a lifetime to find true love.
# tt2582802  The road to greatness can take you to the edge.
# tt1821480                                              NaN
# tt1380152                                              NaN
#
#                                               title          Keywords  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2       time travel
# tt0368933  The Princess Diaries 2: Royal Engagement  princess|royalty
# tt2582802                                  Whiplash        jazz|music
# tt1821480                                   Kahaani   mystery|kolkata
# tt1380152                                Marine Boy               NaN
#
#                                   cast     revenue  movie_profit  \
# imdb_id
# tt2637294    [{"name": "Rob Corddry"}]         NaN      -1685349
# tt0368933  [{"name": "Anne Hathaway"}]         NaN      55149435
# tt2582802   [{"name": "Miles Teller"}]  13092000.0       9792000
# tt1821480    [{"name": "Vidya Balan"}]  16000000.0      14800000
# tt1380152   [{"name": "Kim Kang-woo"}]   3923970.0       3923970
#
#                                   Capitalized_title
# imdb_id
# tt2637294                    HOT TUB TIME MACHINE 2
# tt0368933  THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# tt2582802                                  WHIPLASH
# tt1821480                                   KAHAANI
# tt1380152                                MARINE BOY
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Another way to use <code>apply()</code> involves the use of <code>lambda()</code> function.
#
# * ### A <code>lambda()</code> function is a small anonymous function.
# * ### A <code>lambda()</code> function can take any number of arguments, but can only have one expression.

# %%
def add_two_numbers(a,b):
  return a+b

# %%
x = lambda a,b : a+b
x(1,5)
# Out:
# 6

# %%
# lambda function - Row wise operation
def revised_profit(revenue, budget):
  if revenue > 0:
    new_profit = revenue - budget
  else:
    new_profit = np.nan

  return new_profit

# %%
df['new_profit'] = df.apply(lambda x: revised_profit(x['revenue'], x['budget']),axis=1)

# %%
df.head()
# Out:
#                               belongs_to_collection    budget  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2  14000000
# tt0368933  The Princess Diaries 2: Royal Engagement  40000000
# tt2582802                                  Whiplash   3300000
# tt1821480                                   Kahaani   1200000
# tt1380152                                Marine Boy         0
#
#                                                genres  \
# imdb_id
# tt2637294                        [{"name": "Comedy"}]
# tt0368933     [{"name": "Comedy"}, {"name": "Drama"}]
# tt2582802                         [{"name": "Drama"}]
# tt1821480   [{"name": "Thriller"}, {"name": "Drama"}]
# tt1380152  [{"name": "Action"}, {"name": "Thriller"}]
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# tt0368933                                NaN                en
# tt2582802  http://sonyclassics.com/whiplash/                en
# tt1821480         http://kahaanithefilm.com/                hi
# tt1380152                                NaN                ko
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                Marine Boy
#
#                                                     overview  popularity  \
# imdb_id
# tt2637294                                Time travel comedy.    6.575393
# tt0368933                  A princess prepares for marriage.    8.248895
# tt2582802       A young drummer faces a ruthless instructor.   64.299990
# tt1821480  A woman searches for her missing husband in Ko...    3.174936
# tt1380152        A former swimmer becomes involved in crime.    1.148070
#
#                          production_companies    production_countries  ...  \
# imdb_id                                                                ...
# tt2637294    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]  ...
# tt0368933  [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]  ...
# tt2582802            [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]  ...
# tt1821480                                 NaN  [{"iso_3166_1": "IN"}]  ...
# tt1380152                                 NaN  [{"iso_3166_1": "KR"}]  ...
#
#                       spoken_languages    status  \
# imdb_id
# tt2637294        [{"name": "English"}]  Released
# tt0368933        [{"name": "English"}]  Released
# tt2582802        [{"name": "English"}]  Released
# tt1821480  [{"name": "English|Hindi"}]  Released
# tt1380152         [{"name": "Korean"}]  Released
#
#                                                    tagline  \
# imdb_id
# tt2637294                       The Laws of Space and Time
# tt0368933        It can take a lifetime to find true love.
# tt2582802  The road to greatness can take you to the edge.
# tt1821480                                              NaN
# tt1380152                                              NaN
#
#                                               title          Keywords  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2       time travel
# tt0368933  The Princess Diaries 2: Royal Engagement  princess|royalty
# tt2582802                                  Whiplash        jazz|music
# tt1821480                                   Kahaani   mystery|kolkata
# tt1380152                                Marine Boy               NaN
#
#                                   cast     revenue movie_profit  \
# imdb_id
# tt2637294    [{"name": "Rob Corddry"}]         NaN     -1685349
# tt0368933  [{"name": "Anne Hathaway"}]         NaN     55149435
# tt2582802   [{"name": "Miles Teller"}]  13092000.0      9792000
# tt1821480    [{"name": "Vidya Balan"}]  16000000.0     14800000
# tt1380152   [{"name": "Kim Kang-woo"}]   3923970.0      3923970
#
#                                   Capitalized_title  new_profit
# imdb_id
# tt2637294                    HOT TUB TIME MACHINE 2         NaN
# tt0368933  THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT         NaN
# tt2582802                                  WHIPLASH   9792000.0
# tt1821480                                   KAHAANI  14800000.0
# tt1380152                                MARINE BOY   3923970.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## We can also sort our dataframe by some column values in either an ascending or descending order

# %%
# Sort values in descending order
df.sort_values('runtime', ascending=False)
# Out:
#                                belongs_to_collection     budget  \
# imdb_id
# tt0120338                                    Titanic  200000000
# tt8178634                                        RRR  550000000
# tt0112870                Dilwale Dulhania Le Jayenge   40000000
# tt4154796                          Avengers: Endgame  356000000
# tt0068646                              The Godfather    6000000
# tt1187043                                   3 Idiots  550000000
# tt0816692                               Interstellar  165000000
# tt4849438                 Bahubali 2: The Conclusion  250000000
# tt5074352                                     Dangal   70000000
# tt0468569                            The Dark Knight  185000000
# tt1375666                                  Inception  160000000
# tt15327088                                   Kantara   16000000
# tt6751668                                   Parasite   11400000
# tt0362227                               The Terminal   60000000
# tt3783958                                 La La Land   30000000
# tt0245429                              Spirited Away   19000000
# tt7286456                                      Joker   55000000
# tt1821480                                    Kahaani    1200000
# tt0116908                    The Long Kiss Goodnight   65000000
# tt1380152                                 Marine Boy          0
# tt0368933   The Princess Diaries 2: Royal Engagement   40000000
# tt0105327                                School Ties          0
# tt1600195                                  Abduction   35000000
# tt2582802                                   Whiplash    3300000
# tt0109403                                    Chasers          0
# tt2364975                           We Are the Best!          0
# tt2637294                     Hot Tub Time Machine 2   14000000
# tt0343135                           Along Came Polly   42000000
# tt9000001                           3 Idiots Returns   80000000
# tt9000002                              Mystery Movie   25000000
#
#                                                        genres  \
# imdb_id
# tt0120338            [{"name": "Drama"}, {"name": "Romance"}]
# tt8178634             [{"name": "Action"}, {"name": "Drama"}]
# tt0112870            [{"name": "Drama"}, {"name": "Romance"}]
# tt4154796   [{"name": "Action"}, {"name": "Adventure"}, {"...
# tt0068646              [{"name": "Crime"}, {"name": "Drama"}]
# tt1187043             [{"name": "Comedy"}, {"name": "Drama"}]
# tt0816692   [{"name": "Adventure"}, {"name": "Drama"}, {"n...
# tt4849438             [{"name": "Action"}, {"name": "Drama"}]
# tt5074352              [{"name": "Drama"}, {"name": "Sport"}]
# tt0468569   [{"name": "Action"}, {"name": "Crime"}, {"name...
# tt1375666            [{"name": "Action"}, {"name": "Sci-Fi"}]
# tt15327088            [{"name": "Action"}, {"name": "Drama"}]
# tt6751668           [{"name": "Drama"}, {"name": "Thriller"}]
# tt0362227             [{"name": "Comedy"}, {"name": "Drama"}]
# tt3783958   [{"name": "Comedy"}, {"name": "Drama"}, {"name...
# tt0245429        [{"name": "Animation"}, {"name": "Fantasy"}]
# tt7286456              [{"name": "Crime"}, {"name": "Drama"}]
# tt1821480           [{"name": "Thriller"}, {"name": "Drama"}]
# tt0116908             [{"name": "Crime"}, {"name": "Action"}]
# tt1380152          [{"name": "Action"}, {"name": "Thriller"}]
# tt0368933             [{"name": "Comedy"}, {"name": "Drama"}]
# tt0105327                                 [{"name": "Drama"}]
# tt1600195          [{"name": "Thriller"}, {"name": "Action"}]
# tt2582802                                 [{"name": "Drama"}]
# tt0109403           [{"name": "Comedy"}, {"name": "Romance"}]
# tt2364975              [{"name": "Drama"}, {"name": "Music"}]
# tt2637294                                [{"name": "Comedy"}]
# tt0343135           [{"name": "Comedy"}, {"name": "Romance"}]
# tt9000001             [{"name": "Comedy"}, {"name": "Drama"}]
# tt9000002                                                 NaN
#
#                                         homepage original_language  \
# imdb_id
# tt0120338                                    NaN                en
# tt8178634                                    NaN                te
# tt0112870                                    NaN                hi
# tt4154796                                    NaN                en
# tt0068646                                    NaN                en
# tt1187043            https://example.com/3idiots                hi
# tt0816692                                    NaN                en
# tt4849438                                    NaN                te
# tt5074352                                    NaN                hi
# tt0468569                                    NaN                en
# tt1375666          https://example.com/inception                en
# tt15327088           https://example.com/kantara                kn
# tt6751668                                    NaN                ko
# tt0362227   http://www.theterminal-themovie.com/                en
# tt3783958                                    NaN                en
# tt0245429           https://example.com/spirited                ja
# tt7286456                                    NaN                en
# tt1821480             http://kahaanithefilm.com/                hi
# tt0116908                                    NaN                en
# tt1380152                                    NaN                ko
# tt0368933                                    NaN                en
# tt0105327                                    NaN                en
# tt1600195       http://www.abductionthefilm.com/                en
# tt2582802      http://sonyclassics.com/whiplash/                en
# tt0109403                                    NaN                en
# tt2364975                                    NaN                sv
# tt2637294                                    NaN                en
# tt0343135         http://www.alongcamepolly.com/                en
# tt9000001                                    NaN                hi
# tt9000002                                    NaN                en
#
#                                       original_title  \
# imdb_id
# tt0120338                                    Titanic
# tt8178634                                        RRR
# tt0112870                Dilwale Dulhania Le Jayenge
# tt4154796                          Avengers: Endgame
# tt0068646                              The Godfather
# tt1187043                                   3 Idiots
# tt0816692                               Interstellar
# tt4849438                Baahubali 2: The Conclusion
# tt5074352                                     Dangal
# tt0468569                            The Dark Knight
# tt1375666                                  Inception
# tt15327088                                   Kantara
# tt6751668                                   Parasite
# tt0362227                               The Terminal
# tt3783958                                 La La Land
# tt0245429                              Spirited Away
# tt7286456                                      Joker
# tt1821480                                    Kahaani
# tt0116908                    The Long Kiss Goodnight
# tt1380152                                 Marine Boy
# tt0368933   The Princess Diaries 2: Royal Engagement
# tt0105327                                School Ties
# tt1600195                                  Abduction
# tt2582802                                   Whiplash
# tt0109403                                    Chasers
# tt2364975                           We Are the Best!
# tt2637294                     Hot Tub Time Machine 2
# tt0343135                           Along Came Polly
# tt9000001                           3 Idiots Returns
# tt9000002                              Mystery Movie
#
#                                                      overview  popularity  \
# imdb_id
# tt0120338             A romance unfolds aboard a doomed ship.   78.500000
# tt8178634    Two revolutionaries form an unlikely friendship.   60.300000
# tt0112870      A young couple challenges family expectations.   20.600000
# tt4154796       Heroes attempt to reverse a devastating loss.   88.200000
# tt0068646   The aging patriarch transfers control of his e...   95.300000
# tt1187043            Three friends navigate college and life.   25.300000
# tt0816692       Explorers travel through a wormhole in space.   75.000000
# tt4849438                A kingdom seeks answers and revenge.   52.900000
# tt5074352   A father trains his daughters to become wrestl...   35.400000
# tt0468569                             Batman faces the Joker.   90.100000
# tt1375666             A thief enters dreams to steal secrets.   82.500000
# tt15327088  A village conflict involving tradition and nat...   42.700000
# tt6751668   Two families become entangled in a strange sit...   55.700000
# tt0362227               A man becomes stranded in an airport.   14.092373
# tt3783958   A musician and actress pursue dreams in Los An...   35.800000
# tt0245429            A girl enters a mysterious spirit world.   72.100000
# tt7286456              A failed comedian descends into chaos.   70.900000
# tt1821480   A woman searches for her missing husband in Ko...    3.174936
# tt0116908               A woman discovers her forgotten past.   14.482345
# tt1380152         A former swimmer becomes involved in crime.    1.148070
# tt0368933                   A princess prepares for marriage.    8.248895
# tt0105327       A student faces prejudice at an elite school.    7.438381
# tt1600195   A young man searches for the truth about his i...   10.512109
# tt2582802        A young drummer faces a ruthless instructor.   64.299990
# tt0109403                 Two military men escort a prisoner.    9.853270
# tt2364975                       Three girls form a punk band.    3.727996
# tt2637294                                 Time travel comedy.    6.575393
# tt0343135               A cautious man finds unexpected love.   15.725542
# tt9000001                Friends reunite years after college.   18.200000
# tt9000002                 A mystery with incomplete metadata.   12.500000
#
#                             production_companies    production_countries  ...  \
# imdb_id                                                                   ...
# tt0120338         [{"name": "20th Century Fox"}]  [{"iso_3166_1": "US"}]  ...
# tt8178634        [{"name": "DVV Entertainment"}]  [{"iso_3166_1": "IN"}]  ...
# tt0112870           [{"name": "Yash Raj Films"}]  [{"iso_3166_1": "IN"}]  ...
# tt4154796           [{"name": "Marvel Studios"}]  [{"iso_3166_1": "US"}]  ...
# tt0068646       [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]  ...
# tt1187043       [{"name": "Vinod Chopra Films"}]  [{"iso_3166_1": "IN"}]  ...
# tt0816692       [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]  ...
# tt4849438         [{"name": "Arka Media Works"}]  [{"iso_3166_1": "IN"}]  ...
# tt5074352   [{"name": "Aamir Khan Productions"}]  [{"iso_3166_1": "IN"}]  ...
# tt0468569             [{"name": "Warner Bros."}]  [{"iso_3166_1": "US"}]  ...
# tt1375666             [{"name": "Warner Bros."}]  [{"iso_3166_1": "US"}]  ...
# tt15327088           [{"name": "Hombale Films"}]  [{"iso_3166_1": "IN"}]  ...
# tt6751668             [{"name": "Barunson E&A"}]  [{"iso_3166_1": "KR"}]  ...
# tt0362227           [{"name": "DreamWorks SKG"}]  [{"iso_3166_1": "US"}]  ...
# tt3783958                [{"name": "Lionsgate"}]  [{"iso_3166_1": "US"}]  ...
# tt0245429            [{"name": "Studio Ghibli"}]  [{"iso_3166_1": "JP"}]  ...
# tt7286456             [{"name": "Warner Bros."}]  [{"iso_3166_1": "US"}]  ...
# tt1821480                                    NaN  [{"iso_3166_1": "IN"}]  ...
# tt0116908          [{"name": "New Line Cinema"}]  [{"iso_3166_1": "US"}]  ...
# tt1380152                                    NaN  [{"iso_3166_1": "KR"}]  ...
# tt0368933     [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]  ...
# tt0105327       [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]  ...
# tt1600195         [{"name": "Lions Gate Films"}]  [{"iso_3166_1": "US"}]  ...
# tt2582802               [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]  ...
# tt0109403             [{"name": "Warner Bros."}]  [{"iso_3166_1": "US"}]  ...
# tt2364975              [{"name": "Memfis Film"}]  [{"iso_3166_1": "SE"}]  ...
# tt2637294       [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]  ...
# tt0343135             [{"name": "Jersey Films"}]  [{"iso_3166_1": "US"}]  ...
# tt9000001             [{"name": "Demo Studios"}]  [{"iso_3166_1": "IN"}]  ...
# tt9000002                                    NaN  [{"iso_3166_1": "US"}]  ...
#
#                        spoken_languages    status  \
# imdb_id
# tt0120338         [{"name": "English"}]  Released
# tt8178634          [{"name": "Telugu"}]  Released
# tt0112870           [{"name": "Hindi"}]  Released
# tt4154796         [{"name": "English"}]  Released
# tt0068646         [{"name": "English"}]  Released
# tt1187043           [{"name": "Hindi"}]  Released
# tt0816692         [{"name": "English"}]  Released
# tt4849438          [{"name": "Telugu"}]  Released
# tt5074352           [{"name": "Hindi"}]  Released
# tt0468569         [{"name": "English"}]  Released
# tt1375666         [{"name": "English"}]  Released
# tt15327088        [{"name": "Kannada"}]  Released
# tt6751668          [{"name": "Korean"}]  Released
# tt0362227         [{"name": "English"}]  Released
# tt3783958         [{"name": "English"}]  Released
# tt0245429        [{"name": "Japanese"}]  Released
# tt7286456         [{"name": "English"}]  Released
# tt1821480   [{"name": "English|Hindi"}]  Released
# tt0116908         [{"name": "English"}]  Released
# tt1380152          [{"name": "Korean"}]  Released
# tt0368933         [{"name": "English"}]  Released
# tt0105327         [{"name": "English"}]  Released
# tt1600195         [{"name": "English"}]  Released
# tt2582802         [{"name": "English"}]  Released
# tt0109403         [{"name": "English"}]  Released
# tt2364975         [{"name": "Swedish"}]  Released
# tt2637294         [{"name": "English"}]  Released
# tt0343135         [{"name": "English"}]  Released
# tt9000001           [{"name": "Hindi"}]   Rumored
# tt9000002         [{"name": "English"}]  Released
#
#                                                       tagline  \
# imdb_id
# tt0120338           Nothing on Earth could come between them.
# tt8178634                                 Rise. Roar. Revolt.
# tt0112870                               Come... Fall in love.
# tt4154796                                  Avenge the fallen.
# tt0068646                          An offer you can't refuse.
# tt1187043                                        All is well.
# tt0816692   Mankind was born on Earth. It was never meant ...
# tt4849438                    Why did Kattappa kill Baahubali?
# tt5074352                         Gold is pure. So is Dangal.
# tt0468569                                     Why so serious?
# tt1375666                Your mind is the scene of the crime.
# tt15327088             When tradition calls, destiny answers.
# tt6751668                         Act like you own the place.
# tt0362227                                    Life is waiting.
# tt3783958                      Here's to the fools who dream.
# tt0245429        The tunnel led Chihiro to a mysterious town.
# tt7286456                                Put on a happy face.
# tt1821480                                                 NaN
# tt0116908                What's forgotten is not always gone.
# tt1380152                                                 NaN
# tt0368933           It can take a lifetime to find true love.
# tt0105327   Just because you’re accepted doesn’t mean you ...
# tt1600195           They stole his life. He's taking it back.
# tt2582802     The road to greatness can take you to the edge.
# tt0109403   It was supposed to be a routine prisoner trans...
# tt2364975                                                 NaN
# tt2637294                          The Laws of Space and Time
# tt0343135   For the most cautious man on Earth, life is ab...
# tt9000001                                                 NaN
# tt9000002                                                 NaN
#
#                                                title               Keywords  \
# imdb_id
# tt0120338                                    Titanic           ship|romance
# tt8178634                                        RRR  friendship|revolution
# tt0112870                Dilwale Dulhania Le Jayenge         romance|family
# tt4154796                          Avengers: Endgame       superhero|marvel
# tt0068646                              The Godfather           mafia|family
# tt1187043                                   3 Idiots     college|friendship
# tt0816692                               Interstellar         space|wormhole
# tt4849438                Baahubali 2: The Conclusion            kingdom|war
# tt5074352                                     Dangal       wrestling|family
# tt0468569                            The Dark Knight           joker|batman
# tt1375666                                  Inception            dream|heist
# tt15327088                                   Kantara      village|tradition
# tt6751668                                   Parasite           family|class
# tt0362227                               The Terminal       airport|new york
# tt3783958                                 La La Land      music|los angeles
# tt0245429                              Spirited Away           spirit|magic
# tt7286456                                      Joker            joker|crime
# tt1821480                                    Kahaani        mystery|kolkata
# tt0116908                    The Long Kiss Goodnight   assassination|memory
# tt1380152                                 Marine Boy                    NaN
# tt0368933   The Princess Diaries 2: Royal Engagement       princess|royalty
# tt0105327                                School Ties           school|sport
# tt1600195                                  Abduction         CIA|conspiracy
# tt2582802                                   Whiplash             jazz|music
# tt0109403                                    Chasers        prison|military
# tt2364975                           We Are the Best!            sweden|punk
# tt2637294                     Hot Tub Time Machine 2            time travel
# tt0343135                           Along Came Polly             beach|love
# tt9000001                           3 Idiots Returns                college
# tt9000002                              Mystery Movie                mystery
#
#                                          cast       revenue movie_profit  \
# imdb_id
# tt0120338     [{"name": "Leonardo DiCaprio"}]  2.264743e+09   2064743305
# tt8178634    [{"name": "N. T. Rama Rao Jr."}]  1.200000e+09    650000000
# tt0112870        [{"name": "Shah Rukh Khan"}]  1.200000e+08     80000000
# tt4154796     [{"name": "Robert Downey Jr."}]  2.797501e+09   2441501328
# tt0068646         [{"name": "Marlon Brando"}]  2.500000e+08    244000000
# tt1187043            [{"name": "Aamir Khan"}]  2.000000e+09   1450000000
# tt0816692   [{"name": "Matthew McConaughey"}]  7.017292e+08    536729206
# tt4849438               [{"name": "Prabhas"}]  1.810000e+09   1560000000
# tt5074352            [{"name": "Aamir Khan"}]  3.100000e+08    240000000
# tt0468569        [{"name": "Christian Bale"}]  1.004558e+09    819558444
# tt1375666     [{"name": "Leonardo DiCaprio"}]  8.390000e+08    679000000
# tt15327088        [{"name": "Rishab Shetty"}]  4.000000e+08    384000000
# tt6751668          [{"name": "Song Kang-ho"}]  2.580000e+08    246600000
# tt0362227             [{"name": "Tom Hanks"}]  2.194173e+08    159417255
# tt3783958          [{"name": "Ryan Gosling"}]  4.720000e+08    442000000
# tt0245429          [{"name": "Rumi Hiiragi"}]  3.958000e+08    376800000
# tt7286456       [{"name": "Joaquin Phoenix"}]  1.074251e+09   1019251311
# tt1821480           [{"name": "Vidya Balan"}]  1.600000e+07     14800000
# tt0116908           [{"name": "Geena Davis"}]  8.945676e+07     24456761
# tt1380152          [{"name": "Kim Kang-woo"}]  3.923970e+06      3923970
# tt0368933         [{"name": "Anne Hathaway"}]           NaN     55149435
# tt0105327        [{"name": "Brendan Fraser"}]  1.471507e+07     14715067
# tt1600195        [{"name": "Taylor Lautner"}]  8.208716e+07     47087155
# tt2582802          [{"name": "Miles Teller"}]  1.309200e+07      9792000
# tt0109403          [{"name": "Tom Berenger"}]  1.596687e+06      1596687
# tt2364975       [{"name": "Mira Barkhammar"}]  1.805900e+05       180590
# tt2637294           [{"name": "Rob Corddry"}]           NaN     -1685349
# tt0343135           [{"name": "Ben Stiller"}]  1.719634e+08    129963386
# tt9000001            [{"name": "Aamir Khan"}]  0.000000e+00    -80000000
# tt9000002               [{"name": "Unknown"}]  4.500000e+07     20000000
#
#                                    Capitalized_title    new_profit
# imdb_id
# tt0120338                                    TITANIC  2.064743e+09
# tt8178634                                        RRR  6.500000e+08
# tt0112870                DILWALE DULHANIA LE JAYENGE  8.000000e+07
# tt4154796                          AVENGERS: ENDGAME  2.441501e+09
# tt0068646                              THE GODFATHER  2.440000e+08
# tt1187043                                   3 IDIOTS  1.450000e+09
# tt0816692                               INTERSTELLAR  5.367292e+08
# tt4849438                BAAHUBALI 2: THE CONCLUSION  1.560000e+09
# tt5074352                                     DANGAL  2.400000e+08
# tt0468569                            THE DARK KNIGHT  8.195584e+08
# tt1375666                                  INCEPTION  6.790000e+08
# tt15327088                                   KANTARA  3.840000e+08
# tt6751668                                   PARASITE  2.466000e+08
# tt0362227                               THE TERMINAL  1.594173e+08
# tt3783958                                 LA LA LAND  4.420000e+08
# tt0245429                              SPIRITED AWAY  3.768000e+08
# tt7286456                                      JOKER  1.019251e+09
# tt1821480                                    KAHAANI  1.480000e+07
# tt0116908                    THE LONG KISS GOODNIGHT  2.445676e+07
# tt1380152                                 MARINE BOY  3.923970e+06
# tt0368933   THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT           NaN
# tt0105327                                SCHOOL TIES  1.471507e+07
# tt1600195                                  ABDUCTION  4.708716e+07
# tt2582802                                   WHIPLASH  9.792000e+06
# tt0109403                                    CHASERS  1.596687e+06
# tt2364975                           WE ARE THE BEST!  1.805900e+05
# tt2637294                     HOT TUB TIME MACHINE 2           NaN
# tt0343135                           ALONG CAME POLLY  1.299634e+08
# tt9000001                           3 IDIOTS RETURNS           NaN
# tt9000002                              MYSTERY MOVIE  2.000000e+07
#
# [30 rows x 22 columns]

# %%
# We can also sort by the combination of two columns
df.sort_values(['status','new_profit'], ascending=[False,True]).head()
# Out:
#           belongs_to_collection    budget  \
# imdb_id
# tt9000001      3 Idiots Returns  80000000
# tt2364975      We Are the Best!         0
# tt0109403               Chasers         0
# tt1380152            Marine Boy         0
# tt2582802              Whiplash   3300000
#
#                                                genres  \
# imdb_id
# tt9000001     [{"name": "Comedy"}, {"name": "Drama"}]
# tt2364975      [{"name": "Drama"}, {"name": "Music"}]
# tt0109403   [{"name": "Comedy"}, {"name": "Romance"}]
# tt1380152  [{"name": "Action"}, {"name": "Thriller"}]
# tt2582802                         [{"name": "Drama"}]
#
#                                     homepage original_language  \
# imdb_id
# tt9000001                                NaN                hi
# tt2364975                                NaN                sv
# tt0109403                                NaN                en
# tt1380152                                NaN                ko
# tt2582802  http://sonyclassics.com/whiplash/                en
#
#              original_title                                      overview  \
# imdb_id
# tt9000001  3 Idiots Returns          Friends reunite years after college.
# tt2364975  We Are the Best!                 Three girls form a punk band.
# tt0109403           Chasers           Two military men escort a prisoner.
# tt1380152        Marine Boy   A former swimmer becomes involved in crime.
# tt2582802          Whiplash  A young drummer faces a ruthless instructor.
#
#            popularity        production_companies    production_countries  \
# imdb_id
# tt9000001   18.200000  [{"name": "Demo Studios"}]  [{"iso_3166_1": "IN"}]
# tt2364975    3.727996   [{"name": "Memfis Film"}]  [{"iso_3166_1": "SE"}]
# tt0109403    9.853270  [{"name": "Warner Bros."}]  [{"iso_3166_1": "US"}]
# tt1380152    1.148070                         NaN  [{"iso_3166_1": "KR"}]
# tt2582802   64.299990    [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]
#
#            ...       spoken_languages    status  \
# imdb_id    ...
# tt9000001  ...    [{"name": "Hindi"}]   Rumored
# tt2364975  ...  [{"name": "Swedish"}]  Released
# tt0109403  ...  [{"name": "English"}]  Released
# tt1380152  ...   [{"name": "Korean"}]  Released
# tt2582802  ...  [{"name": "English"}]  Released
#
#                                                      tagline  \
# imdb_id
# tt9000001                                                NaN
# tt2364975                                                NaN
# tt0109403  It was supposed to be a routine prisoner trans...
# tt1380152                                                NaN
# tt2582802    The road to greatness can take you to the edge.
#
#                       title         Keywords                           cast  \
# imdb_id
# tt9000001  3 Idiots Returns          college       [{"name": "Aamir Khan"}]
# tt2364975  We Are the Best!      sweden|punk  [{"name": "Mira Barkhammar"}]
# tt0109403           Chasers  prison|military     [{"name": "Tom Berenger"}]
# tt1380152        Marine Boy              NaN     [{"name": "Kim Kang-woo"}]
# tt2582802          Whiplash       jazz|music     [{"name": "Miles Teller"}]
#
#               revenue movie_profit  Capitalized_title  new_profit
# imdb_id
# tt9000001         0.0    -80000000   3 IDIOTS RETURNS         NaN
# tt2364975    180590.0       180590   WE ARE THE BEST!    180590.0
# tt0109403   1596687.0      1596687            CHASERS   1596687.0
# tt1380152   3923970.0      3923970         MARINE BOY   3923970.0
# tt2582802  13092000.0      9792000           WHIPLASH   9792000.0
#
# [5 rows x 22 columns]

# %% [markdown]
# # <b>Let us explore some datetime operations and functions

# %% [markdown]
# Directive
#
# * #### <b>%a</b>	Weekday as locale’s abbreviated name.	Sun, Mon, …, Sat (en_US)
# So, Mo, …, Sa (de_DE)
# * #### <b>%A</b>	Weekday as locale’s full name.	Sunday, Monday, …, Saturday (en_US)
# Sonntag, Montag, …, Samstag (de_DE)
# * #### <b>%w</b>	Weekday as a decimal number, where 0 is Sunday and 6 is Saturday.	0, 1, 2, 3, 4, 5, 6
# * #### <b>%d</b>	Day of the month as a zero-padded decimal number.	01, 02, …, 31
# * #### <b>%b</b>	Month as locale’s abbreviated name.	Jan, Feb, …, Dec (en_US)
# Jan, Feb, …, Dez (de_DE)
# * #### <b>%B</b>	Month as locale’s full name.	January, February, …, December (en_US)
# Januar, Februar, …, Dezember (de_DE)
# * #### <b>%m</b>	Month as a zero-padded decimal number.	01, 02 … 12
# * #### <b>%y</b>	Year without century as a zero-padded decimal number.	01, 02, … 99
# * #### <b>%Y</b>	Year with century as a decimal number.	0001, 0002, … , 9999
# * #### <b>%H</b>	Hour (24-hour clock) as a zero-padded decimal number.	01, 02, … , 23
# * #### <b>%I</b>	Hour (12-hour clock) as a zero-padded decimal number.	01, 02, … , 12
# * #### <b>%p</b>	Locale’s equivalent of either AM or PM.	AM, PM (en_US)
# am, pm (de_DE)
# * #### <b>%M</b>	Minute as a zero-padded decimal number.	01, 02, … , 59
# * #### <b>%S</b>	Second as a zero-padded decimal number.	01, 02, … , 59
# * #### <b>%f</b>	Microsecond as a decimal number, zero-padded on the left.	000000, 000001, …, 999999

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 30 entries, tt2637294 to tt0112870
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  30 non-null     str
#  1   budget                 30 non-null     int64
#  2   genres                 29 non-null     str
#  3   homepage               9 non-null      str
#  4   original_language      30 non-null     str
#  5   original_title         30 non-null     str
#  6   overview               30 non-null     str
#  7   popularity             30 non-null     float64
#  8   production_companies   27 non-null     str
#  9   production_countries   30 non-null     str
#  10  release_date           30 non-null     str
#  11  runtime                29 non-null     float64
#  12  spoken_languages       30 non-null     str
#  13  status                 30 non-null     str
#  14  tagline                25 non-null     str
#  15  title                  30 non-null     str
#  16  Keywords               29 non-null     str
#  17  cast                   30 non-null     str
#  18  revenue                28 non-null     float64
#  19  movie_profit           30 non-null     int64
#  20  Capitalized_title      30 non-null     str
#  21  new_profit             27 non-null     float64
# dtypes: float64(4), int64(2), str(16)
# memory usage: 6.4+ KB

# %%
df['release_date'][0:5]
# Out:
# imdb_id
# tt2637294     2/20/15
# tt0368933      8/6/04
# tt2582802    10/10/14
# tt1821480      3/9/12
# tt1380152      2/5/09
# Name: release_date, dtype: str

# %%
# Importing datetime modules
from datetime import datetime
from datetime import date

# %% [markdown]
# ## <code>strptime</code> means string parser, this will convert a string format to datetime.
#
# ## <code>strftime</code> means string formatter, this will format a datetime object to string format.

# %%
df['release_date'][0:5]
# Out:
# imdb_id
# tt2637294     2/20/15
# tt0368933      8/6/04
# tt2582802    10/10/14
# tt1821480      3/9/12
# tt1380152      2/5/09
# Name: release_date, dtype: str

# %%
df['new_release_date']=df['release_date'].apply(lambda x : datetime.strptime(x,'%m/%d/%y'))

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 30 entries, tt2637294 to tt0112870
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  30 non-null     str
#  1   budget                 30 non-null     int64
#  2   genres                 29 non-null     str
#  3   homepage               9 non-null      str
#  4   original_language      30 non-null     str
#  5   original_title         30 non-null     str
#  6   overview               30 non-null     str
#  7   popularity             30 non-null     float64
#  8   production_companies   27 non-null     str
#  9   production_countries   30 non-null     str
#  10  release_date           30 non-null     str
#  11  runtime                29 non-null     float64
#  12  spoken_languages       30 non-null     str
#  13  status                 30 non-null     str
#  14  tagline                25 non-null     str
#  15  title                  30 non-null     str
#  16  Keywords               29 non-null     str
#  17  cast                   30 non-null     str
#  18  revenue                28 non-null     float64
#  19  movie_profit           30 non-null     int64
#  20  Capitalized_title      30 non-null     str
#  21  new_profit             27 non-null     float64
#  22  new_release_date       30 non-null     datetime64[us]
# dtypes: datetime64[us](1), float64(4), int64(2), str(16)
# memory usage: 6.7+ KB

# %%
df.head()
# Out:
#                               belongs_to_collection    budget  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2  14000000
# tt0368933  The Princess Diaries 2: Royal Engagement  40000000
# tt2582802                                  Whiplash   3300000
# tt1821480                                   Kahaani   1200000
# tt1380152                                Marine Boy         0
#
#                                                genres  \
# imdb_id
# tt2637294                        [{"name": "Comedy"}]
# tt0368933     [{"name": "Comedy"}, {"name": "Drama"}]
# tt2582802                         [{"name": "Drama"}]
# tt1821480   [{"name": "Thriller"}, {"name": "Drama"}]
# tt1380152  [{"name": "Action"}, {"name": "Thriller"}]
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# tt0368933                                NaN                en
# tt2582802  http://sonyclassics.com/whiplash/                en
# tt1821480         http://kahaanithefilm.com/                hi
# tt1380152                                NaN                ko
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                Marine Boy
#
#                                                     overview  popularity  \
# imdb_id
# tt2637294                                Time travel comedy.    6.575393
# tt0368933                  A princess prepares for marriage.    8.248895
# tt2582802       A young drummer faces a ruthless instructor.   64.299990
# tt1821480  A woman searches for her missing husband in Ko...    3.174936
# tt1380152        A former swimmer becomes involved in crime.    1.148070
#
#                          production_companies    production_countries  ...  \
# imdb_id                                                                ...
# tt2637294    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]  ...
# tt0368933  [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]  ...
# tt2582802            [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]  ...
# tt1821480                                 NaN  [{"iso_3166_1": "IN"}]  ...
# tt1380152                                 NaN  [{"iso_3166_1": "KR"}]  ...
#
#              status                                          tagline  \
# imdb_id
# tt2637294  Released                       The Laws of Space and Time
# tt0368933  Released        It can take a lifetime to find true love.
# tt2582802  Released  The road to greatness can take you to the edge.
# tt1821480  Released                                              NaN
# tt1380152  Released                                              NaN
#
#                                               title          Keywords  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2       time travel
# tt0368933  The Princess Diaries 2: Royal Engagement  princess|royalty
# tt2582802                                  Whiplash        jazz|music
# tt1821480                                   Kahaani   mystery|kolkata
# tt1380152                                Marine Boy               NaN
#
#                                   cast     revenue movie_profit  \
# imdb_id
# tt2637294    [{"name": "Rob Corddry"}]         NaN     -1685349
# tt0368933  [{"name": "Anne Hathaway"}]         NaN     55149435
# tt2582802   [{"name": "Miles Teller"}]  13092000.0      9792000
# tt1821480    [{"name": "Vidya Balan"}]  16000000.0     14800000
# tt1380152   [{"name": "Kim Kang-woo"}]   3923970.0      3923970
#
#                                   Capitalized_title  new_profit  \
# imdb_id
# tt2637294                    HOT TUB TIME MACHINE 2         NaN
# tt0368933  THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT         NaN
# tt2582802                                  WHIPLASH   9792000.0
# tt1821480                                   KAHAANI  14800000.0
# tt1380152                                MARINE BOY   3923970.0
#
#            new_release_date
# imdb_id
# tt2637294        2015-02-20
# tt0368933        2004-08-06
# tt2582802        2014-10-10
# tt1821480        2012-03-09
# tt1380152        2009-02-05
#
# [5 rows x 23 columns]

# %%
df['new_release_date'].iloc[0]
# Out:
# Timestamp('2015-02-20 00:00:00')

# %%
# Month year date
print(df['new_release_date'][0].month)
print(df['new_release_date'][0].year)
print(df['new_release_date'][0].day)
print(df['new_release_date'][0].hour)
print(df['new_release_date'][0].minute)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\LakshmanAIMLHYD\anaconda3\envs\laxman\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 2
#       1 # Month year date
# ----> 2 print(df['new_release_date'][0].month)
#       3 print(df['new_release_date'][0].year)
#       4 print(df['new_release_date'][0].day)
#       5 print(df['new_release_date'][0].hour)
#
# File c:\Users\LakshmanAIMLHYD\anaconda3\envs\laxman\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File c:\Users\LakshmanAIMLHYD\anaconda3\envs\laxman\Lib\site-packages\pandas\core\series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File c:\Users\LakshmanAIMLHYD\anaconda3\envs\laxman\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 0

# %%
print(date.today())
print(datetime.now())
# Out:
# 2021-02-17
# 2021-02-17 16:19:20.428727

# %%
datetime.now() + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-168-29385c49cec3> in <module>()
# ----> 1 datetime.now() + 1
#
# TypeError: unsupported operand type(s) for +: 'datetime.datetime' and 'int'

# %%
# Some operations we can do on datetime
from datetime import timedelta
print(date.today())
print(date.today() - timedelta(days=1))
print(datetime.now() + timedelta(hours=5.5))
print(datetime.now() + timedelta(seconds=60))
# Out:
# 2021-02-17
# 2021-02-16
# 2021-02-17 21:52:15.067322
# 2021-02-17 16:23:15.067618

# %%
print(df['new_release_date'][0])
print(df['new_release_date'][5])
# Out:
# 2015-02-20 00:00:00
# 1987-08-06 00:00:00

# %%
# Difference in two datetime
time_delta=df['new_release_date'][0]-df['new_release_date'][5]
time_delta
# Out:
# Timedelta('10060 days 00:00:00')

# %%
type(time_delta)
# Out:
# pandas._libs.tslibs.timedeltas.Timedelta

# %%
t1 = pd.to_datetime('1/1/2015 01:00')
t2 = pd.to_datetime('1/1/2015 03:30')

print(pd.Timedelta(t2 - t1).seconds / 3600.0)
# Out:
# 2.5

# %% [markdown]
# # **Let's explore the unique and missing values**
#
# * ### <code>unique()</code>
# * ### <code>nunique()</code>
# * ### <code>value_counts()</code>
# * ### <code>isnull()</code>
# * ### <code>fillna()</code>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 30 entries, tt2637294 to tt0112870
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  30 non-null     str
#  1   budget                 30 non-null     int64
#  2   genres                 29 non-null     str
#  3   homepage               9 non-null      str
#  4   original_language      30 non-null     str
#  5   original_title         30 non-null     str
#  6   overview               30 non-null     str
#  7   popularity             30 non-null     float64
#  8   production_companies   27 non-null     str
#  9   production_countries   30 non-null     str
#  10  release_date           30 non-null     str
#  11  runtime                29 non-null     float64
#  12  spoken_languages       30 non-null     str
#  13  status                 30 non-null     str
#  14  tagline                25 non-null     str
#  15  title                  30 non-null     str
#  16  Keywords               29 non-null     str
#  17  cast                   30 non-null     str
#  18  revenue                28 non-null     float64
#  19  movie_profit           30 non-null     int64
#  20  Capitalized_title      30 non-null     str
#  21  new_profit             27 non-null     float64
#  22  new_release_date       30 non-null     datetime64[us]
# dtypes: datetime64[us](1), float64(4), int64(2), str(16)
# memory usage: 6.7+ KB

# %%
# Find the list of unique values in a column
list(df['status'].unique())
# Out:
# ['Released', 'Rumored']

# %%
list(df['original_language'].unique())
# Out:
# ['en', 'hi', 'ko', 'sv', 'ja', 'kn', 'te']

# %%
# Counts the number of unique values in a column
df.original_language.nunique()
# Out:
# 7

# %%
# Give the counts of each category of a variable
df['original_language'].value_counts()
# Out:
# original_language
# en    18
# hi     5
# ko     2
# te     2
# sv     1
# ja     1
# kn     1
# Name: count, dtype: int64

# %%
# Does not make much sense to use value_counts for a numeric variable
df.runtime.value_counts()
# Out:
# runtime
# 122.0    2
# 148.0    2
# 128.0    2
# 106.0    2
# 102.0    2
# 181.0    2
# 93.0     1
# 113.0    1
# 105.0    1
# 118.0    1
# 152.0    1
# 170.0    1
# 132.0    1
# 120.0    1
# 90.0     1
# 169.0    1
# 161.0    1
# 194.0    1
# 125.0    1
# 175.0    1
# 0.0      1
# 187.0    1
# 168.0    1
# Name: count, dtype: int64

# %%
# Returns a series of booleans if a column value contains nulls
df['homepage'].isnull()
# Out:
# imdb_id
# tt2637294      True
# tt0368933      True
# tt2582802     False
# tt1821480     False
# tt1380152      True
# tt1375666     False
# tt0468569      True
# tt1187043     False
# tt6751668      True
# tt0362227     False
# tt0105327      True
# tt0109403      True
# tt2364975      True
# tt0116908      True
# tt0343135     False
# tt1600195     False
# tt0816692      True
# tt5074352      True
# tt4154796      True
# tt0120338      True
# tt0245429     False
# tt0068646      True
# tt9000001      True
# tt9000002      True
# tt15327088    False
# tt8178634      True
# tt4849438      True
# tt7286456      True
# tt3783958      True
# tt0112870      True
# Name: homepage, dtype: bool

# %%
df[~df['homepage'].isnull()]
# Out:
#            belongs_to_collection     budget  \
# imdb_id
# tt2582802               Whiplash    3300000
# tt1821480                Kahaani    1200000
# tt1375666              Inception  160000000
# tt1187043               3 Idiots  550000000
# tt0362227           The Terminal   60000000
# tt0343135       Along Came Polly   42000000
# tt1600195              Abduction   35000000
# tt0245429          Spirited Away   19000000
# tt15327088               Kantara   16000000
#
#                                                   genres  \
# imdb_id
# tt2582802                            [{"name": "Drama"}]
# tt1821480      [{"name": "Thriller"}, {"name": "Drama"}]
# tt1375666       [{"name": "Action"}, {"name": "Sci-Fi"}]
# tt1187043        [{"name": "Comedy"}, {"name": "Drama"}]
# tt0362227        [{"name": "Comedy"}, {"name": "Drama"}]
# tt0343135      [{"name": "Comedy"}, {"name": "Romance"}]
# tt1600195     [{"name": "Thriller"}, {"name": "Action"}]
# tt0245429   [{"name": "Animation"}, {"name": "Fantasy"}]
# tt15327088       [{"name": "Action"}, {"name": "Drama"}]
#
#                                         homepage original_language  \
# imdb_id
# tt2582802      http://sonyclassics.com/whiplash/                en
# tt1821480             http://kahaanithefilm.com/                hi
# tt1375666          https://example.com/inception                en
# tt1187043            https://example.com/3idiots                hi
# tt0362227   http://www.theterminal-themovie.com/                en
# tt0343135         http://www.alongcamepolly.com/                en
# tt1600195       http://www.abductionthefilm.com/                en
# tt0245429           https://example.com/spirited                ja
# tt15327088           https://example.com/kantara                kn
#
#               original_title  \
# imdb_id
# tt2582802           Whiplash
# tt1821480            Kahaani
# tt1375666          Inception
# tt1187043           3 Idiots
# tt0362227       The Terminal
# tt0343135   Along Came Polly
# tt1600195          Abduction
# tt0245429      Spirited Away
# tt15327088           Kantara
#
#                                                      overview  popularity  \
# imdb_id
# tt2582802        A young drummer faces a ruthless instructor.   64.299990
# tt1821480   A woman searches for her missing husband in Ko...    3.174936
# tt1375666             A thief enters dreams to steal secrets.   82.500000
# tt1187043            Three friends navigate college and life.   25.300000
# tt0362227               A man becomes stranded in an airport.   14.092373
# tt0343135               A cautious man finds unexpected love.   15.725542
# tt1600195   A young man searches for the truth about his i...   10.512109
# tt0245429            A girl enters a mysterious spirit world.   72.100000
# tt15327088  A village conflict involving tradition and nat...   42.700000
#
#                         production_companies    production_countries  ...  \
# imdb_id                                                               ...
# tt2582802           [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]  ...
# tt1821480                                NaN  [{"iso_3166_1": "IN"}]  ...
# tt1375666         [{"name": "Warner Bros."}]  [{"iso_3166_1": "US"}]  ...
# tt1187043   [{"name": "Vinod Chopra Films"}]  [{"iso_3166_1": "IN"}]  ...
# tt0362227       [{"name": "DreamWorks SKG"}]  [{"iso_3166_1": "US"}]  ...
# tt0343135         [{"name": "Jersey Films"}]  [{"iso_3166_1": "US"}]  ...
# tt1600195     [{"name": "Lions Gate Films"}]  [{"iso_3166_1": "US"}]  ...
# tt0245429        [{"name": "Studio Ghibli"}]  [{"iso_3166_1": "JP"}]  ...
# tt15327088       [{"name": "Hombale Films"}]  [{"iso_3166_1": "IN"}]  ...
#
#               status                                            tagline  \
# imdb_id
# tt2582802   Released    The road to greatness can take you to the edge.
# tt1821480   Released                                                NaN
# tt1375666   Released               Your mind is the scene of the crime.
# tt1187043   Released                                       All is well.
# tt0362227   Released                                   Life is waiting.
# tt0343135   Released  For the most cautious man on Earth, life is ab...
# tt1600195   Released          They stole his life. He's taking it back.
# tt0245429   Released       The tunnel led Chihiro to a mysterious town.
# tt15327088  Released             When tradition calls, destiny answers.
#
#                        title            Keywords  \
# imdb_id
# tt2582802           Whiplash          jazz|music
# tt1821480            Kahaani     mystery|kolkata
# tt1375666          Inception         dream|heist
# tt1187043           3 Idiots  college|friendship
# tt0362227       The Terminal    airport|new york
# tt0343135   Along Came Polly          beach|love
# tt1600195          Abduction      CIA|conspiracy
# tt0245429      Spirited Away        spirit|magic
# tt15327088           Kantara   village|tradition
#
#                                        cast       revenue movie_profit  \
# imdb_id
# tt2582802        [{"name": "Miles Teller"}]  1.309200e+07      9792000
# tt1821480         [{"name": "Vidya Balan"}]  1.600000e+07     14800000
# tt1375666   [{"name": "Leonardo DiCaprio"}]  8.390000e+08    679000000
# tt1187043          [{"name": "Aamir Khan"}]  2.000000e+09   1450000000
# tt0362227           [{"name": "Tom Hanks"}]  2.194173e+08    159417255
# tt0343135         [{"name": "Ben Stiller"}]  1.719634e+08    129963386
# tt1600195      [{"name": "Taylor Lautner"}]  8.208716e+07     47087155
# tt0245429        [{"name": "Rumi Hiiragi"}]  3.958000e+08    376800000
# tt15327088      [{"name": "Rishab Shetty"}]  4.000000e+08    384000000
#
#            Capitalized_title    new_profit  new_release_date
# imdb_id
# tt2582802           WHIPLASH  9.792000e+06        2014-10-10
# tt1821480            KAHAANI  1.480000e+07        2012-03-09
# tt1375666          INCEPTION  6.790000e+08        2010-07-16
# tt1187043           3 IDIOTS  1.450000e+09        2009-12-25
# tt0362227       THE TERMINAL  1.594173e+08        2004-06-17
# tt0343135   ALONG CAME POLLY  1.299634e+08        2004-01-16
# tt1600195          ABDUCTION  4.708716e+07        2011-09-22
# tt0245429      SPIRITED AWAY  3.768000e+08        2001-07-20
# tt15327088           KANTARA  3.840000e+08        2022-09-30
#
# [9 rows x 23 columns]

# %%
# Lets fill the missing values with the value -999
df['homepage'].fillna('Not Present',inplace = True)
# Out:
# C:\Users\LakshmanAIMLHYD\AppData\Local\Temp\ipykernel_8920\1233594187.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['homepage'].fillna('Not Present',inplace = True)
# imdb_id
# tt2637294                              Not Present
# tt0368933                              Not Present
# tt2582802        http://sonyclassics.com/whiplash/
# tt1821480               http://kahaanithefilm.com/
# tt1380152                              Not Present
# tt1375666            https://example.com/inception
# tt0468569                              Not Present
# tt1187043              https://example.com/3idiots
# tt6751668                              Not Present
# tt0362227     http://www.theterminal-themovie.com/
# tt0105327                              Not Present
# tt0109403                              Not Present
# tt2364975                              Not Present
# tt0116908                              Not Present
# tt0343135           http://www.alongcamepolly.com/
# tt1600195         http://www.abductionthefilm.com/
# tt0816692                              Not Present
# tt5074352                              Not Present
# tt4154796                              Not Present
# tt0120338                              Not Present
# tt0245429             https://example.com/spirited
# tt0068646                              Not Present
# tt9000001                              Not Present
# tt9000002                              Not Present
# tt15327088             https://example.com/kantara
# tt8178634                              Not Present
# tt4849438                              Not Present
# tt7286456                              Not Present
# tt3783958                              Not Present
# tt0112870                              Not Present
# Name: homepage, dtype: str

# %%
df.head()
# Out:
#                               belongs_to_collection    budget  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2  14000000
# tt0368933  The Princess Diaries 2: Royal Engagement  40000000
# tt2582802                                  Whiplash   3300000
# tt1821480                                   Kahaani   1200000
# tt1380152                                Marine Boy         0
#
#                                                genres  \
# imdb_id
# tt2637294                        [{"name": "Comedy"}]
# tt0368933     [{"name": "Comedy"}, {"name": "Drama"}]
# tt2582802                         [{"name": "Drama"}]
# tt1821480   [{"name": "Thriller"}, {"name": "Drama"}]
# tt1380152  [{"name": "Action"}, {"name": "Thriller"}]
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# tt0368933                                NaN                en
# tt2582802  http://sonyclassics.com/whiplash/                en
# tt1821480         http://kahaanithefilm.com/                hi
# tt1380152                                NaN                ko
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                Marine Boy
#
#                                                     overview  popularity  \
# imdb_id
# tt2637294                                Time travel comedy.    6.575393
# tt0368933                  A princess prepares for marriage.    8.248895
# tt2582802       A young drummer faces a ruthless instructor.   64.299990
# tt1821480  A woman searches for her missing husband in Ko...    3.174936
# tt1380152        A former swimmer becomes involved in crime.    1.148070
#
#                          production_companies    production_countries  ...  \
# imdb_id                                                                ...
# tt2637294    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]  ...
# tt0368933  [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]  ...
# tt2582802            [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]  ...
# tt1821480                                 NaN  [{"iso_3166_1": "IN"}]  ...
# tt1380152                                 NaN  [{"iso_3166_1": "KR"}]  ...
#
#              status                                          tagline  \
# imdb_id
# tt2637294  Released                       The Laws of Space and Time
# tt0368933  Released        It can take a lifetime to find true love.
# tt2582802  Released  The road to greatness can take you to the edge.
# tt1821480  Released                                              NaN
# tt1380152  Released                                              NaN
#
#                                               title          Keywords  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2       time travel
# tt0368933  The Princess Diaries 2: Royal Engagement  princess|royalty
# tt2582802                                  Whiplash        jazz|music
# tt1821480                                   Kahaani   mystery|kolkata
# tt1380152                                Marine Boy               NaN
#
#                                   cast     revenue movie_profit  \
# imdb_id
# tt2637294    [{"name": "Rob Corddry"}]         NaN     -1685349
# tt0368933  [{"name": "Anne Hathaway"}]         NaN     55149435
# tt2582802   [{"name": "Miles Teller"}]  13092000.0      9792000
# tt1821480    [{"name": "Vidya Balan"}]  16000000.0     14800000
# tt1380152   [{"name": "Kim Kang-woo"}]   3923970.0      3923970
#
#                                   Capitalized_title  new_profit  \
# imdb_id
# tt2637294                    HOT TUB TIME MACHINE 2         NaN
# tt0368933  THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT         NaN
# tt2582802                                  WHIPLASH   9792000.0
# tt1821480                                   KAHAANI  14800000.0
# tt1380152                                MARINE BOY   3923970.0
#
#            new_release_date
# imdb_id
# tt2637294        2015-02-20
# tt0368933        2004-08-06
# tt2582802        2014-10-10
# tt1821480        2012-03-09
# tt1380152        2009-02-05
#
# [5 rows x 23 columns]
