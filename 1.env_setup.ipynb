# %% [markdown]
# **env**

# %% [markdown]
# - step-1

# %% [markdown]
# **conda create -n  laxman python=3.12 -y**
#
# **or**
#
# **conda create -n  laxman python==3.12 -y**

# %% [markdown]
# - step-2  ( activation of env)

# %% [markdown]
# conda activate laxman

# %% [markdown]
# **env** 2nd method

# %% [markdown]
# **python -m venv venv**

# %% [markdown]
# venv\Scripts\activate

# %% [markdown]
# **if you are using linux/ macos**
#
# source venv/bin/activate

# %%
5
