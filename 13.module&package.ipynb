# %% [markdown]
# # Module:
#     - it is python file , to creating (.py ) file  containing functions, clasess, variables that you want to include in the another program file

# %% [markdown]
# # for example module you can refer math_utils.py and main.py

# %% [markdown]
# - Package:
#     - a package is a directory
#     - it contains multiple modules and special name
#
#
#
#  ![image.png](attachment:image.png)
